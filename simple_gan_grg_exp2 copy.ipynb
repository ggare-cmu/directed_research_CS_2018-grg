# %%
import torch
import pandas as pd
from torch import nn, optim
from torch.autograd.variable import Variable
from torchvision import transforms, datasets
from data_treatment import DataSetGRG, DataAtts
from discriminator import *
from generator import *
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt
import glob

# %%
# Noise
def noise(size):
    n = Variable(torch.randn(size, 100))
    if torch.cuda.is_available(): 
        return n.cuda() 
    return n

# %%
files_dropdown = widgets.Dropdown(
    # options=glob.glob("original_data/*.csv"),
    options=glob.glob("grg_data/*.csv"),
    description='File:',
    # value = 'original_data/diabetes_escalonated.csv',
    disabled=False,
)
display(files_dropdown)
# Out:
# Dropdown(description='File:', options=('grg_data/diabetes-small3_TrainUpsampledPatient.csv', 'grg_data/diabete…

# %%
file_name=files_dropdown.value
dataAtts = DataAtts(file_name)

# %%
def train_generator(optimizer, fake_data):
    # 2. Train Generator
    # Reset gradients
    optimizer.zero_grad()
    # Sample noise and generate fake data
    prediction = discriminator(fake_data)
    # Calculate error and backpropagate
    error = loss(prediction, real_data_target(prediction.size(0)))
    error.backward()
    # Update weights with gradients
    optimizer.step()
    # Return error
    return error

def train_discriminator(optimizer, real_data, fake_data):
    # Reset gradients
    optimizer.zero_grad()
    
    # 1.1 Train on Real Data
    prediction_real = discriminator(real_data)
    # Calculate error and backpropagate
    error_real = loss(prediction_real, real_data_target(real_data.size(0)))
    error_real.backward()

    # 1.2 Train on Fake Data
    prediction_fake = discriminator(fake_data)
    # Calculate error and backpropagate
    error_fake = loss(prediction_fake, fake_data_target(real_data.size(0)))
    error_fake.backward()
    
    # 1.3 Update weights with gradients
    optimizer.step()
    
    # Return error
    return error_real + error_fake, prediction_real, prediction_fake

# %%
def real_data_target(size):
    '''
    Tensor containing ones, with shape = size
    '''
    data = Variable(torch.ones(size, 1))
    if torch.cuda.is_available(): return data.cuda()
    return data

def fake_data_target(size):
    '''
    Tensor containing zeros, with shape = size
    '''
    data = Variable(torch.zeros(size, 1))
    if torch.cuda.is_available(): return data.cuda()
    return data

# %%
lr = 0.0002
#lr= 0.0002
batch_size = 5
# num_epochs = 106
num_epochs = 1500
print_interval = 10
loss = nn.BCELoss()

# %%
# discriminator = DiscriminatorNet(dataAtts.class_len)
discriminator = DiscriminatorNet(dataAtts.class_len,  hidden_layers=[512, 256])
generator = GeneratorNet(dataAtts.class_len,  hidden_layers=[512, 256])
if torch.cuda.is_available():
    discriminator.cuda()
    generator.cuda()
d_optimizer = optim.Adam(discriminator.parameters(), lr=lr)
g_optimizer = optim.Adam(generator.parameters(), lr=lr)

# %%
d_error_plt = [0]
g_error_plt = [0]

generated_points = []

# %%
database = DataSetGRG(csv_file=file_name, root_dir=".")

data_loader = torch.utils.data.DataLoader(database, batch_size=batch_size, shuffle=True)
num_batches = len(data_loader)

# %%
for epoch in range(num_epochs):
    print("Epoch ", epoch)

    for n_batch, real_batch in enumerate(data_loader):
        # 1. Train Discriminator
        real_data = Variable(real_batch).float()
        if torch.cuda.is_available(): 
            real_data = real_data.cuda()
        # Generate fake data
        fake_data = generator(noise(real_data.size(0))).detach()
        # Train D
        d_error, d_pred_real, d_pred_fake = train_discriminator(d_optimizer,
                                                                real_data, fake_data)

        # 2. Train Generator
        # Generate fake data
        fake_data = generator(noise(real_batch.size(0)))
        generated_points.append(fake_data)
        # Train G
        g_error = train_generator(g_optimizer, fake_data)

        # Display Progress

        #if (n_batch) % print_interval == 0:
    filename = "results/" + dataAtts.fname + "/" + str(epoch) + "_" + str(n_batch) + ".txt"
    print(filename)
    file = open(filename, "w")
    print("Discriminator error: ", d_error)
    print("Generator error: ", g_error)
    print("")

    file.write("Discriminator error: " + str(d_error) + "\n")
    file.write("Generator error: " + str(g_error) + "\n")
    file.write("Points: " + str(fake_data) + "\n\n\n")

    # d_error_plt.append(d_error)
    # g_error_plt.append(g_error)
    d_error_plt.append(d_error.detach().cpu().numpy())
    g_error_plt.append(g_error.detach().cpu().numpy())
        #     #display.clear_output(True)
        #     # Display Images
        #     test_images = generator(test_noise).data.cpu()
        #     logger.log_images(test_images, num_test_samples, epoch, n_batch, num_batches);
        #     # Display status Logs
        #     #logger.display_status(epoch, num_epochs, n_batch, num_batches, d_error, g_error, d_pred_real, d_pred_fake)
        # # Model Checkpoints
# Out:
# Epoch  0
# results/diabetes/0_19.txt
# Discriminator error:  tensor(0.6609, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7908, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1
# results/diabetes/1_19.txt
# Discriminator error:  tensor(0.5971, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8246, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  2
# results/diabetes/2_19.txt
# Discriminator error:  tensor(0.8268, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6612, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  3
# results/diabetes/3_19.txt
# Discriminator error:  tensor(0.5630, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6951, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  4
# results/diabetes/4_19.txt
# Discriminator error:  tensor(1.1456, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4937, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  5
# results/diabetes/5_19.txt
# Discriminator error:  tensor(1.2168, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6397, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  6
# results/diabetes/6_19.txt
# Discriminator error:  tensor(0.5981, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7338, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  7
# results/diabetes/7_19.txt
# Discriminator error:  tensor(1.7124, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9907, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  8
# results/diabetes/8_19.txt
# Discriminator error:  tensor(0.8791, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5749, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  9
# results/diabetes/9_19.txt
# Discriminator error:  tensor(1.1772, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9163, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  10
# results/diabetes/10_19.txt
# Discriminator error:  tensor(1.5328, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.3944, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  11
# results/diabetes/11_19.txt
# Discriminator error:  tensor(0.9092, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6395, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  12
# results/diabetes/12_19.txt
# Discriminator error:  tensor(1.6907, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4576, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  13
# results/diabetes/13_19.txt
# Discriminator error:  tensor(0.8118, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8227, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  14
# results/diabetes/14_19.txt
# Discriminator error:  tensor(1.6104, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9972, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  15
# results/diabetes/15_19.txt
# Discriminator error:  tensor(2.6518, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.5179, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  16
# results/diabetes/16_19.txt
# Discriminator error:  tensor(4.3126, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4344, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  17
# results/diabetes/17_19.txt
# Discriminator error:  tensor(1.6998, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1658, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  18
# results/diabetes/18_19.txt
# Discriminator error:  tensor(2.1013, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3603, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  19
# results/diabetes/19_19.txt
# Discriminator error:  tensor(1.3009, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4625, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  20
# results/diabetes/20_19.txt
# Discriminator error:  tensor(1.1831, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1987, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  21
# results/diabetes/21_19.txt
# Discriminator error:  tensor(0.3274, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0834, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  22
# results/diabetes/22_19.txt
# Discriminator error:  tensor(0.6002, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2039, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  23
# results/diabetes/23_19.txt
# Discriminator error:  tensor(0.7862, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7366, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  24
# results/diabetes/24_19.txt
# Discriminator error:  tensor(2.2807, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0590, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  25
# results/diabetes/25_19.txt
# Discriminator error:  tensor(0.4057, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4233, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  26
# results/diabetes/26_19.txt
# Discriminator error:  tensor(0.6745, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3000, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  27
# results/diabetes/27_19.txt
# Discriminator error:  tensor(0.9957, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0877, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  28
# results/diabetes/28_19.txt
# Discriminator error:  tensor(1.1371, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1393, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  29
# results/diabetes/29_19.txt
# Discriminator error:  tensor(2.3951, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6581, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  30
# results/diabetes/30_19.txt
# Discriminator error:  tensor(1.4750, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.3118, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  31
# results/diabetes/31_19.txt
# Discriminator error:  tensor(1.4564, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.3115, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  32
# results/diabetes/32_19.txt
# Discriminator error:  tensor(1.5916, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5555, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  33
# results/diabetes/33_19.txt
# Discriminator error:  tensor(0.5702, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4066, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  34
# results/diabetes/34_19.txt
# Discriminator error:  tensor(0.5324, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0865, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  35
# results/diabetes/35_19.txt
# Discriminator error:  tensor(0.9939, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6096, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  36
# results/diabetes/36_19.txt
# Discriminator error:  tensor(2.2376, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7994, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  37
# results/diabetes/37_19.txt
# Discriminator error:  tensor(0.7784, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9633, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  38
# results/diabetes/38_19.txt
# Discriminator error:  tensor(0.8419, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9423, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  39
# results/diabetes/39_19.txt
# Discriminator error:  tensor(2.7207, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8522, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  40
# results/diabetes/40_19.txt
# Discriminator error:  tensor(2.0847, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7130, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  41
# results/diabetes/41_19.txt
# Discriminator error:  tensor(1.2008, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9627, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  42
# results/diabetes/42_19.txt
# Discriminator error:  tensor(0.7000, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5702, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  43
# results/diabetes/43_19.txt
# Discriminator error:  tensor(0.5398, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5525, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  44
# results/diabetes/44_19.txt
# Discriminator error:  tensor(0.7660, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1174, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  45
# results/diabetes/45_19.txt
# Discriminator error:  tensor(0.7137, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1037, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  46
# results/diabetes/46_19.txt
# Discriminator error:  tensor(0.9290, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6330, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  47
# results/diabetes/47_19.txt
# Discriminator error:  tensor(0.8502, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4480, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  48
# results/diabetes/48_19.txt
# Discriminator error:  tensor(2.6820, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5402, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  49
# results/diabetes/49_19.txt
# Discriminator error:  tensor(0.6208, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8250, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  50
# results/diabetes/50_19.txt
# Discriminator error:  tensor(0.9893, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0273, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  51
# results/diabetes/51_19.txt
# Discriminator error:  tensor(2.1734, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4059, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  52
# results/diabetes/52_19.txt
# Discriminator error:  tensor(0.5926, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7097, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  53
# results/diabetes/53_19.txt
# Discriminator error:  tensor(0.5534, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5140, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  54
# results/diabetes/54_19.txt
# Discriminator error:  tensor(0.9042, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0282, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  55
# results/diabetes/55_19.txt
# Discriminator error:  tensor(0.8004, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5696, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  56
# results/diabetes/56_19.txt
# Discriminator error:  tensor(0.2128, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8269, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  57
# results/diabetes/57_19.txt
# Discriminator error:  tensor(0.3576, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.3354, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  58
# results/diabetes/58_19.txt
# Discriminator error:  tensor(0.2093, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5637, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  59
# results/diabetes/59_19.txt
# Discriminator error:  tensor(1.9900, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5828, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  60
# results/diabetes/60_19.txt
# Discriminator error:  tensor(0.4170, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4933, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  61
# results/diabetes/61_19.txt
# Discriminator error:  tensor(0.6028, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1049, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  62
# results/diabetes/62_19.txt
# Discriminator error:  tensor(0.6215, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6189, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  63
# results/diabetes/63_19.txt
# Discriminator error:  tensor(0.5666, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0690, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  64
# results/diabetes/64_19.txt
# Discriminator error:  tensor(0.5767, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5565, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  65
# results/diabetes/65_19.txt
# Discriminator error:  tensor(0.6337, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4468, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  66
# results/diabetes/66_19.txt
# Discriminator error:  tensor(1.1549, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3655, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  67
# results/diabetes/67_19.txt
# Discriminator error:  tensor(2.8690, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2236, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  68
# results/diabetes/68_19.txt
# Discriminator error:  tensor(1.3724, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9237, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  69
# results/diabetes/69_19.txt
# Discriminator error:  tensor(0.1905, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7876, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  70
# results/diabetes/70_19.txt
# Discriminator error:  tensor(0.4853, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1964, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  71
# results/diabetes/71_19.txt
# Discriminator error:  tensor(1.1455, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2957, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  72
# results/diabetes/72_19.txt
# Discriminator error:  tensor(0.7030, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3829, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  73
# results/diabetes/73_19.txt
# Discriminator error:  tensor(0.6364, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7621, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  74
# results/diabetes/74_19.txt
# Discriminator error:  tensor(0.4731, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4191, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  75
# results/diabetes/75_19.txt
# Discriminator error:  tensor(1.5903, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6542, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  76
# results/diabetes/76_19.txt
# Discriminator error:  tensor(1.4638, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9830, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  77
# results/diabetes/77_19.txt
# Discriminator error:  tensor(1.0390, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6717, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  78
# results/diabetes/78_19.txt
# Discriminator error:  tensor(0.8112, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.3359, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  79
# results/diabetes/79_19.txt
# Discriminator error:  tensor(0.6972, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8985, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  80
# results/diabetes/80_19.txt
# Discriminator error:  tensor(0.3064, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9304, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  81
# results/diabetes/81_19.txt
# Discriminator error:  tensor(1.4762, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6350, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  82
# results/diabetes/82_19.txt
# Discriminator error:  tensor(1.5833, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0118, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  83
# results/diabetes/83_19.txt
# Discriminator error:  tensor(0.6104, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9403, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  84
# results/diabetes/84_19.txt
# Discriminator error:  tensor(0.4559, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7614, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  85
# results/diabetes/85_19.txt
# Discriminator error:  tensor(0.4450, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1681, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  86
# results/diabetes/86_19.txt
# Discriminator error:  tensor(1.0249, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7902, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  87
# results/diabetes/87_19.txt
# Discriminator error:  tensor(1.7722, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9252, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  88
# results/diabetes/88_19.txt
# Discriminator error:  tensor(0.3841, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6579, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  89
# results/diabetes/89_19.txt
# Discriminator error:  tensor(0.5862, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6819, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  90
# results/diabetes/90_19.txt
# Discriminator error:  tensor(0.3319, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0358, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  91
# results/diabetes/91_19.txt
# Discriminator error:  tensor(0.6575, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4706, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  92
# results/diabetes/92_19.txt
# Discriminator error:  tensor(1.5848, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4817, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  93
# results/diabetes/93_19.txt
# Discriminator error:  tensor(0.7280, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4164, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  94
# results/diabetes/94_19.txt
# Discriminator error:  tensor(0.9870, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0902, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  95
# results/diabetes/95_19.txt
# Discriminator error:  tensor(1.3483, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5174, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  96
# results/diabetes/96_19.txt
# Discriminator error:  tensor(1.3602, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5028, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  97
# results/diabetes/97_19.txt
# Discriminator error:  tensor(0.6750, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9969, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  98
# results/diabetes/98_19.txt
# Discriminator error:  tensor(0.4432, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2477, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  99
# results/diabetes/99_19.txt
# Discriminator error:  tensor(0.5036, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1863, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  100
# results/diabetes/100_19.txt
# Discriminator error:  tensor(0.5793, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4325, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  101
# results/diabetes/101_19.txt
# Discriminator error:  tensor(0.4430, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1694, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  102
# results/diabetes/102_19.txt
# Discriminator error:  tensor(0.6204, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1017, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  103
# results/diabetes/103_19.txt
# Discriminator error:  tensor(1.2328, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9665, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  104
# results/diabetes/104_19.txt
# Discriminator error:  tensor(0.4905, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5687, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  105
# results/diabetes/105_19.txt
# Discriminator error:  tensor(1.2349, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8486, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  106
# results/diabetes/106_19.txt
# Discriminator error:  tensor(1.2421, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8975, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  107
# results/diabetes/107_19.txt
# Discriminator error:  tensor(0.9624, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3885, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  108
# results/diabetes/108_19.txt
# Discriminator error:  tensor(0.5349, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1618, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  109
# results/diabetes/109_19.txt
# Discriminator error:  tensor(0.7647, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2041, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  110
# results/diabetes/110_19.txt
# Discriminator error:  tensor(0.6413, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0625, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  111
# results/diabetes/111_19.txt
# Discriminator error:  tensor(0.6799, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6079, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  112
# results/diabetes/112_19.txt
# Discriminator error:  tensor(1.0464, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4265, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  113
# results/diabetes/113_19.txt
# Discriminator error:  tensor(0.7024, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0840, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  114
# results/diabetes/114_19.txt
# Discriminator error:  tensor(0.2789, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7492, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  115
# results/diabetes/115_19.txt
# Discriminator error:  tensor(0.6418, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.2338, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  116
# results/diabetes/116_19.txt
# Discriminator error:  tensor(0.6261, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6647, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  117
# results/diabetes/117_19.txt
# Discriminator error:  tensor(1.4121, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.4095, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  118
# results/diabetes/118_19.txt
# Discriminator error:  tensor(0.5887, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6422, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  119
# results/diabetes/119_19.txt
# Discriminator error:  tensor(0.8995, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2532, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  120
# results/diabetes/120_19.txt
# Discriminator error:  tensor(0.9283, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.3126, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  121
# results/diabetes/121_19.txt
# Discriminator error:  tensor(0.6952, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2294, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  122
# results/diabetes/122_19.txt
# Discriminator error:  tensor(0.2632, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3446, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  123
# results/diabetes/123_19.txt
# Discriminator error:  tensor(0.4185, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8946, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  124
# results/diabetes/124_19.txt
# Discriminator error:  tensor(1.1123, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1835, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  125
# results/diabetes/125_19.txt
# Discriminator error:  tensor(0.2220, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.5388, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  126
# results/diabetes/126_19.txt
# Discriminator error:  tensor(1.1879, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6259, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  127
# results/diabetes/127_19.txt
# Discriminator error:  tensor(1.9326, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8416, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  128
# results/diabetes/128_19.txt
# Discriminator error:  tensor(1.1009, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2294, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  129
# results/diabetes/129_19.txt
# Discriminator error:  tensor(0.5653, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6725, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  130
# results/diabetes/130_19.txt
# Discriminator error:  tensor(1.3174, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6172, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  131
# results/diabetes/131_19.txt
# Discriminator error:  tensor(1.1804, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(3.8421, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  132
# results/diabetes/132_19.txt
# Discriminator error:  tensor(1.8506, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(3.3376, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  133
# results/diabetes/133_19.txt
# Discriminator error:  tensor(0.3360, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.6241, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  134
# results/diabetes/134_19.txt
# Discriminator error:  tensor(0.0598, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(3.8172, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  135
# results/diabetes/135_19.txt
# Discriminator error:  tensor(2.3521, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6274, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  136
# results/diabetes/136_19.txt
# Discriminator error:  tensor(0.5608, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.2450, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  137
# results/diabetes/137_19.txt
# Discriminator error:  tensor(0.2101, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1638, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  138
# results/diabetes/138_19.txt
# Discriminator error:  tensor(0.1785, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9257, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  139
# results/diabetes/139_19.txt
# Discriminator error:  tensor(1.6604, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(4.4255, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  140
# results/diabetes/140_19.txt
# Discriminator error:  tensor(0.7543, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7170, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  141
# results/diabetes/141_19.txt
# Discriminator error:  tensor(0.7751, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4473, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  142
# results/diabetes/142_19.txt
# Discriminator error:  tensor(0.1273, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.9431, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  143
# results/diabetes/143_19.txt
# Discriminator error:  tensor(0.1458, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.3436, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  144
# results/diabetes/144_19.txt
# Discriminator error:  tensor(0.3235, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0901, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  145
# results/diabetes/145_19.txt
# Discriminator error:  tensor(0.2892, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7795, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  146
# results/diabetes/146_19.txt
# Discriminator error:  tensor(0.3403, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5287, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  147
# results/diabetes/147_19.txt
# Discriminator error:  tensor(0.6491, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0478, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  148
# results/diabetes/148_19.txt
# Discriminator error:  tensor(1.4379, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4852, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  149
# results/diabetes/149_19.txt
# Discriminator error:  tensor(0.3831, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8957, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  150
# results/diabetes/150_19.txt
# Discriminator error:  tensor(1.1167, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.2055, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  151
# results/diabetes/151_19.txt
# Discriminator error:  tensor(0.6454, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2871, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  152
# results/diabetes/152_19.txt
# Discriminator error:  tensor(0.7628, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2462, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  153
# results/diabetes/153_19.txt
# Discriminator error:  tensor(1.5688, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1035, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  154
# results/diabetes/154_19.txt
# Discriminator error:  tensor(0.5308, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0739, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  155
# results/diabetes/155_19.txt
# Discriminator error:  tensor(0.7627, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2742, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  156
# results/diabetes/156_19.txt
# Discriminator error:  tensor(2.0077, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5521, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  157
# results/diabetes/157_19.txt
# Discriminator error:  tensor(0.3964, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1701, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  158
# results/diabetes/158_19.txt
# Discriminator error:  tensor(0.5996, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4151, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  159
# results/diabetes/159_19.txt
# Discriminator error:  tensor(1.1669, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7250, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  160
# results/diabetes/160_19.txt
# Discriminator error:  tensor(0.7817, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9774, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  161
# results/diabetes/161_19.txt
# Discriminator error:  tensor(1.0576, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8687, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  162
# results/diabetes/162_19.txt
# Discriminator error:  tensor(1.4998, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6797, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  163
# results/diabetes/163_19.txt
# Discriminator error:  tensor(0.5888, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5558, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  164
# results/diabetes/164_19.txt
# Discriminator error:  tensor(1.2298, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6891, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  165
# results/diabetes/165_19.txt
# Discriminator error:  tensor(0.9295, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2126, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  166
# results/diabetes/166_19.txt
# Discriminator error:  tensor(0.7870, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7497, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  167
# results/diabetes/167_19.txt
# Discriminator error:  tensor(0.1182, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0100, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  168
# results/diabetes/168_19.txt
# Discriminator error:  tensor(0.4491, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7495, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  169
# results/diabetes/169_19.txt
# Discriminator error:  tensor(0.7386, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0033, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  170
# results/diabetes/170_19.txt
# Discriminator error:  tensor(0.6073, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3791, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  171
# results/diabetes/171_19.txt
# Discriminator error:  tensor(0.6825, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6060, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  172
# results/diabetes/172_19.txt
# Discriminator error:  tensor(3.2939, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3857, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  173
# results/diabetes/173_19.txt
# Discriminator error:  tensor(1.6256, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8195, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  174
# results/diabetes/174_19.txt
# Discriminator error:  tensor(0.2943, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.6068, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  175
# results/diabetes/175_19.txt
# Discriminator error:  tensor(0.3659, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.5160, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  176
# results/diabetes/176_19.txt
# Discriminator error:  tensor(0.5655, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1445, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  177
# results/diabetes/177_19.txt
# Discriminator error:  tensor(1.5802, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7708, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  178
# results/diabetes/178_19.txt
# Discriminator error:  tensor(0.7026, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9427, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  179
# results/diabetes/179_19.txt
# Discriminator error:  tensor(0.8807, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3268, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  180
# results/diabetes/180_19.txt
# Discriminator error:  tensor(0.5823, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4400, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  181
# results/diabetes/181_19.txt
# Discriminator error:  tensor(0.1523, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.2991, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  182
# results/diabetes/182_19.txt
# Discriminator error:  tensor(0.6887, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.2171, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  183
# results/diabetes/183_19.txt
# Discriminator error:  tensor(1.0674, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6178, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  184
# results/diabetes/184_19.txt
# Discriminator error:  tensor(0.5643, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0999, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  185
# results/diabetes/185_19.txt
# Discriminator error:  tensor(1.1186, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2720, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  186
# results/diabetes/186_19.txt
# Discriminator error:  tensor(0.5047, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9359, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  187
# results/diabetes/187_19.txt
# Discriminator error:  tensor(0.7026, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3684, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  188
# results/diabetes/188_19.txt
# Discriminator error:  tensor(0.6275, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0307, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  189
# results/diabetes/189_19.txt
# Discriminator error:  tensor(0.8748, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0100, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  190
# results/diabetes/190_19.txt
# Discriminator error:  tensor(0.8566, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8617, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  191
# results/diabetes/191_19.txt
# Discriminator error:  tensor(0.5528, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9231, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  192
# results/diabetes/192_19.txt
# Discriminator error:  tensor(0.4847, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5766, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  193
# results/diabetes/193_19.txt
# Discriminator error:  tensor(0.3965, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6150, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  194
# results/diabetes/194_19.txt
# Discriminator error:  tensor(0.3304, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4434, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  195
# results/diabetes/195_19.txt
# Discriminator error:  tensor(0.0828, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3974, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  196
# results/diabetes/196_19.txt
# Discriminator error:  tensor(0.5234, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0179, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  197
# results/diabetes/197_19.txt
# Discriminator error:  tensor(0.3224, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2395, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  198
# results/diabetes/198_19.txt
# Discriminator error:  tensor(0.3695, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9314, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  199
# results/diabetes/199_19.txt
# Discriminator error:  tensor(1.3765, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3039, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  200
# results/diabetes/200_19.txt
# Discriminator error:  tensor(0.8211, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8302, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  201
# results/diabetes/201_19.txt
# Discriminator error:  tensor(0.4680, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9240, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  202
# results/diabetes/202_19.txt
# Discriminator error:  tensor(0.4669, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.2636, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  203
# results/diabetes/203_19.txt
# Discriminator error:  tensor(0.2713, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.5970, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  204
# results/diabetes/204_19.txt
# Discriminator error:  tensor(0.4572, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5698, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  205
# results/diabetes/205_19.txt
# Discriminator error:  tensor(0.2095, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.3424, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  206
# results/diabetes/206_19.txt
# Discriminator error:  tensor(0.7079, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.9826, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  207
# results/diabetes/207_19.txt
# Discriminator error:  tensor(0.5310, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1698, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  208
# results/diabetes/208_19.txt
# Discriminator error:  tensor(0.4295, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8169, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  209
# results/diabetes/209_19.txt
# Discriminator error:  tensor(0.4917, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3816, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  210
# results/diabetes/210_19.txt
# Discriminator error:  tensor(0.4216, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8342, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  211
# results/diabetes/211_19.txt
# Discriminator error:  tensor(1.1438, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0779, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  212
# results/diabetes/212_19.txt
# Discriminator error:  tensor(0.1961, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8317, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  213
# results/diabetes/213_19.txt
# Discriminator error:  tensor(0.7689, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1557, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  214
# results/diabetes/214_19.txt
# Discriminator error:  tensor(0.3526, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4594, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  215
# results/diabetes/215_19.txt
# Discriminator error:  tensor(0.2361, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0774, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  216
# results/diabetes/216_19.txt
# Discriminator error:  tensor(0.3140, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8278, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  217
# results/diabetes/217_19.txt
# Discriminator error:  tensor(0.3822, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.7238, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  218
# results/diabetes/218_19.txt
# Discriminator error:  tensor(0.2651, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(3.3608, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  219
# results/diabetes/219_19.txt
# Discriminator error:  tensor(0.3096, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.3179, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  220
# results/diabetes/220_19.txt
# Discriminator error:  tensor(0.4061, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5373, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  221
# results/diabetes/221_19.txt
# Discriminator error:  tensor(1.0639, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8016, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  222
# results/diabetes/222_19.txt
# Discriminator error:  tensor(1.6697, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9541, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  223
# results/diabetes/223_19.txt
# Discriminator error:  tensor(1.3314, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.9872, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  224
# results/diabetes/224_19.txt
# Discriminator error:  tensor(0.2416, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(3.3629, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  225
# results/diabetes/225_19.txt
# Discriminator error:  tensor(0.6914, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6119, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  226
# results/diabetes/226_19.txt
# Discriminator error:  tensor(0.4073, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0621, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  227
# results/diabetes/227_19.txt
# Discriminator error:  tensor(2.5389, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0908, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  228
# results/diabetes/228_19.txt
# Discriminator error:  tensor(1.1642, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1536, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  229
# results/diabetes/229_19.txt
# Discriminator error:  tensor(0.3736, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0647, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  230
# results/diabetes/230_19.txt
# Discriminator error:  tensor(0.5265, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7437, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  231
# results/diabetes/231_19.txt
# Discriminator error:  tensor(0.1862, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1395, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  232
# results/diabetes/232_19.txt
# Discriminator error:  tensor(0.2831, device='cuda:0', grad_fn=<AddBackward0>)
# ...
# Generator error:  tensor(1.6043, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1424
# results/diabetes/1424_19.txt
# Discriminator error:  tensor(0.4898, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4293, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1425
# results/diabetes/1425_19.txt
# Discriminator error:  tensor(1.2801, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2657, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1426
# results/diabetes/1426_19.txt
# Discriminator error:  tensor(1.0424, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2578, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1427
# results/diabetes/1427_19.txt
# Discriminator error:  tensor(0.5184, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4977, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1428
# results/diabetes/1428_19.txt
# Discriminator error:  tensor(1.0648, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0900, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1429
# results/diabetes/1429_19.txt
# Discriminator error:  tensor(1.3595, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2218, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1430
# results/diabetes/1430_19.txt
# Discriminator error:  tensor(0.8691, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3675, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1431
# results/diabetes/1431_19.txt
# Discriminator error:  tensor(0.5678, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5636, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1432
# results/diabetes/1432_19.txt
# Discriminator error:  tensor(0.8117, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9280, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1433
# results/diabetes/1433_19.txt
# Discriminator error:  tensor(0.9020, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3547, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1434
# results/diabetes/1434_19.txt
# Discriminator error:  tensor(0.6035, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6791, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1435
# results/diabetes/1435_19.txt
# Discriminator error:  tensor(1.1203, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4290, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1436
# results/diabetes/1436_19.txt
# Discriminator error:  tensor(0.8718, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6053, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1437
# results/diabetes/1437_19.txt
# Discriminator error:  tensor(1.3806, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6532, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1438
# results/diabetes/1438_19.txt
# Discriminator error:  tensor(0.8056, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4425, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1439
# results/diabetes/1439_19.txt
# Discriminator error:  tensor(0.9132, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2351, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1440
# results/diabetes/1440_19.txt
# Discriminator error:  tensor(0.9542, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3604, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1441
# results/diabetes/1441_19.txt
# Discriminator error:  tensor(0.8898, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1626, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1442
# results/diabetes/1442_19.txt
# Discriminator error:  tensor(0.8809, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1536, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1443
# results/diabetes/1443_19.txt
# Discriminator error:  tensor(1.0588, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9351, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1444
# results/diabetes/1444_19.txt
# Discriminator error:  tensor(0.4701, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2459, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1445
# results/diabetes/1445_19.txt
# Discriminator error:  tensor(0.6155, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3978, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1446
# results/diabetes/1446_19.txt
# Discriminator error:  tensor(0.9564, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1157, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1447
# results/diabetes/1447_19.txt
# Discriminator error:  tensor(0.6796, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0755, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1448
# results/diabetes/1448_19.txt
# Discriminator error:  tensor(0.4891, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1680, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1449
# results/diabetes/1449_19.txt
# Discriminator error:  tensor(0.6828, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5530, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1450
# results/diabetes/1450_19.txt
# Discriminator error:  tensor(1.0390, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0835, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1451
# results/diabetes/1451_19.txt
# Discriminator error:  tensor(1.2813, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4396, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1452
# results/diabetes/1452_19.txt
# Discriminator error:  tensor(0.6503, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0290, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1453
# results/diabetes/1453_19.txt
# Discriminator error:  tensor(0.9072, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3970, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1454
# results/diabetes/1454_19.txt
# Discriminator error:  tensor(0.8349, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0438, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1455
# results/diabetes/1455_19.txt
# Discriminator error:  tensor(0.9916, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1456
# results/diabetes/1456_19.txt
# Discriminator error:  tensor(0.9583, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9999, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1457
# results/diabetes/1457_19.txt
# Discriminator error:  tensor(0.4295, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2445, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1458
# results/diabetes/1458_19.txt
# Discriminator error:  tensor(1.0619, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4497, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1459
# results/diabetes/1459_19.txt
# Discriminator error:  tensor(1.0759, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2339, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1460
# results/diabetes/1460_19.txt
# Discriminator error:  tensor(0.8981, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0391, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1461
# results/diabetes/1461_19.txt
# Discriminator error:  tensor(1.0176, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3463, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1462
# results/diabetes/1462_19.txt
# Discriminator error:  tensor(0.7036, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2511, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1463
# results/diabetes/1463_19.txt
# Discriminator error:  tensor(1.1540, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3858, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1464
# results/diabetes/1464_19.txt
# Discriminator error:  tensor(0.5684, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4316, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1465
# results/diabetes/1465_19.txt
# Discriminator error:  tensor(1.1633, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2898, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1466
# results/diabetes/1466_19.txt
# Discriminator error:  tensor(0.6392, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2061, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1467
# results/diabetes/1467_19.txt
# Discriminator error:  tensor(1.1246, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6259, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1468
# results/diabetes/1468_19.txt
# Discriminator error:  tensor(0.7191, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6249, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1469
# results/diabetes/1469_19.txt
# Discriminator error:  tensor(0.7998, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0018, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1470
# results/diabetes/1470_19.txt
# Discriminator error:  tensor(0.9202, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0793, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1471
# results/diabetes/1471_19.txt
# Discriminator error:  tensor(0.6177, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3421, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1472
# results/diabetes/1472_19.txt
# Discriminator error:  tensor(0.6642, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1278, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1473
# results/diabetes/1473_19.txt
# Discriminator error:  tensor(1.0172, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1516, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1474
# results/diabetes/1474_19.txt
# Discriminator error:  tensor(0.8319, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3747, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1475
# results/diabetes/1475_19.txt
# Discriminator error:  tensor(0.9025, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2416, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1476
# results/diabetes/1476_19.txt
# Discriminator error:  tensor(0.8798, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9942, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1477
# results/diabetes/1477_19.txt
# Discriminator error:  tensor(0.9824, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2775, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1478
# results/diabetes/1478_19.txt
# Discriminator error:  tensor(0.8297, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5434, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1479
# results/diabetes/1479_19.txt
# Discriminator error:  tensor(1.5334, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3677, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1480
# results/diabetes/1480_19.txt
# Discriminator error:  tensor(0.8441, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0855, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1481
# results/diabetes/1481_19.txt
# Discriminator error:  tensor(1.2552, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6706, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1482
# results/diabetes/1482_19.txt
# Discriminator error:  tensor(1.4161, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4450, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1483
# results/diabetes/1483_19.txt
# Discriminator error:  tensor(0.9860, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1928, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1484
# results/diabetes/1484_19.txt
# Discriminator error:  tensor(1.1121, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3778, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1485
# results/diabetes/1485_19.txt
# Discriminator error:  tensor(0.5573, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2276, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1486
# results/diabetes/1486_19.txt
# Discriminator error:  tensor(0.5735, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7483, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1487
# results/diabetes/1487_19.txt
# Discriminator error:  tensor(0.8000, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2366, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1488
# results/diabetes/1488_19.txt
# Discriminator error:  tensor(1.1523, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4686, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1489
# results/diabetes/1489_19.txt
# Discriminator error:  tensor(0.5230, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2982, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1490
# results/diabetes/1490_19.txt
# Discriminator error:  tensor(0.6685, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4695, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1491
# results/diabetes/1491_19.txt
# Discriminator error:  tensor(0.6841, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9465, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1492
# results/diabetes/1492_19.txt
# Discriminator error:  tensor(1.4503, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3656, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1493
# results/diabetes/1493_19.txt
# Discriminator error:  tensor(0.9875, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0196, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1494
# results/diabetes/1494_19.txt
# Discriminator error:  tensor(1.0976, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6379, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1495
# results/diabetes/1495_19.txt
# Discriminator error:  tensor(0.9236, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0595, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1496
# results/diabetes/1496_19.txt
# Discriminator error:  tensor(0.9260, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8078, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1497
# results/diabetes/1497_19.txt
# Discriminator error:  tensor(1.2158, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2855, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1498
# results/diabetes/1498_19.txt
# Discriminator error:  tensor(0.5688, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3131, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1499
# results/diabetes/1499_19.txt
# Discriminator error:  tensor(0.6963, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1398, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)

# %%
results_dir = f"models/{file_name.split('/')[-1].split('.')[0]}"
os.mkdir(results_dir)

# %%
print(epoch)
torch.save({
            'epoch': epoch,
            'model_state_dict': generator.state_dict(),
            'optimizer_state_dict': g_optimizer.state_dict(),
            'model_attributes': {'out_features': dataAtts.class_len},
            'loss': loss
            # }, "models/generator" + dataAtts.fname + "_" + str(epoch) + ".pt")
            }, results_dir + "/generator" + dataAtts.fname + "_" + str(epoch) + ".pt")

torch.save({
            'epoch': epoch,
            'model_state_dict': discriminator.state_dict(),
            'optimizer_state_dict': d_optimizer.state_dict(),
            'loss': loss
            # }, "models/discriminator" + dataAtts.fname + "_" + str(epoch) + ".pt")
            }, results_dir + "/discriminator" + dataAtts.fname + "_" + str(epoch) + ".pt")
# Out:
# 1499

# %%
plt.plot(d_error_plt, 'b')
plt.plot(g_error_plt, 'r')
filename = "results/" + dataAtts.fname + "/" + "error_growth.txt"
file = open(filename, "w")
file.write("Discriminator error: " + str(d_error_plt) + "\n")
file.write("\n\n\n")
file.write("Generator error: " + str(g_error_plt) + "\n")
file.close()

plt.savefig('images/'+ dataAtts.fname + "/"+ 'error.png')
plt.show()
plt.clf()
