# %%
import torch
import pandas as pd
from torch import nn, optim
from torch.autograd.variable import Variable
from torchvision import transforms, datasets
from data_treatment import DataSetGRG, DataAtts
from discriminator import *
from generator import *
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt
import glob

# %%
# Noise
def noise(size):
    n = Variable(torch.randn(size, 100))
    if torch.cuda.is_available(): 
        return n.cuda() 
    return n

# %%
files_dropdown = widgets.Dropdown(
    # options=glob.glob("original_data/*.csv"),
    options=glob.glob("grg_data/*.csv"),
    description='File:',
    # value = 'original_data/diabetes_escalonated.csv',
    disabled=False,
)
display(files_dropdown)
# Out:
# Dropdown(description='File:', options=('grg_data/diabetes-t5_TrainUpsampledPatient.csv', 'grg_data/diabetes-t2…

# %%
file_name=files_dropdown.value
dataAtts = DataAtts(file_name)

# %%
def train_generator(optimizer, fake_data):
    # 2. Train Generator
    # Reset gradients
    optimizer.zero_grad()
    # Sample noise and generate fake data
    prediction = discriminator(fake_data)
    # Calculate error and backpropagate
    error = loss(prediction, real_data_target(prediction.size(0)))
    error.backward()
    # Update weights with gradients
    optimizer.step()
    # Return error
    return error

def train_discriminator(optimizer, real_data, fake_data):
    # Reset gradients
    optimizer.zero_grad()
    
    # 1.1 Train on Real Data
    prediction_real = discriminator(real_data)
    # Calculate error and backpropagate
    error_real = loss(prediction_real, real_data_target(real_data.size(0)))
    error_real.backward()

    # 1.2 Train on Fake Data
    prediction_fake = discriminator(fake_data)
    # Calculate error and backpropagate
    error_fake = loss(prediction_fake, fake_data_target(real_data.size(0)))
    error_fake.backward()
    
    # 1.3 Update weights with gradients
    optimizer.step()
    
    # Return error
    return error_real + error_fake, prediction_real, prediction_fake

# %%
def real_data_target(size):
    '''
    Tensor containing ones, with shape = size
    '''
    data = Variable(torch.ones(size, 1))
    if torch.cuda.is_available(): return data.cuda()
    return data

def fake_data_target(size):
    '''
    Tensor containing zeros, with shape = size
    '''
    data = Variable(torch.zeros(size, 1))
    if torch.cuda.is_available(): return data.cuda()
    return data

# %%
lr = 0.0002
#lr= 0.0002
batch_size = 5
num_epochs = 106
print_interval = 10
loss = nn.BCELoss()

# %%
discriminator = DiscriminatorNet(dataAtts.class_len)
generator = GeneratorNet(dataAtts.class_len)
if torch.cuda.is_available():
    discriminator.cuda()
    generator.cuda()
d_optimizer = optim.Adam(discriminator.parameters(), lr=lr)
g_optimizer = optim.Adam(generator.parameters(), lr=lr)

# %%
d_error_plt = [0]
g_error_plt = [0]

generated_points = []

# %%
database = DataSetGRG(csv_file=file_name, root_dir=".")

data_loader = torch.utils.data.DataLoader(database, batch_size=batch_size, shuffle=True)
num_batches = len(data_loader)

# %%
for epoch in range(num_epochs):
    print("Epoch ", epoch)

    for n_batch, real_batch in enumerate(data_loader):
        # 1. Train Discriminator
        real_data = Variable(real_batch).float()
        if torch.cuda.is_available(): 
            real_data = real_data.cuda()
        # Generate fake data
        fake_data = generator(noise(real_data.size(0))).detach()
        # Train D
        d_error, d_pred_real, d_pred_fake = train_discriminator(d_optimizer,
                                                                real_data, fake_data)

        # 2. Train Generator
        # Generate fake data
        fake_data = generator(noise(real_batch.size(0)))
        generated_points.append(fake_data)
        # Train G
        g_error = train_generator(g_optimizer, fake_data)

        # Display Progress

        #if (n_batch) % print_interval == 0:
    filename = "results/" + dataAtts.fname + "/" + str(epoch) + "_" + str(n_batch) + ".txt"
    print(filename)
    file = open(filename, "w")
    print("Discriminator error: ", d_error)
    print("Generator error: ", g_error)
    print("")

    file.write("Discriminator error: " + str(d_error) + "\n")
    file.write("Generator error: " + str(g_error) + "\n")
    file.write("Points: " + str(fake_data) + "\n\n\n")

    # d_error_plt.append(d_error)
    # g_error_plt.append(g_error)
    d_error_plt.append(d_error.detach().cpu().numpy())
    g_error_plt.append(g_error.detach().cpu().numpy())
        #     #display.clear_output(True)
        #     # Display Images
        #     test_images = generator(test_noise).data.cpu()
        #     logger.log_images(test_images, num_test_samples, epoch, n_batch, num_batches);
        #     # Display status Logs
        #     #logger.display_status(epoch, num_epochs, n_batch, num_batches, d_error, g_error, d_pred_real, d_pred_fake)
        # # Model Checkpoints
# Out:
# Epoch  0
# results/diabetes/0_138.txt
# Discriminator error:  tensor(1.7700, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.6906, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1
# results/diabetes/1_138.txt
# Discriminator error:  tensor(1.8093, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.2124, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  2
# results/diabetes/2_138.txt
# Discriminator error:  tensor(0.3590, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4027, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  3
# results/diabetes/3_138.txt
# Discriminator error:  tensor(1.1796, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5502, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  4
# results/diabetes/4_138.txt
# Discriminator error:  tensor(1.2543, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0604, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  5
# results/diabetes/5_138.txt
# Discriminator error:  tensor(1.3395, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6883, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  6
# results/diabetes/6_138.txt
# Discriminator error:  tensor(1.7127, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.2790, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  7
# results/diabetes/7_138.txt
# Discriminator error:  tensor(1.3066, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0696, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  8
# results/diabetes/8_138.txt
# Discriminator error:  tensor(0.4376, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0664, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  9
# results/diabetes/9_138.txt
# Discriminator error:  tensor(0.5754, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1787, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  10
# results/diabetes/10_138.txt
# Discriminator error:  tensor(0.7837, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8877, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  11
# results/diabetes/11_138.txt
# Discriminator error:  tensor(0.3222, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8416, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  12
# results/diabetes/12_138.txt
# Discriminator error:  tensor(0.7070, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6841, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  13
# results/diabetes/13_138.txt
# Discriminator error:  tensor(0.2320, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6039, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  14
# results/diabetes/14_138.txt
# Discriminator error:  tensor(0.2758, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8993, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  15
# results/diabetes/15_138.txt
# Discriminator error:  tensor(1.1728, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0514, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  16
# results/diabetes/16_138.txt
# Discriminator error:  tensor(0.2479, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3645, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  17
# results/diabetes/17_138.txt
# Discriminator error:  tensor(0.8578, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4667, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  18
# results/diabetes/18_138.txt
# Discriminator error:  tensor(1.5449, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0648, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  19
# results/diabetes/19_138.txt
# Discriminator error:  tensor(0.4645, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3910, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  20
# results/diabetes/20_138.txt
# Discriminator error:  tensor(1.7380, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5816, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  21
# results/diabetes/21_138.txt
# Discriminator error:  tensor(1.0879, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9275, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  22
# results/diabetes/22_138.txt
# Discriminator error:  tensor(1.9133, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9655, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  23
# results/diabetes/23_138.txt
# Discriminator error:  tensor(1.2995, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1542, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  24
# results/diabetes/24_138.txt
# Discriminator error:  tensor(0.9869, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6632, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  25
# results/diabetes/25_138.txt
# Discriminator error:  tensor(1.0820, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6285, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  26
# results/diabetes/26_138.txt
# Discriminator error:  tensor(0.9013, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8940, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  27
# results/diabetes/27_138.txt
# Discriminator error:  tensor(2.0479, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9069, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  28
# results/diabetes/28_138.txt
# Discriminator error:  tensor(1.0224, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7483, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  29
# results/diabetes/29_138.txt
# Discriminator error:  tensor(0.6367, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6240, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  30
# results/diabetes/30_138.txt
# Discriminator error:  tensor(0.7898, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9053, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  31
# results/diabetes/31_138.txt
# Discriminator error:  tensor(1.0992, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3709, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  32
# results/diabetes/32_138.txt
# Discriminator error:  tensor(1.1812, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6429, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  33
# results/diabetes/33_138.txt
# Discriminator error:  tensor(1.1991, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9334, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  34
# results/diabetes/34_138.txt
# Discriminator error:  tensor(0.8821, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1431, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  35
# results/diabetes/35_138.txt
# Discriminator error:  tensor(0.8925, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2406, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  36
# results/diabetes/36_138.txt
# Discriminator error:  tensor(1.6027, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0589, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  37
# results/diabetes/37_138.txt
# Discriminator error:  tensor(1.5453, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3121, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  38
# results/diabetes/38_138.txt
# Discriminator error:  tensor(1.1763, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6753, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  39
# results/diabetes/39_138.txt
# Discriminator error:  tensor(0.8366, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7983, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  40
# results/diabetes/40_138.txt
# Discriminator error:  tensor(1.1463, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3030, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  41
# results/diabetes/41_138.txt
# Discriminator error:  tensor(1.6775, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4825, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  42
# results/diabetes/42_138.txt
# Discriminator error:  tensor(0.8777, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1465, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  43
# results/diabetes/43_138.txt
# Discriminator error:  tensor(2.0060, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1307, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  44
# results/diabetes/44_138.txt
# Discriminator error:  tensor(1.5093, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6704, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  45
# results/diabetes/45_138.txt
# Discriminator error:  tensor(1.2236, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6722, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  46
# results/diabetes/46_138.txt
# Discriminator error:  tensor(1.6617, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8289, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  47
# results/diabetes/47_138.txt
# Discriminator error:  tensor(0.8799, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7251, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  48
# results/diabetes/48_138.txt
# Discriminator error:  tensor(1.1712, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8609, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  49
# results/diabetes/49_138.txt
# Discriminator error:  tensor(1.4697, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8104, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  50
# results/diabetes/50_138.txt
# Discriminator error:  tensor(0.9697, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7379, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  51
# results/diabetes/51_138.txt
# Discriminator error:  tensor(2.9773, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8469, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  52
# results/diabetes/52_138.txt
# Discriminator error:  tensor(0.7836, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8225, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  53
# results/diabetes/53_138.txt
# Discriminator error:  tensor(0.9154, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8233, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  54
# results/diabetes/54_138.txt
# Discriminator error:  tensor(1.1396, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9232, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  55
# results/diabetes/55_138.txt
# Discriminator error:  tensor(1.4247, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1809, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  56
# results/diabetes/56_138.txt
# Discriminator error:  tensor(1.4153, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9723, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  57
# results/diabetes/57_138.txt
# Discriminator error:  tensor(1.3214, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0677, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  58
# results/diabetes/58_138.txt
# Discriminator error:  tensor(1.3093, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7454, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  59
# results/diabetes/59_138.txt
# Discriminator error:  tensor(1.7425, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9185, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  60
# results/diabetes/60_138.txt
# Discriminator error:  tensor(0.9772, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9010, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  61
# results/diabetes/61_138.txt
# Discriminator error:  tensor(0.9900, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9985, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  62
# results/diabetes/62_138.txt
# Discriminator error:  tensor(2.0961, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9125, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  63
# results/diabetes/63_138.txt
# Discriminator error:  tensor(1.9517, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8584, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  64
# results/diabetes/64_138.txt
# Discriminator error:  tensor(1.2583, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7860, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  65
# results/diabetes/65_138.txt
# Discriminator error:  tensor(1.3092, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6237, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  66
# results/diabetes/66_138.txt
# Discriminator error:  tensor(1.8493, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3624, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  67
# results/diabetes/67_138.txt
# Discriminator error:  tensor(1.3999, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0200, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  68
# results/diabetes/68_138.txt
# Discriminator error:  tensor(1.8115, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5342, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  69
# results/diabetes/69_138.txt
# Discriminator error:  tensor(0.8933, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6351, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  70
# results/diabetes/70_138.txt
# Discriminator error:  tensor(1.3367, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9356, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  71
# results/diabetes/71_138.txt
# Discriminator error:  tensor(1.1437, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8379, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  72
# results/diabetes/72_138.txt
# Discriminator error:  tensor(1.3885, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7386, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  73
# results/diabetes/73_138.txt
# Discriminator error:  tensor(1.4752, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8641, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  74
# results/diabetes/74_138.txt
# Discriminator error:  tensor(1.3950, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6667, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  75
# results/diabetes/75_138.txt
# Discriminator error:  tensor(1.1680, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6485, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  76
# results/diabetes/76_138.txt
# Discriminator error:  tensor(1.2585, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2212, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  77
# results/diabetes/77_138.txt
# Discriminator error:  tensor(1.3066, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6088, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  78
# results/diabetes/78_138.txt
# Discriminator error:  tensor(1.3104, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1841, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  79
# results/diabetes/79_138.txt
# Discriminator error:  tensor(1.1309, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9924, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  80
# results/diabetes/80_138.txt
# Discriminator error:  tensor(1.0758, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9815, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  81
# results/diabetes/81_138.txt
# Discriminator error:  tensor(1.3671, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7059, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  82
# results/diabetes/82_138.txt
# Discriminator error:  tensor(1.1484, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7449, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  83
# results/diabetes/83_138.txt
# Discriminator error:  tensor(1.7447, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6830, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  84
# results/diabetes/84_138.txt
# Discriminator error:  tensor(1.6876, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5088, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  85
# results/diabetes/85_138.txt
# Discriminator error:  tensor(1.0463, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6919, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  86
# results/diabetes/86_138.txt
# Discriminator error:  tensor(1.3601, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9444, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  87
# results/diabetes/87_138.txt
# Discriminator error:  tensor(1.1523, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8362, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  88
# results/diabetes/88_138.txt
# Discriminator error:  tensor(1.1033, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5412, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  89
# results/diabetes/89_138.txt
# Discriminator error:  tensor(0.9056, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1029, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  90
# results/diabetes/90_138.txt
# Discriminator error:  tensor(1.2548, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9188, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  91
# results/diabetes/91_138.txt
# Discriminator error:  tensor(1.0421, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7688, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  92
# results/diabetes/92_138.txt
# Discriminator error:  tensor(0.9935, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0240, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  93
# results/diabetes/93_138.txt
# Discriminator error:  tensor(1.1014, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1914, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  94
# results/diabetes/94_138.txt
# Discriminator error:  tensor(1.6892, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9979, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  95
# results/diabetes/95_138.txt
# Discriminator error:  tensor(1.0806, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4959, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  96
# results/diabetes/96_138.txt
# Discriminator error:  tensor(1.1209, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8097, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  97
# results/diabetes/97_138.txt
# Discriminator error:  tensor(1.3227, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6618, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  98
# results/diabetes/98_138.txt
# Discriminator error:  tensor(2.1373, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0280, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  99
# results/diabetes/99_138.txt
# Discriminator error:  tensor(1.1517, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9247, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  100
# results/diabetes/100_138.txt
# Discriminator error:  tensor(1.3652, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9556, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  101
# results/diabetes/101_138.txt
# Discriminator error:  tensor(1.3505, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9378, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  102
# results/diabetes/102_138.txt
# Discriminator error:  tensor(1.2015, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4320, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  103
# results/diabetes/103_138.txt
# Discriminator error:  tensor(1.6341, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0865, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  104
# results/diabetes/104_138.txt
# Discriminator error:  tensor(1.8143, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6329, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  105
# results/diabetes/105_138.txt
# Discriminator error:  tensor(1.1852, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7068, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)

# %%
results_dir = f"models/{file_name.split('/')[-1].split('.')[0]}"
os.mkdir(results_dir)

# %%
print(epoch)
torch.save({
            'epoch': epoch,
            'model_state_dict': generator.state_dict(),
            'optimizer_state_dict': g_optimizer.state_dict(),
            'model_attributes': {'out_features': dataAtts.class_len},
            'loss': loss
            # }, "models/generator" + dataAtts.fname + "_" + str(epoch) + ".pt")
            }, results_dir + "/generator" + dataAtts.fname + "_" + str(epoch) + ".pt")

torch.save({
            'epoch': epoch,
            'model_state_dict': discriminator.state_dict(),
            'optimizer_state_dict': d_optimizer.state_dict(),
            'loss': loss
            # }, "models/discriminator" + dataAtts.fname + "_" + str(epoch) + ".pt")
            }, results_dir + "/discriminator" + dataAtts.fname + "_" + str(epoch) + ".pt")
# Out:
# 105

# %%
plt.plot(d_error_plt, 'b')
plt.plot(g_error_plt, 'r')
filename = "results/" + dataAtts.fname + "/" + "error_growth.txt"
file = open(filename, "w")
file.write("Discriminator error: " + str(d_error_plt) + "\n")
file.write("\n\n\n")
file.write("Generator error: " + str(g_error_plt) + "\n")
file.close()

plt.savefig('images/'+ dataAtts.fname + "/"+ 'error.png')
plt.show()
plt.clf()
