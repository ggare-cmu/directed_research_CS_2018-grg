# %%
import torch
import pandas as pd
from torch import nn, optim
from torch.autograd.variable import Variable
from torchvision import transforms, datasets
from data_treatment import DataSetGRG, DataAtts
from discriminator import *
from generator import *
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt
import glob

# %%
# Noise
def noise(size):
    n = Variable(torch.randn(size, 100))
    if torch.cuda.is_available(): 
        return n.cuda() 
    return n

# %%
files_dropdown = widgets.Dropdown(
    # options=glob.glob("original_data/*.csv"),
    options=glob.glob("grg_data/*.csv"),
    description='File:',
    # value = 'original_data/diabetes_escalonated.csv',
    disabled=False,
)
display(files_dropdown)
# Out:
# Dropdown(description='File:', options=('grg_data/diabetes-small3_TrainUpsampledPatient.csv', 'grg_data/diabete…

# %%
file_name=files_dropdown.value
dataAtts = DataAtts(file_name)

# %%
def train_generator(optimizer, fake_data):
    # 2. Train Generator
    # Reset gradients
    optimizer.zero_grad()
    # Sample noise and generate fake data
    prediction = discriminator(fake_data)
    # Calculate error and backpropagate
    error = loss(prediction, real_data_target(prediction.size(0)))
    error.backward()
    # Update weights with gradients
    optimizer.step()
    # Return error
    return error

def train_discriminator(optimizer, real_data, fake_data):
    # Reset gradients
    optimizer.zero_grad()
    
    # 1.1 Train on Real Data
    prediction_real = discriminator(real_data)
    # Calculate error and backpropagate
    error_real = loss(prediction_real, real_data_target(real_data.size(0)))
    error_real.backward()

    # 1.2 Train on Fake Data
    prediction_fake = discriminator(fake_data)
    # Calculate error and backpropagate
    error_fake = loss(prediction_fake, fake_data_target(real_data.size(0)))
    error_fake.backward()
    
    # 1.3 Update weights with gradients
    optimizer.step()
    
    # Return error
    return error_real + error_fake, prediction_real, prediction_fake

# %%
def real_data_target(size):
    '''
    Tensor containing ones, with shape = size
    '''
    data = Variable(torch.ones(size, 1))
    if torch.cuda.is_available(): return data.cuda()
    return data

def fake_data_target(size):
    '''
    Tensor containing zeros, with shape = size
    '''
    data = Variable(torch.zeros(size, 1))
    if torch.cuda.is_available(): return data.cuda()
    return data

# %%
lr = 0.0002
#lr= 0.0002
batch_size = 5
# num_epochs = 106
num_epochs = 1500
print_interval = 10
loss = nn.BCELoss()

# %%
# discriminator = DiscriminatorNet(dataAtts.class_len)
discriminator = DiscriminatorNet(dataAtts.class_len,  hidden_layers=[512, 256])
generator = GeneratorNet(dataAtts.class_len,  hidden_layers=[512, 256])
if torch.cuda.is_available():
    discriminator.cuda()
    generator.cuda()
d_optimizer = optim.Adam(discriminator.parameters(), lr=lr)
g_optimizer = optim.Adam(generator.parameters(), lr=lr)

# %%
d_error_plt = [0]
g_error_plt = [0]

generated_points = []

# %%
database = DataSetGRG(csv_file=file_name, root_dir=".")

data_loader = torch.utils.data.DataLoader(database, batch_size=batch_size, shuffle=True)
num_batches = len(data_loader)

# %%
for epoch in range(num_epochs):
    print("Epoch ", epoch)

    for n_batch, real_batch in enumerate(data_loader):
        # 1. Train Discriminator
        real_data = Variable(real_batch).float()
        if torch.cuda.is_available(): 
            real_data = real_data.cuda()
        # Generate fake data
        fake_data = generator(noise(real_data.size(0))).detach()
        # Train D
        d_error, d_pred_real, d_pred_fake = train_discriminator(d_optimizer,
                                                                real_data, fake_data)

        # 2. Train Generator
        # Generate fake data
        fake_data = generator(noise(real_batch.size(0)))
        generated_points.append(fake_data)
        # Train G
        g_error = train_generator(g_optimizer, fake_data)

        # Display Progress

        #if (n_batch) % print_interval == 0:
    filename = "results/" + dataAtts.fname + "/" + str(epoch) + "_" + str(n_batch) + ".txt"
    print(filename)
    file = open(filename, "w")
    print("Discriminator error: ", d_error)
    print("Generator error: ", g_error)
    print("")

    file.write("Discriminator error: " + str(d_error) + "\n")
    file.write("Generator error: " + str(g_error) + "\n")
    file.write("Points: " + str(fake_data) + "\n\n\n")

    # d_error_plt.append(d_error)
    # g_error_plt.append(g_error)
    d_error_plt.append(d_error.detach().cpu().numpy())
    g_error_plt.append(g_error.detach().cpu().numpy())
        #     #display.clear_output(True)
        #     # Display Images
        #     test_images = generator(test_noise).data.cpu()
        #     logger.log_images(test_images, num_test_samples, epoch, n_batch, num_batches);
        #     # Display status Logs
        #     #logger.display_status(epoch, num_epochs, n_batch, num_batches, d_error, g_error, d_pred_real, d_pred_fake)
        # # Model Checkpoints
# Out:
# Epoch  0
# results/diabetes/0_19.txt
# Discriminator error:  tensor(0.7282, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6812, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1
# results/diabetes/1_19.txt
# Discriminator error:  tensor(0.6861, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7091, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  2
# results/diabetes/2_19.txt
# Discriminator error:  tensor(0.8189, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5966, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  3
# results/diabetes/3_19.txt
# Discriminator error:  tensor(0.9076, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.3945, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  4
# results/diabetes/4_19.txt
# Discriminator error:  tensor(0.7249, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7285, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  5
# results/diabetes/5_19.txt
# Discriminator error:  tensor(0.9048, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5856, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  6
# results/diabetes/6_19.txt
# Discriminator error:  tensor(2.1182, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.3037, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  7
# results/diabetes/7_19.txt
# Discriminator error:  tensor(1.0806, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4585, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  8
# results/diabetes/8_19.txt
# Discriminator error:  tensor(1.0804, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7048, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  9
# results/diabetes/9_19.txt
# Discriminator error:  tensor(0.6450, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3286, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  10
# results/diabetes/10_19.txt
# Discriminator error:  tensor(1.0009, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5466, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  11
# results/diabetes/11_19.txt
# Discriminator error:  tensor(0.9485, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6660, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  12
# results/diabetes/12_19.txt
# Discriminator error:  tensor(1.7474, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.2316, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  13
# results/diabetes/13_19.txt
# Discriminator error:  tensor(1.5472, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2459, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  14
# results/diabetes/14_19.txt
# Discriminator error:  tensor(1.8456, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5250, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  15
# results/diabetes/15_19.txt
# Discriminator error:  tensor(0.7971, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2970, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  16
# results/diabetes/16_19.txt
# Discriminator error:  tensor(0.5767, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.3863, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  17
# results/diabetes/17_19.txt
# Discriminator error:  tensor(0.4054, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8805, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  18
# results/diabetes/18_19.txt
# Discriminator error:  tensor(0.8097, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6962, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  19
# results/diabetes/19_19.txt
# Discriminator error:  tensor(0.9383, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1206, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  20
# results/diabetes/20_19.txt
# Discriminator error:  tensor(1.8157, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9055, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  21
# results/diabetes/21_19.txt
# Discriminator error:  tensor(1.4184, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3960, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  22
# results/diabetes/22_19.txt
# Discriminator error:  tensor(1.1516, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5596, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  23
# results/diabetes/23_19.txt
# Discriminator error:  tensor(0.6044, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2243, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  24
# results/diabetes/24_19.txt
# Discriminator error:  tensor(0.8644, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8094, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  25
# results/diabetes/25_19.txt
# Discriminator error:  tensor(1.3297, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5069, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  26
# results/diabetes/26_19.txt
# Discriminator error:  tensor(0.8570, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4489, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  27
# results/diabetes/27_19.txt
# Discriminator error:  tensor(0.6201, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6972, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  28
# results/diabetes/28_19.txt
# Discriminator error:  tensor(1.0602, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2555, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  29
# results/diabetes/29_19.txt
# Discriminator error:  tensor(1.5747, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5279, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  30
# results/diabetes/30_19.txt
# Discriminator error:  tensor(0.2893, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1186, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  31
# results/diabetes/31_19.txt
# Discriminator error:  tensor(0.3134, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4853, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  32
# results/diabetes/32_19.txt
# Discriminator error:  tensor(0.9906, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7923, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  33
# results/diabetes/33_19.txt
# Discriminator error:  tensor(0.7331, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4134, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  34
# results/diabetes/34_19.txt
# Discriminator error:  tensor(0.3234, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5720, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  35
# results/diabetes/35_19.txt
# Discriminator error:  tensor(1.6998, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9069, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  36
# results/diabetes/36_19.txt
# Discriminator error:  tensor(0.4680, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1902, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  37
# results/diabetes/37_19.txt
# Discriminator error:  tensor(2.5750, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0371, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  38
# results/diabetes/38_19.txt
# Discriminator error:  tensor(0.5091, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2903, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  39
# results/diabetes/39_19.txt
# Discriminator error:  tensor(0.6804, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2953, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  40
# results/diabetes/40_19.txt
# Discriminator error:  tensor(1.0465, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8048, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  41
# results/diabetes/41_19.txt
# Discriminator error:  tensor(0.6727, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1758, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  42
# results/diabetes/42_19.txt
# Discriminator error:  tensor(0.5404, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9468, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  43
# results/diabetes/43_19.txt
# Discriminator error:  tensor(0.3664, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.5127, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  44
# results/diabetes/44_19.txt
# Discriminator error:  tensor(0.3847, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8100, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  45
# results/diabetes/45_19.txt
# Discriminator error:  tensor(0.6470, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7138, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  46
# results/diabetes/46_19.txt
# Discriminator error:  tensor(0.7106, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7122, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  47
# results/diabetes/47_19.txt
# Discriminator error:  tensor(0.3401, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1053, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  48
# results/diabetes/48_19.txt
# Discriminator error:  tensor(1.2947, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6551, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  49
# results/diabetes/49_19.txt
# Discriminator error:  tensor(0.2274, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8098, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  50
# results/diabetes/50_19.txt
# Discriminator error:  tensor(3.8448, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6531, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  51
# results/diabetes/51_19.txt
# Discriminator error:  tensor(1.1505, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7337, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  52
# results/diabetes/52_19.txt
# Discriminator error:  tensor(0.3506, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6161, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  53
# results/diabetes/53_19.txt
# Discriminator error:  tensor(0.7939, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.3350, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  54
# results/diabetes/54_19.txt
# Discriminator error:  tensor(0.1822, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2116, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  55
# results/diabetes/55_19.txt
# Discriminator error:  tensor(0.2966, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6473, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  56
# results/diabetes/56_19.txt
# Discriminator error:  tensor(0.7672, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0734, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  57
# results/diabetes/57_19.txt
# Discriminator error:  tensor(0.6691, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8816, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  58
# results/diabetes/58_19.txt
# Discriminator error:  tensor(0.3390, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1966, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  59
# results/diabetes/59_19.txt
# Discriminator error:  tensor(0.6027, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9167, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  60
# results/diabetes/60_19.txt
# Discriminator error:  tensor(0.9822, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4058, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  61
# results/diabetes/61_19.txt
# Discriminator error:  tensor(1.3125, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1041, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  62
# results/diabetes/62_19.txt
# Discriminator error:  tensor(0.8869, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9976, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  63
# results/diabetes/63_19.txt
# Discriminator error:  tensor(1.9483, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2113, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  64
# results/diabetes/64_19.txt
# Discriminator error:  tensor(0.8908, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0926, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  65
# results/diabetes/65_19.txt
# Discriminator error:  tensor(0.9047, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5008, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  66
# results/diabetes/66_19.txt
# Discriminator error:  tensor(0.9947, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1699, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  67
# results/diabetes/67_19.txt
# Discriminator error:  tensor(1.7567, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8451, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  68
# results/diabetes/68_19.txt
# Discriminator error:  tensor(0.3080, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8821, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  69
# results/diabetes/69_19.txt
# Discriminator error:  tensor(1.3007, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3473, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  70
# results/diabetes/70_19.txt
# Discriminator error:  tensor(0.6628, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.4533, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  71
# results/diabetes/71_19.txt
# Discriminator error:  tensor(2.8101, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4522, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  72
# results/diabetes/72_19.txt
# Discriminator error:  tensor(1.7693, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9829, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  73
# results/diabetes/73_19.txt
# Discriminator error:  tensor(1.1966, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6918, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  74
# results/diabetes/74_19.txt
# Discriminator error:  tensor(1.7893, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9036, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  75
# results/diabetes/75_19.txt
# Discriminator error:  tensor(0.5730, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9934, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  76
# results/diabetes/76_19.txt
# Discriminator error:  tensor(0.4801, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8437, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  77
# results/diabetes/77_19.txt
# Discriminator error:  tensor(1.0529, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6838, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  78
# results/diabetes/78_19.txt
# Discriminator error:  tensor(0.3503, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1793, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  79
# results/diabetes/79_19.txt
# Discriminator error:  tensor(0.5807, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5532, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  80
# results/diabetes/80_19.txt
# Discriminator error:  tensor(0.4713, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9796, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  81
# results/diabetes/81_19.txt
# Discriminator error:  tensor(0.4795, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5522, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  82
# results/diabetes/82_19.txt
# Discriminator error:  tensor(0.0915, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8975, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  83
# results/diabetes/83_19.txt
# Discriminator error:  tensor(0.4208, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5121, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  84
# results/diabetes/84_19.txt
# Discriminator error:  tensor(0.3875, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9100, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  85
# results/diabetes/85_19.txt
# Discriminator error:  tensor(0.5081, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3099, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  86
# results/diabetes/86_19.txt
# Discriminator error:  tensor(0.6629, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0220, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  87
# results/diabetes/87_19.txt
# Discriminator error:  tensor(0.3156, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7294, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  88
# results/diabetes/88_19.txt
# Discriminator error:  tensor(0.4083, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2830, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  89
# results/diabetes/89_19.txt
# Discriminator error:  tensor(2.1089, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7157, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  90
# results/diabetes/90_19.txt
# Discriminator error:  tensor(0.8177, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4599, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  91
# results/diabetes/91_19.txt
# Discriminator error:  tensor(0.3249, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8744, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  92
# results/diabetes/92_19.txt
# Discriminator error:  tensor(0.2348, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8567, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  93
# results/diabetes/93_19.txt
# Discriminator error:  tensor(0.4251, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.7618, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  94
# results/diabetes/94_19.txt
# Discriminator error:  tensor(0.8221, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8198, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  95
# results/diabetes/95_19.txt
# Discriminator error:  tensor(1.4872, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8892, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  96
# results/diabetes/96_19.txt
# Discriminator error:  tensor(0.4119, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2125, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  97
# results/diabetes/97_19.txt
# Discriminator error:  tensor(0.9316, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5649, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  98
# results/diabetes/98_19.txt
# Discriminator error:  tensor(1.1006, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7232, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  99
# results/diabetes/99_19.txt
# Discriminator error:  tensor(1.1911, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7673, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  100
# results/diabetes/100_19.txt
# Discriminator error:  tensor(0.4854, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7796, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  101
# results/diabetes/101_19.txt
# Discriminator error:  tensor(0.4195, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3393, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  102
# results/diabetes/102_19.txt
# Discriminator error:  tensor(0.7359, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3959, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  103
# results/diabetes/103_19.txt
# Discriminator error:  tensor(0.2789, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0918, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  104
# results/diabetes/104_19.txt
# Discriminator error:  tensor(0.8578, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0050, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  105
# results/diabetes/105_19.txt
# Discriminator error:  tensor(1.3722, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2347, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  106
# results/diabetes/106_19.txt
# Discriminator error:  tensor(0.5951, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9962, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  107
# results/diabetes/107_19.txt
# Discriminator error:  tensor(1.0570, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6886, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  108
# results/diabetes/108_19.txt
# Discriminator error:  tensor(0.5781, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7721, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  109
# results/diabetes/109_19.txt
# Discriminator error:  tensor(0.5983, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8446, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  110
# results/diabetes/110_19.txt
# Discriminator error:  tensor(0.7629, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4429, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  111
# results/diabetes/111_19.txt
# Discriminator error:  tensor(0.3208, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.3990, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  112
# results/diabetes/112_19.txt
# Discriminator error:  tensor(0.3828, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.5270, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  113
# results/diabetes/113_19.txt
# Discriminator error:  tensor(0.8613, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6530, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  114
# results/diabetes/114_19.txt
# Discriminator error:  tensor(0.9172, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0965, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  115
# results/diabetes/115_19.txt
# Discriminator error:  tensor(8.5843, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(3.0702, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  116
# results/diabetes/116_19.txt
# Discriminator error:  tensor(10.2698, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.2034, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  117
# results/diabetes/117_19.txt
# Discriminator error:  tensor(0.9141, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7679, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  118
# results/diabetes/118_19.txt
# Discriminator error:  tensor(1.9787, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.6336, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  119
# results/diabetes/119_19.txt
# Discriminator error:  tensor(0.2807, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1820, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  120
# results/diabetes/120_19.txt
# Discriminator error:  tensor(0.4792, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2762, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  121
# results/diabetes/121_19.txt
# Discriminator error:  tensor(1.7615, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3662, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  122
# results/diabetes/122_19.txt
# Discriminator error:  tensor(0.5942, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2986, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  123
# results/diabetes/123_19.txt
# Discriminator error:  tensor(0.8421, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7196, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  124
# results/diabetes/124_19.txt
# Discriminator error:  tensor(0.5051, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1017, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  125
# results/diabetes/125_19.txt
# Discriminator error:  tensor(0.8770, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6674, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  126
# results/diabetes/126_19.txt
# Discriminator error:  tensor(0.8486, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1330, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  127
# results/diabetes/127_19.txt
# Discriminator error:  tensor(2.0271, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1107, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  128
# results/diabetes/128_19.txt
# Discriminator error:  tensor(0.7202, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3591, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  129
# results/diabetes/129_19.txt
# Discriminator error:  tensor(0.5016, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0222, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  130
# results/diabetes/130_19.txt
# Discriminator error:  tensor(0.2464, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2210, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  131
# results/diabetes/131_19.txt
# Discriminator error:  tensor(0.9222, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0469, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  132
# results/diabetes/132_19.txt
# Discriminator error:  tensor(0.3242, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8051, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  133
# results/diabetes/133_19.txt
# Discriminator error:  tensor(1.0639, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7317, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  134
# results/diabetes/134_19.txt
# Discriminator error:  tensor(0.9604, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7883, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  135
# results/diabetes/135_19.txt
# Discriminator error:  tensor(0.2815, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0095, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  136
# results/diabetes/136_19.txt
# Discriminator error:  tensor(1.2544, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6990, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  137
# results/diabetes/137_19.txt
# Discriminator error:  tensor(0.1752, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(3.1292, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  138
# results/diabetes/138_19.txt
# Discriminator error:  tensor(0.1658, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9033, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  139
# results/diabetes/139_19.txt
# Discriminator error:  tensor(1.0184, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9323, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  140
# results/diabetes/140_19.txt
# Discriminator error:  tensor(0.9261, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0263, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  141
# results/diabetes/141_19.txt
# Discriminator error:  tensor(1.4239, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5216, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  142
# results/diabetes/142_19.txt
# Discriminator error:  tensor(0.8721, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5034, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  143
# results/diabetes/143_19.txt
# Discriminator error:  tensor(0.5045, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3857, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  144
# results/diabetes/144_19.txt
# Discriminator error:  tensor(1.6691, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9404, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  145
# results/diabetes/145_19.txt
# Discriminator error:  tensor(0.6948, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7099, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  146
# results/diabetes/146_19.txt
# Discriminator error:  tensor(0.6985, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9887, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  147
# results/diabetes/147_19.txt
# Discriminator error:  tensor(1.1317, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0006, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  148
# results/diabetes/148_19.txt
# Discriminator error:  tensor(2.1733, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8948, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  149
# results/diabetes/149_19.txt
# Discriminator error:  tensor(1.6952, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5318, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  150
# results/diabetes/150_19.txt
# Discriminator error:  tensor(1.3269, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2838, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  151
# results/diabetes/151_19.txt
# Discriminator error:  tensor(0.6856, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6547, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  152
# results/diabetes/152_19.txt
# Discriminator error:  tensor(1.0282, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0228, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  153
# results/diabetes/153_19.txt
# Discriminator error:  tensor(0.8682, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9936, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  154
# results/diabetes/154_19.txt
# Discriminator error:  tensor(0.9131, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5114, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  155
# results/diabetes/155_19.txt
# Discriminator error:  tensor(1.0861, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7524, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  156
# results/diabetes/156_19.txt
# Discriminator error:  tensor(2.2025, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3905, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  157
# results/diabetes/157_19.txt
# Discriminator error:  tensor(1.3889, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9768, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  158
# results/diabetes/158_19.txt
# Discriminator error:  tensor(2.1530, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0767, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  159
# results/diabetes/159_19.txt
# Discriminator error:  tensor(1.3929, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0591, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  160
# results/diabetes/160_19.txt
# Discriminator error:  tensor(1.1423, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1153, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  161
# results/diabetes/161_19.txt
# Discriminator error:  tensor(1.3377, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2796, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  162
# results/diabetes/162_19.txt
# Discriminator error:  tensor(1.4511, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8774, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  163
# results/diabetes/163_19.txt
# Discriminator error:  tensor(1.2386, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9825, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  164
# results/diabetes/164_19.txt
# Discriminator error:  tensor(1.2269, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9156, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  165
# results/diabetes/165_19.txt
# Discriminator error:  tensor(0.7125, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8933, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  166
# results/diabetes/166_19.txt
# Discriminator error:  tensor(2.3350, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9644, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  167
# results/diabetes/167_19.txt
# Discriminator error:  tensor(0.9679, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0535, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  168
# results/diabetes/168_19.txt
# Discriminator error:  tensor(0.6894, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9380, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  169
# results/diabetes/169_19.txt
# Discriminator error:  tensor(1.1202, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2911, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  170
# results/diabetes/170_19.txt
# Discriminator error:  tensor(1.0890, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5496, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  171
# results/diabetes/171_19.txt
# Discriminator error:  tensor(0.8377, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6398, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  172
# results/diabetes/172_19.txt
# Discriminator error:  tensor(1.7672, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7012, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  173
# results/diabetes/173_19.txt
# Discriminator error:  tensor(1.2311, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3202, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  174
# results/diabetes/174_19.txt
# Discriminator error:  tensor(0.9736, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9480, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  175
# results/diabetes/175_19.txt
# Discriminator error:  tensor(0.7798, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2727, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  176
# results/diabetes/176_19.txt
# Discriminator error:  tensor(1.2454, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7513, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  177
# results/diabetes/177_19.txt
# Discriminator error:  tensor(1.7830, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9920, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  178
# results/diabetes/178_19.txt
# Discriminator error:  tensor(1.1002, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0384, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  179
# results/diabetes/179_19.txt
# Discriminator error:  tensor(2.4363, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8096, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  180
# results/diabetes/180_19.txt
# Discriminator error:  tensor(1.3507, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3575, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  181
# results/diabetes/181_19.txt
# Discriminator error:  tensor(1.1992, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9031, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  182
# results/diabetes/182_19.txt
# Discriminator error:  tensor(0.9974, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2013, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  183
# results/diabetes/183_19.txt
# Discriminator error:  tensor(0.8286, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6197, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  184
# results/diabetes/184_19.txt
# Discriminator error:  tensor(1.5185, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5640, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  185
# results/diabetes/185_19.txt
# Discriminator error:  tensor(1.2277, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7841, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  186
# results/diabetes/186_19.txt
# Discriminator error:  tensor(0.4188, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8390, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  187
# results/diabetes/187_19.txt
# Discriminator error:  tensor(0.6318, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1403, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  188
# results/diabetes/188_19.txt
# Discriminator error:  tensor(0.8898, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1389, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  189
# results/diabetes/189_19.txt
# Discriminator error:  tensor(1.0731, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0518, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  190
# results/diabetes/190_19.txt
# Discriminator error:  tensor(1.7941, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7896, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  191
# results/diabetes/191_19.txt
# Discriminator error:  tensor(1.2011, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0687, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  192
# results/diabetes/192_19.txt
# Discriminator error:  tensor(1.2732, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9157, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  193
# results/diabetes/193_19.txt
# Discriminator error:  tensor(0.8672, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7491, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  194
# results/diabetes/194_19.txt
# Discriminator error:  tensor(2.5621, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4928, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  195
# results/diabetes/195_19.txt
# Discriminator error:  tensor(0.9342, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5200, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  196
# results/diabetes/196_19.txt
# Discriminator error:  tensor(0.9409, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1858, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  197
# results/diabetes/197_19.txt
# Discriminator error:  tensor(0.6195, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2957, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  198
# results/diabetes/198_19.txt
# Discriminator error:  tensor(0.9973, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0460, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  199
# results/diabetes/199_19.txt
# Discriminator error:  tensor(1.4832, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1692, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  200
# results/diabetes/200_19.txt
# Discriminator error:  tensor(0.8419, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0641, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  201
# results/diabetes/201_19.txt
# Discriminator error:  tensor(0.9184, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8115, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  202
# results/diabetes/202_19.txt
# Discriminator error:  tensor(0.6200, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6265, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  203
# results/diabetes/203_19.txt
# Discriminator error:  tensor(0.7138, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1267, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  204
# results/diabetes/204_19.txt
# Discriminator error:  tensor(1.4717, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3899, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  205
# results/diabetes/205_19.txt
# Discriminator error:  tensor(2.0889, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6833, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  206
# results/diabetes/206_19.txt
# Discriminator error:  tensor(2.2554, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1074, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  207
# results/diabetes/207_19.txt
# Discriminator error:  tensor(1.3059, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9424, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  208
# results/diabetes/208_19.txt
# Discriminator error:  tensor(0.3689, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5309, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  209
# results/diabetes/209_19.txt
# Discriminator error:  tensor(0.6814, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8005, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  210
# results/diabetes/210_19.txt
# Discriminator error:  tensor(1.4653, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.3506, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  211
# results/diabetes/211_19.txt
# Discriminator error:  tensor(1.0442, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1451, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  212
# results/diabetes/212_19.txt
# Discriminator error:  tensor(0.4582, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3796, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  213
# results/diabetes/213_19.txt
# Discriminator error:  tensor(1.4832, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2631, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  214
# results/diabetes/214_19.txt
# Discriminator error:  tensor(1.0975, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9984, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  215
# results/diabetes/215_19.txt
# Discriminator error:  tensor(0.9877, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0521, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  216
# results/diabetes/216_19.txt
# Discriminator error:  tensor(0.9187, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6321, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  217
# results/diabetes/217_19.txt
# Discriminator error:  tensor(1.6073, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2657, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  218
# results/diabetes/218_19.txt
# Discriminator error:  tensor(1.6384, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3526, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  219
# results/diabetes/219_19.txt
# Discriminator error:  tensor(1.1078, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1259, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  220
# results/diabetes/220_19.txt
# Discriminator error:  tensor(0.8143, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8453, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  221
# results/diabetes/221_19.txt
# Discriminator error:  tensor(1.4018, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4018, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  222
# results/diabetes/222_19.txt
# Discriminator error:  tensor(0.8470, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6107, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  223
# results/diabetes/223_19.txt
# Discriminator error:  tensor(1.2710, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0333, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  224
# results/diabetes/224_19.txt
# Discriminator error:  tensor(1.2271, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0703, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  225
# results/diabetes/225_19.txt
# Discriminator error:  tensor(1.1985, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9287, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  226
# results/diabetes/226_19.txt
# Discriminator error:  tensor(1.4009, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0298, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  227
# results/diabetes/227_19.txt
# Discriminator error:  tensor(0.8658, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2368, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  228
# results/diabetes/228_19.txt
# Discriminator error:  tensor(0.7743, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7733, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  229
# results/diabetes/229_19.txt
# Discriminator error:  tensor(0.9326, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8661, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  230
# results/diabetes/230_19.txt
# Discriminator error:  tensor(0.7518, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2790, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  231
# results/diabetes/231_19.txt
# Discriminator error:  tensor(0.8292, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9407, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  232
# results/diabetes/232_19.txt
# Discriminator error:  tensor(1.2644, device='cuda:0', grad_fn=<AddBackward0>)
# ...
# Generator error:  tensor(0.7082, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1424
# results/diabetes/1424_19.txt
# Discriminator error:  tensor(1.3444, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0833, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1425
# results/diabetes/1425_19.txt
# Discriminator error:  tensor(1.2777, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9281, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1426
# results/diabetes/1426_19.txt
# Discriminator error:  tensor(1.2272, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6970, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1427
# results/diabetes/1427_19.txt
# Discriminator error:  tensor(1.3011, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7673, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1428
# results/diabetes/1428_19.txt
# Discriminator error:  tensor(1.3884, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7642, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1429
# results/diabetes/1429_19.txt
# Discriminator error:  tensor(1.4932, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8099, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1430
# results/diabetes/1430_19.txt
# Discriminator error:  tensor(0.9871, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0245, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1431
# results/diabetes/1431_19.txt
# Discriminator error:  tensor(1.3528, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1014, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1432
# results/diabetes/1432_19.txt
# Discriminator error:  tensor(1.1647, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9680, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1433
# results/diabetes/1433_19.txt
# Discriminator error:  tensor(1.1334, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8656, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1434
# results/diabetes/1434_19.txt
# Discriminator error:  tensor(1.5983, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7337, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1435
# results/diabetes/1435_19.txt
# Discriminator error:  tensor(1.4693, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9632, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1436
# results/diabetes/1436_19.txt
# Discriminator error:  tensor(0.8370, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0111, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1437
# results/diabetes/1437_19.txt
# Discriminator error:  tensor(1.3256, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9514, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1438
# results/diabetes/1438_19.txt
# Discriminator error:  tensor(1.1455, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6711, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1439
# results/diabetes/1439_19.txt
# Discriminator error:  tensor(1.2878, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7407, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1440
# results/diabetes/1440_19.txt
# Discriminator error:  tensor(1.5399, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7961, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1441
# results/diabetes/1441_19.txt
# Discriminator error:  tensor(2.0558, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0065, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1442
# results/diabetes/1442_19.txt
# Discriminator error:  tensor(1.2014, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9350, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1443
# results/diabetes/1443_19.txt
# Discriminator error:  tensor(1.3264, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8871, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1444
# results/diabetes/1444_19.txt
# Discriminator error:  tensor(1.1462, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1865, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1445
# results/diabetes/1445_19.txt
# Discriminator error:  tensor(1.1620, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9769, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1446
# results/diabetes/1446_19.txt
# Discriminator error:  tensor(1.4367, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9309, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1447
# results/diabetes/1447_19.txt
# Discriminator error:  tensor(1.2523, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9999, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1448
# results/diabetes/1448_19.txt
# Discriminator error:  tensor(1.5363, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7974, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1449
# results/diabetes/1449_19.txt
# Discriminator error:  tensor(1.3778, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7998, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1450
# results/diabetes/1450_19.txt
# Discriminator error:  tensor(1.3927, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6710, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1451
# results/diabetes/1451_19.txt
# Discriminator error:  tensor(1.2907, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0372, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1452
# results/diabetes/1452_19.txt
# Discriminator error:  tensor(1.2655, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6130, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1453
# results/diabetes/1453_19.txt
# Discriminator error:  tensor(1.4031, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.3442, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1454
# results/diabetes/1454_19.txt
# Discriminator error:  tensor(1.4327, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5626, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1455
# results/diabetes/1455_19.txt
# Discriminator error:  tensor(1.2356, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7720, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1456
# results/diabetes/1456_19.txt
# Discriminator error:  tensor(1.4720, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6580, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1457
# results/diabetes/1457_19.txt
# Discriminator error:  tensor(1.2671, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6823, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1458
# results/diabetes/1458_19.txt
# Discriminator error:  tensor(1.3728, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6861, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1459
# results/diabetes/1459_19.txt
# Discriminator error:  tensor(1.5398, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7324, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1460
# results/diabetes/1460_19.txt
# Discriminator error:  tensor(1.0857, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3639, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1461
# results/diabetes/1461_19.txt
# Discriminator error:  tensor(1.4725, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8026, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1462
# results/diabetes/1462_19.txt
# Discriminator error:  tensor(1.3585, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8114, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1463
# results/diabetes/1463_19.txt
# Discriminator error:  tensor(1.2706, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6133, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1464
# results/diabetes/1464_19.txt
# Discriminator error:  tensor(1.1977, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7650, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1465
# results/diabetes/1465_19.txt
# Discriminator error:  tensor(1.2536, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9113, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1466
# results/diabetes/1466_19.txt
# Discriminator error:  tensor(1.3939, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8602, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1467
# results/diabetes/1467_19.txt
# Discriminator error:  tensor(1.3060, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7187, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1468
# results/diabetes/1468_19.txt
# Discriminator error:  tensor(1.5752, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9533, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1469
# results/diabetes/1469_19.txt
# Discriminator error:  tensor(1.4839, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8349, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1470
# results/diabetes/1470_19.txt
# Discriminator error:  tensor(1.6132, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1731, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1471
# results/diabetes/1471_19.txt
# Discriminator error:  tensor(1.3049, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9112, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1472
# results/diabetes/1472_19.txt
# Discriminator error:  tensor(1.0959, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0608, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1473
# results/diabetes/1473_19.txt
# Discriminator error:  tensor(1.9048, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6864, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1474
# results/diabetes/1474_19.txt
# Discriminator error:  tensor(1.6198, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7533, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1475
# results/diabetes/1475_19.txt
# Discriminator error:  tensor(1.6943, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6630, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1476
# results/diabetes/1476_19.txt
# Discriminator error:  tensor(1.2885, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9088, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1477
# results/diabetes/1477_19.txt
# Discriminator error:  tensor(1.3651, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5662, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1478
# results/diabetes/1478_19.txt
# Discriminator error:  tensor(1.6763, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2446, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1479
# results/diabetes/1479_19.txt
# Discriminator error:  tensor(1.9997, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0479, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1480
# results/diabetes/1480_19.txt
# Discriminator error:  tensor(1.2918, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3410, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1481
# results/diabetes/1481_19.txt
# Discriminator error:  tensor(1.2090, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1126, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1482
# results/diabetes/1482_19.txt
# Discriminator error:  tensor(1.1738, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7927, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1483
# results/diabetes/1483_19.txt
# Discriminator error:  tensor(1.5634, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9084, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1484
# results/diabetes/1484_19.txt
# Discriminator error:  tensor(1.4086, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6324, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1485
# results/diabetes/1485_19.txt
# Discriminator error:  tensor(1.2193, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7983, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1486
# results/diabetes/1486_19.txt
# Discriminator error:  tensor(1.1806, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0179, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1487
# results/diabetes/1487_19.txt
# Discriminator error:  tensor(1.3594, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0804, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1488
# results/diabetes/1488_19.txt
# Discriminator error:  tensor(1.1705, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0151, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1489
# results/diabetes/1489_19.txt
# Discriminator error:  tensor(1.3350, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1191, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1490
# results/diabetes/1490_19.txt
# Discriminator error:  tensor(1.0107, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0864, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1491
# results/diabetes/1491_19.txt
# Discriminator error:  tensor(1.1180, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0041, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1492
# results/diabetes/1492_19.txt
# Discriminator error:  tensor(1.4829, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8962, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1493
# results/diabetes/1493_19.txt
# Discriminator error:  tensor(0.9883, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8683, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1494
# results/diabetes/1494_19.txt
# Discriminator error:  tensor(1.6573, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6197, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1495
# results/diabetes/1495_19.txt
# Discriminator error:  tensor(1.1885, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0248, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1496
# results/diabetes/1496_19.txt
# Discriminator error:  tensor(1.7535, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5940, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1497
# results/diabetes/1497_19.txt
# Discriminator error:  tensor(1.1134, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5841, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1498
# results/diabetes/1498_19.txt
# Discriminator error:  tensor(1.3170, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9860, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1499
# results/diabetes/1499_19.txt
# Discriminator error:  tensor(1.3654, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7059, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)

# %%
results_dir = f"models/{file_name.split('/')[-1].split('.')[0]}"
os.mkdir(results_dir)

# %%
print(epoch)
torch.save({
            'epoch': epoch,
            'model_state_dict': generator.state_dict(),
            'optimizer_state_dict': g_optimizer.state_dict(),
            'model_attributes': {'out_features': dataAtts.class_len},
            'loss': loss
            # }, "models/generator" + dataAtts.fname + "_" + str(epoch) + ".pt")
            }, results_dir + "/generator" + dataAtts.fname + "_" + str(epoch) + ".pt")

torch.save({
            'epoch': epoch,
            'model_state_dict': discriminator.state_dict(),
            'optimizer_state_dict': d_optimizer.state_dict(),
            'loss': loss
            # }, "models/discriminator" + dataAtts.fname + "_" + str(epoch) + ".pt")
            }, results_dir + "/discriminator" + dataAtts.fname + "_" + str(epoch) + ".pt")
# Out:
# 1499

# %%
plt.plot(d_error_plt, 'b')
plt.plot(g_error_plt, 'r')
filename = "results/" + dataAtts.fname + "/" + "error_growth.txt"
file = open(filename, "w")
file.write("Discriminator error: " + str(d_error_plt) + "\n")
file.write("\n\n\n")
file.write("Generator error: " + str(g_error_plt) + "\n")
file.close()

plt.savefig('images/'+ dataAtts.fname + "/"+ 'error.png')
plt.show()
plt.clf()
