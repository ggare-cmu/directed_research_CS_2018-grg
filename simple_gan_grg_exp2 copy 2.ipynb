# %%
import torch
import pandas as pd
from torch import nn, optim
from torch.autograd.variable import Variable
from torchvision import transforms, datasets
from data_treatment import DataSetGRG, DataAtts
from discriminator import *
from generator import *
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt
import glob

# %%
# Noise
def noise(size):
    n = Variable(torch.randn(size, 100))
    if torch.cuda.is_available(): 
        return n.cuda() 
    return n

# %%
files_dropdown = widgets.Dropdown(
    # options=glob.glob("original_data/*.csv"),
    options=glob.glob("grg_data/*.csv"),
    description='File:',
    # value = 'original_data/diabetes_escalonated.csv',
    disabled=False,
)
display(files_dropdown)
# Out:
# Dropdown(description='File:', options=('grg_data/diabetes-small3_TrainUpsampledPatient.csv', 'grg_data/diabete…

# %%
file_name=files_dropdown.value
dataAtts = DataAtts(file_name)

# %%
def train_generator(optimizer, fake_data):
    # 2. Train Generator
    # Reset gradients
    optimizer.zero_grad()
    # Sample noise and generate fake data
    prediction = discriminator(fake_data)
    # Calculate error and backpropagate
    error = loss(prediction, real_data_target(prediction.size(0)))
    error.backward()
    # Update weights with gradients
    optimizer.step()
    # Return error
    return error

def train_discriminator(optimizer, real_data, fake_data):
    # Reset gradients
    optimizer.zero_grad()
    
    # 1.1 Train on Real Data
    prediction_real = discriminator(real_data)
    # Calculate error and backpropagate
    error_real = loss(prediction_real, real_data_target(real_data.size(0)))
    error_real.backward()

    # 1.2 Train on Fake Data
    prediction_fake = discriminator(fake_data)
    # Calculate error and backpropagate
    error_fake = loss(prediction_fake, fake_data_target(real_data.size(0)))
    error_fake.backward()
    
    # 1.3 Update weights with gradients
    optimizer.step()
    
    # Return error
    return error_real + error_fake, prediction_real, prediction_fake

# %%
def real_data_target(size):
    '''
    Tensor containing ones, with shape = size
    '''
    data = Variable(torch.ones(size, 1))
    if torch.cuda.is_available(): return data.cuda()
    return data

def fake_data_target(size):
    '''
    Tensor containing zeros, with shape = size
    '''
    data = Variable(torch.zeros(size, 1))
    if torch.cuda.is_available(): return data.cuda()
    return data

# %%
lr = 0.0002
#lr= 0.0002
batch_size = 5
# num_epochs = 106
num_epochs = 1500
print_interval = 10
loss = nn.BCELoss()

# %%
# discriminator = DiscriminatorNet(dataAtts.class_len)
discriminator = DiscriminatorNet(dataAtts.class_len,  hidden_layers=[512, 256])
generator = GeneratorNet(dataAtts.class_len,  hidden_layers=[512, 256])
if torch.cuda.is_available():
    discriminator.cuda()
    generator.cuda()
d_optimizer = optim.Adam(discriminator.parameters(), lr=lr)
g_optimizer = optim.Adam(generator.parameters(), lr=lr)

# %%
d_error_plt = [0]
g_error_plt = [0]

generated_points = []

# %%
database = DataSetGRG(csv_file=file_name, root_dir=".")

data_loader = torch.utils.data.DataLoader(database, batch_size=batch_size, shuffle=True)
num_batches = len(data_loader)

# %%
for epoch in range(num_epochs):
    print("Epoch ", epoch)

    for n_batch, real_batch in enumerate(data_loader):
        # 1. Train Discriminator
        real_data = Variable(real_batch).float()
        if torch.cuda.is_available(): 
            real_data = real_data.cuda()
        # Generate fake data
        fake_data = generator(noise(real_data.size(0))).detach()
        # Train D
        d_error, d_pred_real, d_pred_fake = train_discriminator(d_optimizer,
                                                                real_data, fake_data)

        # 2. Train Generator
        # Generate fake data
        fake_data = generator(noise(real_batch.size(0)))
        generated_points.append(fake_data)
        # Train G
        g_error = train_generator(g_optimizer, fake_data)

        # Display Progress

        #if (n_batch) % print_interval == 0:
    filename = "results/" + dataAtts.fname + "/" + str(epoch) + "_" + str(n_batch) + ".txt"
    print(filename)
    file = open(filename, "w")
    print("Discriminator error: ", d_error)
    print("Generator error: ", g_error)
    print("")

    file.write("Discriminator error: " + str(d_error) + "\n")
    file.write("Generator error: " + str(g_error) + "\n")
    file.write("Points: " + str(fake_data) + "\n\n\n")

    # d_error_plt.append(d_error)
    # g_error_plt.append(g_error)
    d_error_plt.append(d_error.detach().cpu().numpy())
    g_error_plt.append(g_error.detach().cpu().numpy())
        #     #display.clear_output(True)
        #     # Display Images
        #     test_images = generator(test_noise).data.cpu()
        #     logger.log_images(test_images, num_test_samples, epoch, n_batch, num_batches);
        #     # Display status Logs
        #     #logger.display_status(epoch, num_epochs, n_batch, num_batches, d_error, g_error, d_pred_real, d_pred_fake)
        # # Model Checkpoints
# Out:
# Epoch  0
# results/diabetes/0_19.txt
# Discriminator error:  tensor(0.8365, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5916, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1
# results/diabetes/1_19.txt
# Discriminator error:  tensor(1.1645, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.3522, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  2
# results/diabetes/2_19.txt
# Discriminator error:  tensor(1.3610, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.3159, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  3
# results/diabetes/3_19.txt
# Discriminator error:  tensor(0.9640, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6629, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  4
# results/diabetes/4_19.txt
# Discriminator error:  tensor(1.1815, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.3944, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  5
# results/diabetes/5_19.txt
# Discriminator error:  tensor(0.8280, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6163, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  6
# results/diabetes/6_19.txt
# Discriminator error:  tensor(0.7932, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6321, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  7
# results/diabetes/7_19.txt
# Discriminator error:  tensor(1.1056, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5011, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  8
# results/diabetes/8_19.txt
# Discriminator error:  tensor(1.1390, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7907, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  9
# results/diabetes/9_19.txt
# Discriminator error:  tensor(0.4919, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0898, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  10
# results/diabetes/10_19.txt
# Discriminator error:  tensor(3.0298, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4534, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  11
# results/diabetes/11_19.txt
# Discriminator error:  tensor(0.9724, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6856, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  12
# results/diabetes/12_19.txt
# Discriminator error:  tensor(1.0231, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9938, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  13
# results/diabetes/13_19.txt
# Discriminator error:  tensor(1.2772, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9937, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  14
# results/diabetes/14_19.txt
# Discriminator error:  tensor(0.8937, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4121, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  15
# results/diabetes/15_19.txt
# Discriminator error:  tensor(1.1445, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7388, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  16
# results/diabetes/16_19.txt
# Discriminator error:  tensor(1.1270, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.3856, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  17
# results/diabetes/17_19.txt
# Discriminator error:  tensor(1.9956, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1499, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  18
# results/diabetes/18_19.txt
# Discriminator error:  tensor(2.1006, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2586, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  19
# results/diabetes/19_19.txt
# Discriminator error:  tensor(0.4074, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4623, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  20
# results/diabetes/20_19.txt
# Discriminator error:  tensor(0.6582, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3404, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  21
# results/diabetes/21_19.txt
# Discriminator error:  tensor(1.7717, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.2538, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  22
# results/diabetes/22_19.txt
# Discriminator error:  tensor(1.4901, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.3279, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  23
# results/diabetes/23_19.txt
# Discriminator error:  tensor(0.8797, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7542, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  24
# results/diabetes/24_19.txt
# Discriminator error:  tensor(0.7243, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9230, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  25
# results/diabetes/25_19.txt
# Discriminator error:  tensor(0.7620, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1593, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  26
# results/diabetes/26_19.txt
# Discriminator error:  tensor(1.1441, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8343, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  27
# results/diabetes/27_19.txt
# Discriminator error:  tensor(1.2359, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.3714, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  28
# results/diabetes/28_19.txt
# Discriminator error:  tensor(0.6894, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1994, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  29
# results/diabetes/29_19.txt
# Discriminator error:  tensor(0.7246, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3385, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  30
# results/diabetes/30_19.txt
# Discriminator error:  tensor(0.2677, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8380, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  31
# results/diabetes/31_19.txt
# Discriminator error:  tensor(0.2954, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7583, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  32
# results/diabetes/32_19.txt
# Discriminator error:  tensor(2.3990, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4702, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  33
# results/diabetes/33_19.txt
# Discriminator error:  tensor(1.5045, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6267, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  34
# results/diabetes/34_19.txt
# Discriminator error:  tensor(0.8911, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6258, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  35
# results/diabetes/35_19.txt
# Discriminator error:  tensor(0.3256, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7864, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  36
# results/diabetes/36_19.txt
# Discriminator error:  tensor(0.7536, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1098, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  37
# results/diabetes/37_19.txt
# Discriminator error:  tensor(0.8925, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3393, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  38
# results/diabetes/38_19.txt
# Discriminator error:  tensor(0.5979, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5118, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  39
# results/diabetes/39_19.txt
# Discriminator error:  tensor(1.0048, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7845, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  40
# results/diabetes/40_19.txt
# Discriminator error:  tensor(0.8885, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4065, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  41
# results/diabetes/41_19.txt
# Discriminator error:  tensor(0.7110, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7717, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  42
# results/diabetes/42_19.txt
# Discriminator error:  tensor(0.6156, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0519, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  43
# results/diabetes/43_19.txt
# Discriminator error:  tensor(0.5337, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9677, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  44
# results/diabetes/44_19.txt
# Discriminator error:  tensor(0.7040, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0229, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  45
# results/diabetes/45_19.txt
# Discriminator error:  tensor(0.6099, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0059, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  46
# results/diabetes/46_19.txt
# Discriminator error:  tensor(1.0077, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5243, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  47
# results/diabetes/47_19.txt
# Discriminator error:  tensor(0.4483, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2221, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  48
# results/diabetes/48_19.txt
# Discriminator error:  tensor(1.6955, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.3799, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  49
# results/diabetes/49_19.txt
# Discriminator error:  tensor(0.2778, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1583, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  50
# results/diabetes/50_19.txt
# Discriminator error:  tensor(0.5051, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9496, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  51
# results/diabetes/51_19.txt
# Discriminator error:  tensor(0.4469, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1092, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  52
# results/diabetes/52_19.txt
# Discriminator error:  tensor(1.2477, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.3394, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  53
# results/diabetes/53_19.txt
# Discriminator error:  tensor(1.0318, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9829, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  54
# results/diabetes/54_19.txt
# Discriminator error:  tensor(1.0221, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7702, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  55
# results/diabetes/55_19.txt
# Discriminator error:  tensor(0.9014, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5541, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  56
# results/diabetes/56_19.txt
# Discriminator error:  tensor(0.7295, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0361, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  57
# results/diabetes/57_19.txt
# Discriminator error:  tensor(0.7554, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4213, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  58
# results/diabetes/58_19.txt
# Discriminator error:  tensor(0.8200, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5361, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  59
# results/diabetes/59_19.txt
# Discriminator error:  tensor(0.7424, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2072, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  60
# results/diabetes/60_19.txt
# Discriminator error:  tensor(0.8089, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3056, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  61
# results/diabetes/61_19.txt
# Discriminator error:  tensor(0.6968, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2992, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  62
# results/diabetes/62_19.txt
# Discriminator error:  tensor(0.8802, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4269, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  63
# results/diabetes/63_19.txt
# Discriminator error:  tensor(0.2307, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4879, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  64
# results/diabetes/64_19.txt
# Discriminator error:  tensor(0.3263, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7467, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  65
# results/diabetes/65_19.txt
# Discriminator error:  tensor(1.2009, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7519, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  66
# results/diabetes/66_19.txt
# Discriminator error:  tensor(0.5285, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4397, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  67
# results/diabetes/67_19.txt
# Discriminator error:  tensor(0.0994, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.2280, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  68
# results/diabetes/68_19.txt
# Discriminator error:  tensor(1.1342, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8813, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  69
# results/diabetes/69_19.txt
# Discriminator error:  tensor(0.5526, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8905, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  70
# results/diabetes/70_19.txt
# Discriminator error:  tensor(0.4692, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2431, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  71
# results/diabetes/71_19.txt
# Discriminator error:  tensor(0.1897, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1938, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  72
# results/diabetes/72_19.txt
# Discriminator error:  tensor(1.8001, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7017, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  73
# results/diabetes/73_19.txt
# Discriminator error:  tensor(0.4442, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0376, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  74
# results/diabetes/74_19.txt
# Discriminator error:  tensor(0.6454, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9448, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  75
# results/diabetes/75_19.txt
# Discriminator error:  tensor(1.2325, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0628, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  76
# results/diabetes/76_19.txt
# Discriminator error:  tensor(0.9611, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3625, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  77
# results/diabetes/77_19.txt
# Discriminator error:  tensor(0.5586, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1897, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  78
# results/diabetes/78_19.txt
# Discriminator error:  tensor(0.7078, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0888, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  79
# results/diabetes/79_19.txt
# Discriminator error:  tensor(0.4421, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8983, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  80
# results/diabetes/80_19.txt
# Discriminator error:  tensor(0.3939, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2895, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  81
# results/diabetes/81_19.txt
# Discriminator error:  tensor(0.3877, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5034, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  82
# results/diabetes/82_19.txt
# Discriminator error:  tensor(0.2802, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4128, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  83
# results/diabetes/83_19.txt
# Discriminator error:  tensor(1.0238, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3756, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  84
# results/diabetes/84_19.txt
# Discriminator error:  tensor(0.2408, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8429, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  85
# results/diabetes/85_19.txt
# Discriminator error:  tensor(1.3157, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3592, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  86
# results/diabetes/86_19.txt
# Discriminator error:  tensor(1.4266, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1163, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  87
# results/diabetes/87_19.txt
# Discriminator error:  tensor(0.6600, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5539, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  88
# results/diabetes/88_19.txt
# Discriminator error:  tensor(0.0965, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.4300, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  89
# results/diabetes/89_19.txt
# Discriminator error:  tensor(1.2667, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6754, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  90
# results/diabetes/90_19.txt
# Discriminator error:  tensor(0.5791, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3541, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  91
# results/diabetes/91_19.txt
# Discriminator error:  tensor(2.2680, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6192, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  92
# results/diabetes/92_19.txt
# Discriminator error:  tensor(0.4989, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1944, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  93
# results/diabetes/93_19.txt
# Discriminator error:  tensor(4.3622, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.9052, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  94
# results/diabetes/94_19.txt
# Discriminator error:  tensor(0.2391, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6805, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  95
# results/diabetes/95_19.txt
# Discriminator error:  tensor(5.7490, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8166, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  96
# results/diabetes/96_19.txt
# Discriminator error:  tensor(1.6949, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4720, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  97
# results/diabetes/97_19.txt
# Discriminator error:  tensor(0.8259, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1455, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  98
# results/diabetes/98_19.txt
# Discriminator error:  tensor(0.8029, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9709, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  99
# results/diabetes/99_19.txt
# Discriminator error:  tensor(0.6584, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0314, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  100
# results/diabetes/100_19.txt
# Discriminator error:  tensor(0.7192, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8500, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  101
# results/diabetes/101_19.txt
# Discriminator error:  tensor(1.5469, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6000, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  102
# results/diabetes/102_19.txt
# Discriminator error:  tensor(0.0977, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0620, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  103
# results/diabetes/103_19.txt
# Discriminator error:  tensor(0.4261, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9539, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  104
# results/diabetes/104_19.txt
# Discriminator error:  tensor(0.9543, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4575, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  105
# results/diabetes/105_19.txt
# Discriminator error:  tensor(1.7578, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7537, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  106
# results/diabetes/106_19.txt
# Discriminator error:  tensor(0.5262, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5476, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  107
# results/diabetes/107_19.txt
# Discriminator error:  tensor(0.6917, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4169, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  108
# results/diabetes/108_19.txt
# Discriminator error:  tensor(0.6568, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1193, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  109
# results/diabetes/109_19.txt
# Discriminator error:  tensor(0.3828, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8675, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  110
# results/diabetes/110_19.txt
# Discriminator error:  tensor(0.9760, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6905, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  111
# results/diabetes/111_19.txt
# Discriminator error:  tensor(0.3553, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9570, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  112
# results/diabetes/112_19.txt
# Discriminator error:  tensor(0.8410, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9306, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  113
# results/diabetes/113_19.txt
# Discriminator error:  tensor(0.5978, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3734, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  114
# results/diabetes/114_19.txt
# Discriminator error:  tensor(1.3967, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1193, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  115
# results/diabetes/115_19.txt
# Discriminator error:  tensor(1.2604, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0422, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  116
# results/diabetes/116_19.txt
# Discriminator error:  tensor(0.6894, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2601, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  117
# results/diabetes/117_19.txt
# Discriminator error:  tensor(0.4676, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6826, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  118
# results/diabetes/118_19.txt
# Discriminator error:  tensor(0.2489, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2157, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  119
# results/diabetes/119_19.txt
# Discriminator error:  tensor(0.7808, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1443, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  120
# results/diabetes/120_19.txt
# Discriminator error:  tensor(0.9438, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8938, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  121
# results/diabetes/121_19.txt
# Discriminator error:  tensor(0.3743, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2878, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  122
# results/diabetes/122_19.txt
# Discriminator error:  tensor(0.3653, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.2240, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  123
# results/diabetes/123_19.txt
# Discriminator error:  tensor(0.8158, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0985, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  124
# results/diabetes/124_19.txt
# Discriminator error:  tensor(0.6126, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9691, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  125
# results/diabetes/125_19.txt
# Discriminator error:  tensor(0.5943, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6077, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  126
# results/diabetes/126_19.txt
# Discriminator error:  tensor(1.2536, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.2141, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  127
# results/diabetes/127_19.txt
# Discriminator error:  tensor(1.5236, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1071, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  128
# results/diabetes/128_19.txt
# Discriminator error:  tensor(0.7524, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2756, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  129
# results/diabetes/129_19.txt
# Discriminator error:  tensor(0.4479, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.3089, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  130
# results/diabetes/130_19.txt
# Discriminator error:  tensor(0.0816, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.5056, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  131
# results/diabetes/131_19.txt
# Discriminator error:  tensor(0.5893, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9928, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  132
# results/diabetes/132_19.txt
# Discriminator error:  tensor(1.4007, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8718, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  133
# results/diabetes/133_19.txt
# Discriminator error:  tensor(0.5629, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1226, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  134
# results/diabetes/134_19.txt
# Discriminator error:  tensor(1.1057, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6850, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  135
# results/diabetes/135_19.txt
# Discriminator error:  tensor(0.1045, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.8897, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  136
# results/diabetes/136_19.txt
# Discriminator error:  tensor(0.1772, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(3.0220, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  137
# results/diabetes/137_19.txt
# Discriminator error:  tensor(0.6231, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6212, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  138
# results/diabetes/138_19.txt
# Discriminator error:  tensor(1.6420, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0289, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  139
# results/diabetes/139_19.txt
# Discriminator error:  tensor(0.6569, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.3973, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  140
# results/diabetes/140_19.txt
# Discriminator error:  tensor(1.1015, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4317, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  141
# results/diabetes/141_19.txt
# Discriminator error:  tensor(0.4593, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1067, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  142
# results/diabetes/142_19.txt
# Discriminator error:  tensor(0.3872, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.3242, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  143
# results/diabetes/143_19.txt
# Discriminator error:  tensor(0.4822, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7245, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  144
# results/diabetes/144_19.txt
# Discriminator error:  tensor(0.0850, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(3.9436, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  145
# results/diabetes/145_19.txt
# Discriminator error:  tensor(0.2409, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8060, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  146
# results/diabetes/146_19.txt
# Discriminator error:  tensor(0.6558, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1454, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  147
# results/diabetes/147_19.txt
# Discriminator error:  tensor(0.2237, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4836, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  148
# results/diabetes/148_19.txt
# Discriminator error:  tensor(0.6374, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7213, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  149
# results/diabetes/149_19.txt
# Discriminator error:  tensor(0.5234, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9872, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  150
# results/diabetes/150_19.txt
# Discriminator error:  tensor(0.5399, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5073, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  151
# results/diabetes/151_19.txt
# Discriminator error:  tensor(0.9693, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1024, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  152
# results/diabetes/152_19.txt
# Discriminator error:  tensor(1.2397, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8992, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  153
# results/diabetes/153_19.txt
# Discriminator error:  tensor(0.1957, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.2493, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  154
# results/diabetes/154_19.txt
# Discriminator error:  tensor(0.5670, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6614, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  155
# results/diabetes/155_19.txt
# Discriminator error:  tensor(0.9279, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4175, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  156
# results/diabetes/156_19.txt
# Discriminator error:  tensor(0.3289, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8971, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  157
# results/diabetes/157_19.txt
# Discriminator error:  tensor(0.6796, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4120, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  158
# results/diabetes/158_19.txt
# Discriminator error:  tensor(1.6339, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.8489, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  159
# results/diabetes/159_19.txt
# Discriminator error:  tensor(0.2641, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9111, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  160
# results/diabetes/160_19.txt
# Discriminator error:  tensor(0.3253, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8715, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  161
# results/diabetes/161_19.txt
# Discriminator error:  tensor(0.4494, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.3894, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  162
# results/diabetes/162_19.txt
# Discriminator error:  tensor(0.2730, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7432, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  163
# results/diabetes/163_19.txt
# Discriminator error:  tensor(0.1722, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0785, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  164
# results/diabetes/164_19.txt
# Discriminator error:  tensor(0.2973, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7998, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  165
# results/diabetes/165_19.txt
# Discriminator error:  tensor(0.4910, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4155, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  166
# results/diabetes/166_19.txt
# Discriminator error:  tensor(0.0401, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(4.3047, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  167
# results/diabetes/167_19.txt
# Discriminator error:  tensor(0.4636, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6248, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  168
# results/diabetes/168_19.txt
# Discriminator error:  tensor(0.0584, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(3.7858, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  169
# results/diabetes/169_19.txt
# Discriminator error:  tensor(0.7670, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6050, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  170
# results/diabetes/170_19.txt
# Discriminator error:  tensor(4.9438, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1226, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  171
# results/diabetes/171_19.txt
# Discriminator error:  tensor(0.5446, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8600, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  172
# results/diabetes/172_19.txt
# Discriminator error:  tensor(0.9344, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7908, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  173
# results/diabetes/173_19.txt
# Discriminator error:  tensor(0.4612, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0269, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  174
# results/diabetes/174_19.txt
# Discriminator error:  tensor(0.6553, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1049, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  175
# results/diabetes/175_19.txt
# Discriminator error:  tensor(0.1144, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.9571, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  176
# results/diabetes/176_19.txt
# Discriminator error:  tensor(2.7166, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5079, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  177
# results/diabetes/177_19.txt
# Discriminator error:  tensor(0.4291, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5939, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  178
# results/diabetes/178_19.txt
# Discriminator error:  tensor(2.0547, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.5461, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  179
# results/diabetes/179_19.txt
# Discriminator error:  tensor(2.4273, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0525, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  180
# results/diabetes/180_19.txt
# Discriminator error:  tensor(0.2258, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.6933, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  181
# results/diabetes/181_19.txt
# Discriminator error:  tensor(2.3651, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4163, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  182
# results/diabetes/182_19.txt
# Discriminator error:  tensor(2.2309, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.3765, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  183
# results/diabetes/183_19.txt
# Discriminator error:  tensor(0.9193, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3644, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  184
# results/diabetes/184_19.txt
# Discriminator error:  tensor(0.4542, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(3.2637, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  185
# results/diabetes/185_19.txt
# Discriminator error:  tensor(0.6569, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5021, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  186
# results/diabetes/186_19.txt
# Discriminator error:  tensor(1.0398, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.2277, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  187
# results/diabetes/187_19.txt
# Discriminator error:  tensor(1.4535, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.4999, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  188
# results/diabetes/188_19.txt
# Discriminator error:  tensor(0.8935, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.4482, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  189
# results/diabetes/189_19.txt
# Discriminator error:  tensor(0.8711, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(3.1336, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  190
# results/diabetes/190_19.txt
# Discriminator error:  tensor(1.3578, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(3.0624, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  191
# results/diabetes/191_19.txt
# Discriminator error:  tensor(1.5344, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.9398, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  192
# results/diabetes/192_19.txt
# Discriminator error:  tensor(0.5173, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.7401, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  193
# results/diabetes/193_19.txt
# Discriminator error:  tensor(0.5982, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2013, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  194
# results/diabetes/194_19.txt
# Discriminator error:  tensor(2.0639, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9513, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  195
# results/diabetes/195_19.txt
# Discriminator error:  tensor(0.7510, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6044, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  196
# results/diabetes/196_19.txt
# Discriminator error:  tensor(0.8354, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6437, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  197
# results/diabetes/197_19.txt
# Discriminator error:  tensor(0.4718, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8626, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  198
# results/diabetes/198_19.txt
# Discriminator error:  tensor(0.2976, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5773, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  199
# results/diabetes/199_19.txt
# Discriminator error:  tensor(0.4145, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.2689, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  200
# results/diabetes/200_19.txt
# Discriminator error:  tensor(0.4040, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(3.0846, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  201
# results/diabetes/201_19.txt
# Discriminator error:  tensor(0.2251, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0767, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  202
# results/diabetes/202_19.txt
# Discriminator error:  tensor(0.8057, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8414, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  203
# results/diabetes/203_19.txt
# Discriminator error:  tensor(0.4818, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4029, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  204
# results/diabetes/204_19.txt
# Discriminator error:  tensor(1.8539, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3104, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  205
# results/diabetes/205_19.txt
# Discriminator error:  tensor(0.6277, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4424, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  206
# results/diabetes/206_19.txt
# Discriminator error:  tensor(1.3457, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0990, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  207
# results/diabetes/207_19.txt
# Discriminator error:  tensor(0.9193, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6236, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  208
# results/diabetes/208_19.txt
# Discriminator error:  tensor(0.8286, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1162, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  209
# results/diabetes/209_19.txt
# Discriminator error:  tensor(0.8549, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4573, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  210
# results/diabetes/210_19.txt
# Discriminator error:  tensor(0.6944, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2331, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  211
# results/diabetes/211_19.txt
# Discriminator error:  tensor(0.4221, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6293, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  212
# results/diabetes/212_19.txt
# Discriminator error:  tensor(0.8221, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3654, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  213
# results/diabetes/213_19.txt
# Discriminator error:  tensor(0.4850, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6480, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  214
# results/diabetes/214_19.txt
# Discriminator error:  tensor(0.4967, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6197, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  215
# results/diabetes/215_19.txt
# Discriminator error:  tensor(0.9824, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9741, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  216
# results/diabetes/216_19.txt
# Discriminator error:  tensor(1.0140, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4514, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  217
# results/diabetes/217_19.txt
# Discriminator error:  tensor(0.8767, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3862, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  218
# results/diabetes/218_19.txt
# Discriminator error:  tensor(0.5610, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9924, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  219
# results/diabetes/219_19.txt
# Discriminator error:  tensor(0.5925, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4484, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  220
# results/diabetes/220_19.txt
# Discriminator error:  tensor(0.6106, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0028, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  221
# results/diabetes/221_19.txt
# Discriminator error:  tensor(0.5943, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7964, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  222
# results/diabetes/222_19.txt
# Discriminator error:  tensor(1.5611, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0573, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  223
# results/diabetes/223_19.txt
# Discriminator error:  tensor(1.0750, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0000, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  224
# results/diabetes/224_19.txt
# Discriminator error:  tensor(0.7007, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2581, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  225
# results/diabetes/225_19.txt
# Discriminator error:  tensor(0.8631, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2421, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  226
# results/diabetes/226_19.txt
# Discriminator error:  tensor(0.7962, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6408, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  227
# results/diabetes/227_19.txt
# Discriminator error:  tensor(0.2329, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.8041, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  228
# results/diabetes/228_19.txt
# Discriminator error:  tensor(0.3620, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0744, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  229
# results/diabetes/229_19.txt
# Discriminator error:  tensor(0.3298, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9903, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  230
# results/diabetes/230_19.txt
# Discriminator error:  tensor(0.8644, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.3838, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  231
# results/diabetes/231_19.txt
# Discriminator error:  tensor(0.4311, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.4494, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  232
# results/diabetes/232_19.txt
# Discriminator error:  tensor(0.3453, device='cuda:0', grad_fn=<AddBackward0>)
# ...
# Generator error:  tensor(0.6194, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1424
# results/diabetes/1424_19.txt
# Discriminator error:  tensor(0.9414, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8023, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1425
# results/diabetes/1425_19.txt
# Discriminator error:  tensor(1.4457, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0418, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1426
# results/diabetes/1426_19.txt
# Discriminator error:  tensor(2.0685, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7477, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1427
# results/diabetes/1427_19.txt
# Discriminator error:  tensor(0.8503, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3110, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1428
# results/diabetes/1428_19.txt
# Discriminator error:  tensor(1.2934, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7325, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1429
# results/diabetes/1429_19.txt
# Discriminator error:  tensor(1.8056, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1281, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1430
# results/diabetes/1430_19.txt
# Discriminator error:  tensor(1.1276, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0006, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1431
# results/diabetes/1431_19.txt
# Discriminator error:  tensor(1.3859, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8265, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1432
# results/diabetes/1432_19.txt
# Discriminator error:  tensor(1.8649, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8741, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1433
# results/diabetes/1433_19.txt
# Discriminator error:  tensor(1.7354, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9982, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1434
# results/diabetes/1434_19.txt
# Discriminator error:  tensor(1.0765, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5276, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1435
# results/diabetes/1435_19.txt
# Discriminator error:  tensor(1.9560, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7587, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1436
# results/diabetes/1436_19.txt
# Discriminator error:  tensor(1.5858, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8279, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1437
# results/diabetes/1437_19.txt
# Discriminator error:  tensor(0.9846, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8814, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1438
# results/diabetes/1438_19.txt
# Discriminator error:  tensor(1.0692, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8027, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1439
# results/diabetes/1439_19.txt
# Discriminator error:  tensor(1.4261, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7973, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1440
# results/diabetes/1440_19.txt
# Discriminator error:  tensor(1.2002, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8949, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1441
# results/diabetes/1441_19.txt
# Discriminator error:  tensor(1.3215, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9024, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1442
# results/diabetes/1442_19.txt
# Discriminator error:  tensor(1.4342, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8691, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1443
# results/diabetes/1443_19.txt
# Discriminator error:  tensor(1.3022, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0833, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1444
# results/diabetes/1444_19.txt
# Discriminator error:  tensor(1.4865, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7452, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1445
# results/diabetes/1445_19.txt
# Discriminator error:  tensor(1.2815, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1502, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1446
# results/diabetes/1446_19.txt
# Discriminator error:  tensor(1.1384, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7697, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1447
# results/diabetes/1447_19.txt
# Discriminator error:  tensor(1.2118, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6122, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1448
# results/diabetes/1448_19.txt
# Discriminator error:  tensor(1.2745, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9723, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1449
# results/diabetes/1449_19.txt
# Discriminator error:  tensor(1.2893, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0061, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1450
# results/diabetes/1450_19.txt
# Discriminator error:  tensor(1.3458, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0702, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1451
# results/diabetes/1451_19.txt
# Discriminator error:  tensor(1.5910, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5613, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1452
# results/diabetes/1452_19.txt
# Discriminator error:  tensor(1.1815, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5724, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1453
# results/diabetes/1453_19.txt
# Discriminator error:  tensor(1.3030, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7987, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1454
# results/diabetes/1454_19.txt
# Discriminator error:  tensor(1.4628, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1032, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1455
# results/diabetes/1455_19.txt
# Discriminator error:  tensor(1.3862, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7140, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1456
# results/diabetes/1456_19.txt
# Discriminator error:  tensor(1.2519, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0362, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1457
# results/diabetes/1457_19.txt
# Discriminator error:  tensor(1.4120, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9446, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1458
# results/diabetes/1458_19.txt
# Discriminator error:  tensor(1.5173, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9458, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1459
# results/diabetes/1459_19.txt
# Discriminator error:  tensor(1.0620, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6727, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1460
# results/diabetes/1460_19.txt
# Discriminator error:  tensor(1.3519, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8346, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1461
# results/diabetes/1461_19.txt
# Discriminator error:  tensor(0.9876, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5834, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1462
# results/diabetes/1462_19.txt
# Discriminator error:  tensor(0.9472, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7040, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1463
# results/diabetes/1463_19.txt
# Discriminator error:  tensor(1.2481, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9827, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1464
# results/diabetes/1464_19.txt
# Discriminator error:  tensor(1.4656, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5701, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1465
# results/diabetes/1465_19.txt
# Discriminator error:  tensor(1.0858, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7506, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1466
# results/diabetes/1466_19.txt
# Discriminator error:  tensor(1.2735, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9684, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1467
# results/diabetes/1467_19.txt
# Discriminator error:  tensor(1.5097, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0013, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1468
# results/diabetes/1468_19.txt
# Discriminator error:  tensor(1.1187, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7752, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1469
# results/diabetes/1469_19.txt
# Discriminator error:  tensor(1.3191, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9379, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1470
# results/diabetes/1470_19.txt
# Discriminator error:  tensor(0.9802, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9882, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1471
# results/diabetes/1471_19.txt
# Discriminator error:  tensor(1.6393, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9491, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1472
# results/diabetes/1472_19.txt
# Discriminator error:  tensor(1.0958, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7401, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1473
# results/diabetes/1473_19.txt
# Discriminator error:  tensor(1.2125, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0074, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1474
# results/diabetes/1474_19.txt
# Discriminator error:  tensor(1.0633, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9986, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1475
# results/diabetes/1475_19.txt
# Discriminator error:  tensor(1.0494, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8779, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1476
# results/diabetes/1476_19.txt
# Discriminator error:  tensor(0.9844, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0855, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1477
# results/diabetes/1477_19.txt
# Discriminator error:  tensor(1.4455, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3006, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1478
# results/diabetes/1478_19.txt
# Discriminator error:  tensor(1.2204, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8935, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1479
# results/diabetes/1479_19.txt
# Discriminator error:  tensor(1.1067, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0418, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1480
# results/diabetes/1480_19.txt
# Discriminator error:  tensor(1.5704, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8948, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1481
# results/diabetes/1481_19.txt
# Discriminator error:  tensor(1.1643, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2117, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1482
# results/diabetes/1482_19.txt
# Discriminator error:  tensor(1.3615, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9448, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1483
# results/diabetes/1483_19.txt
# Discriminator error:  tensor(1.7341, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8396, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1484
# results/diabetes/1484_19.txt
# Discriminator error:  tensor(1.3310, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0227, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1485
# results/diabetes/1485_19.txt
# Discriminator error:  tensor(1.3910, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6726, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1486
# results/diabetes/1486_19.txt
# Discriminator error:  tensor(1.1080, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0829, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1487
# results/diabetes/1487_19.txt
# Discriminator error:  tensor(1.4639, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9545, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1488
# results/diabetes/1488_19.txt
# Discriminator error:  tensor(1.0201, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8881, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1489
# results/diabetes/1489_19.txt
# Discriminator error:  tensor(1.2290, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0926, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1490
# results/diabetes/1490_19.txt
# Discriminator error:  tensor(1.4099, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9431, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1491
# results/diabetes/1491_19.txt
# Discriminator error:  tensor(1.4546, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8213, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1492
# results/diabetes/1492_19.txt
# Discriminator error:  tensor(1.4723, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8523, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1493
# results/diabetes/1493_19.txt
# Discriminator error:  tensor(1.2799, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3224, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1494
# results/diabetes/1494_19.txt
# Discriminator error:  tensor(0.9633, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6809, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1495
# results/diabetes/1495_19.txt
# Discriminator error:  tensor(1.2174, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7831, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1496
# results/diabetes/1496_19.txt
# Discriminator error:  tensor(0.8761, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7582, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1497
# results/diabetes/1497_19.txt
# Discriminator error:  tensor(1.2829, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0833, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1498
# results/diabetes/1498_19.txt
# Discriminator error:  tensor(1.0443, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8536, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1499
# results/diabetes/1499_19.txt
# Discriminator error:  tensor(0.9677, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0336, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)

# %%
results_dir = f"models/{file_name.split('/')[-1].split('.')[0]}"
os.mkdir(results_dir)

# %%
print(epoch)
torch.save({
            'epoch': epoch,
            'model_state_dict': generator.state_dict(),
            'optimizer_state_dict': g_optimizer.state_dict(),
            'model_attributes': {'out_features': dataAtts.class_len},
            'loss': loss
            # }, "models/generator" + dataAtts.fname + "_" + str(epoch) + ".pt")
            }, results_dir + "/generator" + dataAtts.fname + "_" + str(epoch) + ".pt")

torch.save({
            'epoch': epoch,
            'model_state_dict': discriminator.state_dict(),
            'optimizer_state_dict': d_optimizer.state_dict(),
            'loss': loss
            # }, "models/discriminator" + dataAtts.fname + "_" + str(epoch) + ".pt")
            }, results_dir + "/discriminator" + dataAtts.fname + "_" + str(epoch) + ".pt")
# Out:
# 1499

# %%
plt.plot(d_error_plt, 'b')
plt.plot(g_error_plt, 'r')
filename = "results/" + dataAtts.fname + "/" + "error_growth.txt"
file = open(filename, "w")
file.write("Discriminator error: " + str(d_error_plt) + "\n")
file.write("\n\n\n")
file.write("Generator error: " + str(g_error_plt) + "\n")
file.close()

plt.savefig('images/'+ dataAtts.fname + "/"+ 'error.png')
plt.show()
plt.clf()
