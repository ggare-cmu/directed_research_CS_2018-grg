# %%
import torch
import pandas as pd
from torch import nn, optim
from torch.autograd.variable import Variable
from torchvision import transforms, datasets
from data_treatment import DataSetGRG, DataAtts
from discriminator import *
from generator import *
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt
import glob

# %%
# Noise
def noise(size):
    n = Variable(torch.randn(size, 100))
    if torch.cuda.is_available(): 
        return n.cuda() 
    return n

# %%
files_dropdown = widgets.Dropdown(
    # options=glob.glob("original_data/*.csv"),
    options=glob.glob("grg_data/*.csv"),
    description='File:',
    # value = 'original_data/diabetes_escalonated.csv',
    disabled=False,
)
display(files_dropdown)
# Out:
# Dropdown(description='File:', options=('grg_data/diabetes-small3_TrainUpsampledPatient.csv', 'grg_data/diabete…

# %%
file_name=files_dropdown.value
dataAtts = DataAtts(file_name)

# %%
def train_generator(optimizer, fake_data):
    # 2. Train Generator
    # Reset gradients
    optimizer.zero_grad()
    # Sample noise and generate fake data
    prediction = discriminator(fake_data)
    # Calculate error and backpropagate
    error = loss(prediction, real_data_target(prediction.size(0)))
    error.backward()
    # Update weights with gradients
    optimizer.step()
    # Return error
    return error

def train_discriminator(optimizer, real_data, fake_data):
    # Reset gradients
    optimizer.zero_grad()
    
    # 1.1 Train on Real Data
    prediction_real = discriminator(real_data)
    # Calculate error and backpropagate
    error_real = loss(prediction_real, real_data_target(real_data.size(0)))
    error_real.backward()

    # 1.2 Train on Fake Data
    prediction_fake = discriminator(fake_data)
    # Calculate error and backpropagate
    error_fake = loss(prediction_fake, fake_data_target(real_data.size(0)))
    error_fake.backward()
    
    # 1.3 Update weights with gradients
    optimizer.step()
    
    # Return error
    return error_real + error_fake, prediction_real, prediction_fake

# %%
def real_data_target(size):
    '''
    Tensor containing ones, with shape = size
    '''
    data = Variable(torch.ones(size, 1))
    if torch.cuda.is_available(): return data.cuda()
    return data

def fake_data_target(size):
    '''
    Tensor containing zeros, with shape = size
    '''
    data = Variable(torch.zeros(size, 1))
    if torch.cuda.is_available(): return data.cuda()
    return data

# %%
lr = 0.0002
#lr= 0.0002
batch_size = 5
# num_epochs = 106
num_epochs = 1500
print_interval = 10
loss = nn.BCELoss()

# %%
# discriminator = DiscriminatorNet(dataAtts.class_len)
discriminator = DiscriminatorNet(dataAtts.class_len,  hidden_layers=[512, 256])
generator = GeneratorNet(dataAtts.class_len,  hidden_layers=[512, 256])
if torch.cuda.is_available():
    discriminator.cuda()
    generator.cuda()
d_optimizer = optim.Adam(discriminator.parameters(), lr=lr)
g_optimizer = optim.Adam(generator.parameters(), lr=lr)

# %%
d_error_plt = [0]
g_error_plt = [0]

generated_points = []

# %%
database = DataSetGRG(csv_file=file_name, root_dir=".")

data_loader = torch.utils.data.DataLoader(database, batch_size=batch_size, shuffle=True)
num_batches = len(data_loader)

# %%
for epoch in range(num_epochs):
    print("Epoch ", epoch)

    for n_batch, real_batch in enumerate(data_loader):
        # 1. Train Discriminator
        real_data = Variable(real_batch).float()
        if torch.cuda.is_available(): 
            real_data = real_data.cuda()
        # Generate fake data
        fake_data = generator(noise(real_data.size(0))).detach()
        # Train D
        d_error, d_pred_real, d_pred_fake = train_discriminator(d_optimizer,
                                                                real_data, fake_data)

        # 2. Train Generator
        # Generate fake data
        fake_data = generator(noise(real_batch.size(0)))
        generated_points.append(fake_data)
        # Train G
        g_error = train_generator(g_optimizer, fake_data)

        # Display Progress

        #if (n_batch) % print_interval == 0:
    filename = "results/" + dataAtts.fname + "/" + str(epoch) + "_" + str(n_batch) + ".txt"
    print(filename)
    file = open(filename, "w")
    print("Discriminator error: ", d_error)
    print("Generator error: ", g_error)
    print("")

    file.write("Discriminator error: " + str(d_error) + "\n")
    file.write("Generator error: " + str(g_error) + "\n")
    file.write("Points: " + str(fake_data) + "\n\n\n")

    # d_error_plt.append(d_error)
    # g_error_plt.append(g_error)
    d_error_plt.append(d_error.detach().cpu().numpy())
    g_error_plt.append(g_error.detach().cpu().numpy())
        #     #display.clear_output(True)
        #     # Display Images
        #     test_images = generator(test_noise).data.cpu()
        #     logger.log_images(test_images, num_test_samples, epoch, n_batch, num_batches);
        #     # Display status Logs
        #     #logger.display_status(epoch, num_epochs, n_batch, num_batches, d_error, g_error, d_pred_real, d_pred_fake)
        # # Model Checkpoints
# Out:
# Epoch  0
# results/diabetes/0_19.txt
# Discriminator error:  tensor(0.8057, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5939, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1
# results/diabetes/1_19.txt
# Discriminator error:  tensor(0.8817, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5245, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  2
# results/diabetes/2_19.txt
# Discriminator error:  tensor(0.9729, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4254, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  3
# results/diabetes/3_19.txt
# Discriminator error:  tensor(1.1537, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4197, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  4
# results/diabetes/4_19.txt
# Discriminator error:  tensor(1.1732, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.3752, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  5
# results/diabetes/5_19.txt
# Discriminator error:  tensor(1.2634, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5001, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  6
# results/diabetes/6_19.txt
# Discriminator error:  tensor(1.0594, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5016, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  7
# results/diabetes/7_19.txt
# Discriminator error:  tensor(0.4759, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0821, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  8
# results/diabetes/8_19.txt
# Discriminator error:  tensor(0.8932, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7981, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  9
# results/diabetes/9_19.txt
# Discriminator error:  tensor(1.1185, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6119, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  10
# results/diabetes/10_19.txt
# Discriminator error:  tensor(1.0365, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4481, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  11
# results/diabetes/11_19.txt
# Discriminator error:  tensor(1.0093, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7017, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  12
# results/diabetes/12_19.txt
# Discriminator error:  tensor(0.7084, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6086, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  13
# results/diabetes/13_19.txt
# Discriminator error:  tensor(1.4251, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4898, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  14
# results/diabetes/14_19.txt
# Discriminator error:  tensor(0.6067, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0400, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  15
# results/diabetes/15_19.txt
# Discriminator error:  tensor(1.1382, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4554, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  16
# results/diabetes/16_19.txt
# Discriminator error:  tensor(1.4217, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8017, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  17
# results/diabetes/17_19.txt
# Discriminator error:  tensor(0.4859, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4294, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  18
# results/diabetes/18_19.txt
# Discriminator error:  tensor(0.4968, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0408, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  19
# results/diabetes/19_19.txt
# Discriminator error:  tensor(1.1906, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0330, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  20
# results/diabetes/20_19.txt
# Discriminator error:  tensor(1.3893, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6623, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  21
# results/diabetes/21_19.txt
# Discriminator error:  tensor(0.3552, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3532, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  22
# results/diabetes/22_19.txt
# Discriminator error:  tensor(0.6123, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4291, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  23
# results/diabetes/23_19.txt
# Discriminator error:  tensor(0.6503, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7455, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  24
# results/diabetes/24_19.txt
# Discriminator error:  tensor(1.4581, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8026, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  25
# results/diabetes/25_19.txt
# Discriminator error:  tensor(1.1457, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4674, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  26
# results/diabetes/26_19.txt
# Discriminator error:  tensor(0.7261, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7334, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  27
# results/diabetes/27_19.txt
# Discriminator error:  tensor(1.5486, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4287, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  28
# results/diabetes/28_19.txt
# Discriminator error:  tensor(0.9362, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8787, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  29
# results/diabetes/29_19.txt
# Discriminator error:  tensor(0.2890, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9559, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  30
# results/diabetes/30_19.txt
# Discriminator error:  tensor(0.9611, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5891, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  31
# results/diabetes/31_19.txt
# Discriminator error:  tensor(1.2384, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4488, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  32
# results/diabetes/32_19.txt
# Discriminator error:  tensor(0.4731, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4938, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  33
# results/diabetes/33_19.txt
# Discriminator error:  tensor(1.2349, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7157, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  34
# results/diabetes/34_19.txt
# Discriminator error:  tensor(0.5019, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6283, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  35
# results/diabetes/35_19.txt
# Discriminator error:  tensor(0.5340, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7770, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  36
# results/diabetes/36_19.txt
# Discriminator error:  tensor(0.8951, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0932, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  37
# results/diabetes/37_19.txt
# Discriminator error:  tensor(1.0772, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.7000, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  38
# results/diabetes/38_19.txt
# Discriminator error:  tensor(0.7376, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5816, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  39
# results/diabetes/39_19.txt
# Discriminator error:  tensor(0.4681, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7980, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  40
# results/diabetes/40_19.txt
# Discriminator error:  tensor(0.3402, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7614, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  41
# results/diabetes/41_19.txt
# Discriminator error:  tensor(1.2208, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7580, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  42
# results/diabetes/42_19.txt
# Discriminator error:  tensor(0.2979, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2992, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  43
# results/diabetes/43_19.txt
# Discriminator error:  tensor(1.1102, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4366, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  44
# results/diabetes/44_19.txt
# Discriminator error:  tensor(0.4046, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4640, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  45
# results/diabetes/45_19.txt
# Discriminator error:  tensor(2.5282, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9795, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  46
# results/diabetes/46_19.txt
# Discriminator error:  tensor(4.7397, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4289, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  47
# results/diabetes/47_19.txt
# Discriminator error:  tensor(0.1472, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4829, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  48
# results/diabetes/48_19.txt
# Discriminator error:  tensor(0.8939, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5098, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  49
# results/diabetes/49_19.txt
# Discriminator error:  tensor(1.9331, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.3807, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  50
# results/diabetes/50_19.txt
# Discriminator error:  tensor(1.2343, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5174, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  51
# results/diabetes/51_19.txt
# Discriminator error:  tensor(0.8297, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1130, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  52
# results/diabetes/52_19.txt
# Discriminator error:  tensor(0.5539, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8414, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  53
# results/diabetes/53_19.txt
# Discriminator error:  tensor(1.1105, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9774, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  54
# results/diabetes/54_19.txt
# Discriminator error:  tensor(1.0519, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9773, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  55
# results/diabetes/55_19.txt
# Discriminator error:  tensor(1.3739, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2912, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  56
# results/diabetes/56_19.txt
# Discriminator error:  tensor(0.4288, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2525, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  57
# results/diabetes/57_19.txt
# Discriminator error:  tensor(0.7649, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2742, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  58
# results/diabetes/58_19.txt
# Discriminator error:  tensor(0.8088, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8742, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  59
# results/diabetes/59_19.txt
# Discriminator error:  tensor(0.3372, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.3229, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  60
# results/diabetes/60_19.txt
# Discriminator error:  tensor(0.9784, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0445, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  61
# results/diabetes/61_19.txt
# Discriminator error:  tensor(0.8198, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0374, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  62
# results/diabetes/62_19.txt
# Discriminator error:  tensor(0.9819, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4136, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  63
# results/diabetes/63_19.txt
# Discriminator error:  tensor(0.3514, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1974, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  64
# results/diabetes/64_19.txt
# Discriminator error:  tensor(2.2408, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.1633, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  65
# results/diabetes/65_19.txt
# Discriminator error:  tensor(2.0772, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.1659, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  66
# results/diabetes/66_19.txt
# Discriminator error:  tensor(1.1451, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5231, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  67
# results/diabetes/67_19.txt
# Discriminator error:  tensor(1.2036, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9578, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  68
# results/diabetes/68_19.txt
# Discriminator error:  tensor(0.2411, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5377, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  69
# results/diabetes/69_19.txt
# Discriminator error:  tensor(0.8226, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7111, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  70
# results/diabetes/70_19.txt
# Discriminator error:  tensor(0.7607, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8902, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  71
# results/diabetes/71_19.txt
# Discriminator error:  tensor(0.6813, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8999, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  72
# results/diabetes/72_19.txt
# Discriminator error:  tensor(0.7388, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1957, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  73
# results/diabetes/73_19.txt
# Discriminator error:  tensor(0.4944, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2405, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  74
# results/diabetes/74_19.txt
# Discriminator error:  tensor(0.5299, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0300, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  75
# results/diabetes/75_19.txt
# Discriminator error:  tensor(1.0259, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9828, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  76
# results/diabetes/76_19.txt
# Discriminator error:  tensor(1.3419, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0887, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  77
# results/diabetes/77_19.txt
# Discriminator error:  tensor(0.3938, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4798, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  78
# results/diabetes/78_19.txt
# Discriminator error:  tensor(0.4184, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3738, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  79
# results/diabetes/79_19.txt
# Discriminator error:  tensor(0.4813, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1771, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  80
# results/diabetes/80_19.txt
# Discriminator error:  tensor(0.8736, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9605, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  81
# results/diabetes/81_19.txt
# Discriminator error:  tensor(1.5689, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7067, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  82
# results/diabetes/82_19.txt
# Discriminator error:  tensor(0.3615, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6860, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  83
# results/diabetes/83_19.txt
# Discriminator error:  tensor(1.0122, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5079, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  84
# results/diabetes/84_19.txt
# Discriminator error:  tensor(0.3108, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.5099, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  85
# results/diabetes/85_19.txt
# Discriminator error:  tensor(1.8291, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2724, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  86
# results/diabetes/86_19.txt
# Discriminator error:  tensor(1.3199, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0335, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  87
# results/diabetes/87_19.txt
# Discriminator error:  tensor(2.0245, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6975, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  88
# results/diabetes/88_19.txt
# Discriminator error:  tensor(0.2405, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4133, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  89
# results/diabetes/89_19.txt
# Discriminator error:  tensor(1.0155, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1721, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  90
# results/diabetes/90_19.txt
# Discriminator error:  tensor(0.5482, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6722, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  91
# results/diabetes/91_19.txt
# Discriminator error:  tensor(0.6030, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0085, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  92
# results/diabetes/92_19.txt
# Discriminator error:  tensor(1.5124, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1287, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  93
# results/diabetes/93_19.txt
# Discriminator error:  tensor(0.5939, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1545, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  94
# results/diabetes/94_19.txt
# Discriminator error:  tensor(0.7718, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7564, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  95
# results/diabetes/95_19.txt
# Discriminator error:  tensor(0.3393, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2265, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  96
# results/diabetes/96_19.txt
# Discriminator error:  tensor(2.0823, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9549, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  97
# results/diabetes/97_19.txt
# Discriminator error:  tensor(0.6563, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4500, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  98
# results/diabetes/98_19.txt
# Discriminator error:  tensor(0.3217, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.4147, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  99
# results/diabetes/99_19.txt
# Discriminator error:  tensor(0.5747, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2545, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  100
# results/diabetes/100_19.txt
# Discriminator error:  tensor(0.8843, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8208, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  101
# results/diabetes/101_19.txt
# Discriminator error:  tensor(0.5509, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1910, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  102
# results/diabetes/102_19.txt
# Discriminator error:  tensor(0.8361, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5015, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  103
# results/diabetes/103_19.txt
# Discriminator error:  tensor(0.2456, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6829, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  104
# results/diabetes/104_19.txt
# Discriminator error:  tensor(0.5079, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5011, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  105
# results/diabetes/105_19.txt
# Discriminator error:  tensor(0.8821, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2943, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  106
# results/diabetes/106_19.txt
# Discriminator error:  tensor(1.0445, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8142, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  107
# results/diabetes/107_19.txt
# Discriminator error:  tensor(0.2313, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1543, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  108
# results/diabetes/108_19.txt
# Discriminator error:  tensor(0.6093, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8451, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  109
# results/diabetes/109_19.txt
# Discriminator error:  tensor(1.2452, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6794, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  110
# results/diabetes/110_19.txt
# Discriminator error:  tensor(0.3076, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1889, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  111
# results/diabetes/111_19.txt
# Discriminator error:  tensor(0.4594, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0438, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  112
# results/diabetes/112_19.txt
# Discriminator error:  tensor(0.8217, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7674, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  113
# results/diabetes/113_19.txt
# Discriminator error:  tensor(0.4148, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3140, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  114
# results/diabetes/114_19.txt
# Discriminator error:  tensor(1.1144, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3574, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  115
# results/diabetes/115_19.txt
# Discriminator error:  tensor(0.4221, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4828, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  116
# results/diabetes/116_19.txt
# Discriminator error:  tensor(0.4527, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3115, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  117
# results/diabetes/117_19.txt
# Discriminator error:  tensor(0.3539, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.7980, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  118
# results/diabetes/118_19.txt
# Discriminator error:  tensor(0.2924, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3679, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  119
# results/diabetes/119_19.txt
# Discriminator error:  tensor(1.2936, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5876, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  120
# results/diabetes/120_19.txt
# Discriminator error:  tensor(0.9118, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1889, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  121
# results/diabetes/121_19.txt
# Discriminator error:  tensor(0.3970, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9769, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  122
# results/diabetes/122_19.txt
# Discriminator error:  tensor(0.2676, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.9522, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  123
# results/diabetes/123_19.txt
# Discriminator error:  tensor(0.1828, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8110, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  124
# results/diabetes/124_19.txt
# Discriminator error:  tensor(0.3940, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7364, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  125
# results/diabetes/125_19.txt
# Discriminator error:  tensor(2.2180, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3667, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  126
# results/diabetes/126_19.txt
# Discriminator error:  tensor(1.4484, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3158, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  127
# results/diabetes/127_19.txt
# Discriminator error:  tensor(0.8971, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9510, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  128
# results/diabetes/128_19.txt
# Discriminator error:  tensor(0.8909, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8237, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  129
# results/diabetes/129_19.txt
# Discriminator error:  tensor(0.1773, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5524, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  130
# results/diabetes/130_19.txt
# Discriminator error:  tensor(0.1982, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8929, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  131
# results/diabetes/131_19.txt
# Discriminator error:  tensor(0.9536, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5762, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  132
# results/diabetes/132_19.txt
# Discriminator error:  tensor(0.3637, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2215, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  133
# results/diabetes/133_19.txt
# Discriminator error:  tensor(0.5643, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2105, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  134
# results/diabetes/134_19.txt
# Discriminator error:  tensor(0.2592, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0702, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  135
# results/diabetes/135_19.txt
# Discriminator error:  tensor(0.1960, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.6086, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  136
# results/diabetes/136_19.txt
# Discriminator error:  tensor(0.8829, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7949, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  137
# results/diabetes/137_19.txt
# Discriminator error:  tensor(0.3949, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.2653, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  138
# results/diabetes/138_19.txt
# Discriminator error:  tensor(0.3447, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5104, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  139
# results/diabetes/139_19.txt
# Discriminator error:  tensor(0.0832, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(3.0864, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  140
# results/diabetes/140_19.txt
# Discriminator error:  tensor(0.3988, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4354, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  141
# results/diabetes/141_19.txt
# Discriminator error:  tensor(0.7066, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0617, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  142
# results/diabetes/142_19.txt
# Discriminator error:  tensor(0.2468, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5442, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  143
# results/diabetes/143_19.txt
# Discriminator error:  tensor(0.6437, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6057, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  144
# results/diabetes/144_19.txt
# Discriminator error:  tensor(0.5420, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2885, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  145
# results/diabetes/145_19.txt
# Discriminator error:  tensor(2.3100, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9163, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  146
# results/diabetes/146_19.txt
# Discriminator error:  tensor(0.8959, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0554, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  147
# results/diabetes/147_19.txt
# Discriminator error:  tensor(1.1594, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8372, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  148
# results/diabetes/148_19.txt
# Discriminator error:  tensor(0.8437, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0196, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  149
# results/diabetes/149_19.txt
# Discriminator error:  tensor(0.9797, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6013, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  150
# results/diabetes/150_19.txt
# Discriminator error:  tensor(1.1768, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5819, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  151
# results/diabetes/151_19.txt
# Discriminator error:  tensor(1.0386, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5845, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  152
# results/diabetes/152_19.txt
# Discriminator error:  tensor(1.5512, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2751, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  153
# results/diabetes/153_19.txt
# Discriminator error:  tensor(1.9289, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1347, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  154
# results/diabetes/154_19.txt
# Discriminator error:  tensor(0.5743, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1509, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  155
# results/diabetes/155_19.txt
# Discriminator error:  tensor(1.2876, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2090, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  156
# results/diabetes/156_19.txt
# Discriminator error:  tensor(0.8543, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3319, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  157
# results/diabetes/157_19.txt
# Discriminator error:  tensor(0.5574, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2406, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  158
# results/diabetes/158_19.txt
# Discriminator error:  tensor(2.1480, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4352, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  159
# results/diabetes/159_19.txt
# Discriminator error:  tensor(1.5113, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5343, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  160
# results/diabetes/160_19.txt
# Discriminator error:  tensor(1.5358, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8903, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  161
# results/diabetes/161_19.txt
# Discriminator error:  tensor(0.4073, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1840, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  162
# results/diabetes/162_19.txt
# Discriminator error:  tensor(1.2337, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8802, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  163
# results/diabetes/163_19.txt
# Discriminator error:  tensor(1.0785, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3115, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  164
# results/diabetes/164_19.txt
# Discriminator error:  tensor(0.9802, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8141, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  165
# results/diabetes/165_19.txt
# Discriminator error:  tensor(1.0438, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1714, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  166
# results/diabetes/166_19.txt
# Discriminator error:  tensor(0.9898, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0158, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  167
# results/diabetes/167_19.txt
# Discriminator error:  tensor(1.1395, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6026, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  168
# results/diabetes/168_19.txt
# Discriminator error:  tensor(1.5404, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2711, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  169
# results/diabetes/169_19.txt
# Discriminator error:  tensor(1.2398, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7177, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  170
# results/diabetes/170_19.txt
# Discriminator error:  tensor(0.9740, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1517, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  171
# results/diabetes/171_19.txt
# Discriminator error:  tensor(0.5669, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1172, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  172
# results/diabetes/172_19.txt
# Discriminator error:  tensor(0.9877, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6908, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  173
# results/diabetes/173_19.txt
# Discriminator error:  tensor(0.6159, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3459, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  174
# results/diabetes/174_19.txt
# Discriminator error:  tensor(1.3169, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4292, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  175
# results/diabetes/175_19.txt
# Discriminator error:  tensor(0.2878, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3594, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  176
# results/diabetes/176_19.txt
# Discriminator error:  tensor(0.7628, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8405, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  177
# results/diabetes/177_19.txt
# Discriminator error:  tensor(1.7067, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5075, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  178
# results/diabetes/178_19.txt
# Discriminator error:  tensor(1.0498, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4875, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  179
# results/diabetes/179_19.txt
# Discriminator error:  tensor(1.2421, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7677, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  180
# results/diabetes/180_19.txt
# Discriminator error:  tensor(1.1112, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4864, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  181
# results/diabetes/181_19.txt
# Discriminator error:  tensor(0.8332, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4230, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  182
# results/diabetes/182_19.txt
# Discriminator error:  tensor(1.5506, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0782, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  183
# results/diabetes/183_19.txt
# Discriminator error:  tensor(0.6407, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6756, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  184
# results/diabetes/184_19.txt
# Discriminator error:  tensor(1.6473, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1803, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  185
# results/diabetes/185_19.txt
# Discriminator error:  tensor(0.9387, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4896, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  186
# results/diabetes/186_19.txt
# Discriminator error:  tensor(0.7947, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4923, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  187
# results/diabetes/187_19.txt
# Discriminator error:  tensor(0.9805, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0576, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  188
# results/diabetes/188_19.txt
# Discriminator error:  tensor(0.9411, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9859, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  189
# results/diabetes/189_19.txt
# Discriminator error:  tensor(1.4664, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8217, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  190
# results/diabetes/190_19.txt
# Discriminator error:  tensor(1.0531, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6657, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  191
# results/diabetes/191_19.txt
# Discriminator error:  tensor(1.8198, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7646, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  192
# results/diabetes/192_19.txt
# Discriminator error:  tensor(0.7211, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5714, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  193
# results/diabetes/193_19.txt
# Discriminator error:  tensor(0.7934, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5420, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  194
# results/diabetes/194_19.txt
# Discriminator error:  tensor(1.4398, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5868, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  195
# results/diabetes/195_19.txt
# Discriminator error:  tensor(1.2292, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8457, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  196
# results/diabetes/196_19.txt
# Discriminator error:  tensor(0.6138, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8682, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  197
# results/diabetes/197_19.txt
# Discriminator error:  tensor(0.9073, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0794, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  198
# results/diabetes/198_19.txt
# Discriminator error:  tensor(2.2198, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5922, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  199
# results/diabetes/199_19.txt
# Discriminator error:  tensor(1.5241, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8560, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  200
# results/diabetes/200_19.txt
# Discriminator error:  tensor(1.0139, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6684, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  201
# results/diabetes/201_19.txt
# Discriminator error:  tensor(1.4723, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1936, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  202
# results/diabetes/202_19.txt
# Discriminator error:  tensor(1.7793, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9465, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  203
# results/diabetes/203_19.txt
# Discriminator error:  tensor(0.8544, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6791, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  204
# results/diabetes/204_19.txt
# Discriminator error:  tensor(0.8367, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0761, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  205
# results/diabetes/205_19.txt
# Discriminator error:  tensor(0.3755, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5003, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  206
# results/diabetes/206_19.txt
# Discriminator error:  tensor(0.3891, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4397, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  207
# results/diabetes/207_19.txt
# Discriminator error:  tensor(1.1583, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6785, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  208
# results/diabetes/208_19.txt
# Discriminator error:  tensor(0.9912, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8822, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  209
# results/diabetes/209_19.txt
# Discriminator error:  tensor(0.8242, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5793, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  210
# results/diabetes/210_19.txt
# Discriminator error:  tensor(1.3868, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7251, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  211
# results/diabetes/211_19.txt
# Discriminator error:  tensor(0.7432, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2578, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  212
# results/diabetes/212_19.txt
# Discriminator error:  tensor(1.6794, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5389, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  213
# results/diabetes/213_19.txt
# Discriminator error:  tensor(1.0249, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5704, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  214
# results/diabetes/214_19.txt
# Discriminator error:  tensor(1.1076, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8289, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  215
# results/diabetes/215_19.txt
# Discriminator error:  tensor(1.0900, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5319, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  216
# results/diabetes/216_19.txt
# Discriminator error:  tensor(1.3999, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0649, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  217
# results/diabetes/217_19.txt
# Discriminator error:  tensor(1.3797, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9503, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  218
# results/diabetes/218_19.txt
# Discriminator error:  tensor(1.0522, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4344, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  219
# results/diabetes/219_19.txt
# Discriminator error:  tensor(0.4019, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1106, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  220
# results/diabetes/220_19.txt
# Discriminator error:  tensor(0.9344, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6268, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  221
# results/diabetes/221_19.txt
# Discriminator error:  tensor(1.1778, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9152, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  222
# results/diabetes/222_19.txt
# Discriminator error:  tensor(1.3711, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1500, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  223
# results/diabetes/223_19.txt
# Discriminator error:  tensor(1.0674, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2333, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  224
# results/diabetes/224_19.txt
# Discriminator error:  tensor(1.4230, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5377, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  225
# results/diabetes/225_19.txt
# Discriminator error:  tensor(1.0330, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9044, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  226
# results/diabetes/226_19.txt
# Discriminator error:  tensor(1.3903, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4168, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  227
# results/diabetes/227_19.txt
# Discriminator error:  tensor(0.5459, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5089, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  228
# results/diabetes/228_19.txt
# Discriminator error:  tensor(0.7994, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1141, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  229
# results/diabetes/229_19.txt
# Discriminator error:  tensor(0.9280, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9048, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  230
# results/diabetes/230_19.txt
# Discriminator error:  tensor(1.1994, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1608, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  231
# results/diabetes/231_19.txt
# Discriminator error:  tensor(1.8536, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9634, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  232
# results/diabetes/232_19.txt
# Discriminator error:  tensor(1.1707, device='cuda:0', grad_fn=<AddBackward0>)
# ...
# Generator error:  tensor(0.7006, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1424
# results/diabetes/1424_19.txt
# Discriminator error:  tensor(1.1411, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7681, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1425
# results/diabetes/1425_19.txt
# Discriminator error:  tensor(1.2427, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8321, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1426
# results/diabetes/1426_19.txt
# Discriminator error:  tensor(1.2864, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9574, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1427
# results/diabetes/1427_19.txt
# Discriminator error:  tensor(1.2739, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5789, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1428
# results/diabetes/1428_19.txt
# Discriminator error:  tensor(1.2920, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6616, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1429
# results/diabetes/1429_19.txt
# Discriminator error:  tensor(1.0751, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8519, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1430
# results/diabetes/1430_19.txt
# Discriminator error:  tensor(1.3763, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8999, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1431
# results/diabetes/1431_19.txt
# Discriminator error:  tensor(1.4557, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7902, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1432
# results/diabetes/1432_19.txt
# Discriminator error:  tensor(1.2975, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9358, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1433
# results/diabetes/1433_19.txt
# Discriminator error:  tensor(1.4525, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8478, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1434
# results/diabetes/1434_19.txt
# Discriminator error:  tensor(1.2213, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6284, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1435
# results/diabetes/1435_19.txt
# Discriminator error:  tensor(1.1065, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9827, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1436
# results/diabetes/1436_19.txt
# Discriminator error:  tensor(1.1048, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8676, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1437
# results/diabetes/1437_19.txt
# Discriminator error:  tensor(1.3574, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9391, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1438
# results/diabetes/1438_19.txt
# Discriminator error:  tensor(1.3060, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0502, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1439
# results/diabetes/1439_19.txt
# Discriminator error:  tensor(1.3127, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9145, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1440
# results/diabetes/1440_19.txt
# Discriminator error:  tensor(1.2632, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8573, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1441
# results/diabetes/1441_19.txt
# Discriminator error:  tensor(1.1227, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8633, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1442
# results/diabetes/1442_19.txt
# Discriminator error:  tensor(1.5308, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9315, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1443
# results/diabetes/1443_19.txt
# Discriminator error:  tensor(0.9321, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6112, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1444
# results/diabetes/1444_19.txt
# Discriminator error:  tensor(1.4893, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1759, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1445
# results/diabetes/1445_19.txt
# Discriminator error:  tensor(1.3459, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6216, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1446
# results/diabetes/1446_19.txt
# Discriminator error:  tensor(1.4890, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1447
# results/diabetes/1447_19.txt
# Discriminator error:  tensor(1.2237, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8141, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1448
# results/diabetes/1448_19.txt
# Discriminator error:  tensor(1.6035, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5888, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1449
# results/diabetes/1449_19.txt
# Discriminator error:  tensor(1.4022, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9677, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1450
# results/diabetes/1450_19.txt
# Discriminator error:  tensor(1.3294, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9384, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1451
# results/diabetes/1451_19.txt
# Discriminator error:  tensor(1.4100, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8255, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1452
# results/diabetes/1452_19.txt
# Discriminator error:  tensor(1.3620, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9440, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1453
# results/diabetes/1453_19.txt
# Discriminator error:  tensor(1.1175, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9312, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1454
# results/diabetes/1454_19.txt
# Discriminator error:  tensor(1.0701, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8606, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1455
# results/diabetes/1455_19.txt
# Discriminator error:  tensor(1.1024, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8794, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1456
# results/diabetes/1456_19.txt
# Discriminator error:  tensor(1.5641, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0466, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1457
# results/diabetes/1457_19.txt
# Discriminator error:  tensor(1.2786, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7021, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1458
# results/diabetes/1458_19.txt
# Discriminator error:  tensor(1.3937, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7485, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1459
# results/diabetes/1459_19.txt
# Discriminator error:  tensor(1.1737, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9764, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1460
# results/diabetes/1460_19.txt
# Discriminator error:  tensor(1.3080, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8508, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1461
# results/diabetes/1461_19.txt
# Discriminator error:  tensor(1.2178, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0282, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1462
# results/diabetes/1462_19.txt
# Discriminator error:  tensor(1.6915, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8231, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1463
# results/diabetes/1463_19.txt
# Discriminator error:  tensor(1.6343, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6371, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1464
# results/diabetes/1464_19.txt
# Discriminator error:  tensor(1.2926, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7667, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1465
# results/diabetes/1465_19.txt
# Discriminator error:  tensor(1.6672, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0484, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1466
# results/diabetes/1466_19.txt
# Discriminator error:  tensor(1.0771, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6232, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1467
# results/diabetes/1467_19.txt
# Discriminator error:  tensor(1.4182, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8751, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1468
# results/diabetes/1468_19.txt
# Discriminator error:  tensor(2.0230, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8778, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1469
# results/diabetes/1469_19.txt
# Discriminator error:  tensor(1.7199, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0408, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1470
# results/diabetes/1470_19.txt
# Discriminator error:  tensor(1.2711, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6788, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1471
# results/diabetes/1471_19.txt
# Discriminator error:  tensor(1.3441, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0812, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1472
# results/diabetes/1472_19.txt
# Discriminator error:  tensor(1.3757, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9060, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1473
# results/diabetes/1473_19.txt
# Discriminator error:  tensor(1.2956, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7992, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1474
# results/diabetes/1474_19.txt
# Discriminator error:  tensor(1.0681, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7572, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1475
# results/diabetes/1475_19.txt
# Discriminator error:  tensor(1.1542, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3620, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1476
# results/diabetes/1476_19.txt
# Discriminator error:  tensor(1.3354, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8633, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1477
# results/diabetes/1477_19.txt
# Discriminator error:  tensor(1.0743, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7630, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1478
# results/diabetes/1478_19.txt
# Discriminator error:  tensor(1.1891, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6212, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1479
# results/diabetes/1479_19.txt
# Discriminator error:  tensor(1.3558, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4912, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1480
# results/diabetes/1480_19.txt
# Discriminator error:  tensor(1.3958, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2557, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1481
# results/diabetes/1481_19.txt
# Discriminator error:  tensor(1.3305, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7796, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1482
# results/diabetes/1482_19.txt
# Discriminator error:  tensor(1.3232, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6988, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1483
# results/diabetes/1483_19.txt
# Discriminator error:  tensor(1.4166, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9360, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1484
# results/diabetes/1484_19.txt
# Discriminator error:  tensor(1.3375, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7330, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1485
# results/diabetes/1485_19.txt
# Discriminator error:  tensor(1.4479, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7640, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1486
# results/diabetes/1486_19.txt
# Discriminator error:  tensor(1.2235, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9710, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1487
# results/diabetes/1487_19.txt
# Discriminator error:  tensor(1.7722, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8177, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1488
# results/diabetes/1488_19.txt
# Discriminator error:  tensor(1.2211, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9765, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1489
# results/diabetes/1489_19.txt
# Discriminator error:  tensor(1.0230, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8979, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1490
# results/diabetes/1490_19.txt
# Discriminator error:  tensor(1.4505, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8285, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1491
# results/diabetes/1491_19.txt
# Discriminator error:  tensor(1.5798, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9002, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1492
# results/diabetes/1492_19.txt
# Discriminator error:  tensor(1.2332, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9384, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1493
# results/diabetes/1493_19.txt
# Discriminator error:  tensor(1.5062, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7527, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1494
# results/diabetes/1494_19.txt
# Discriminator error:  tensor(1.4009, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7790, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1495
# results/diabetes/1495_19.txt
# Discriminator error:  tensor(1.3444, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8790, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1496
# results/diabetes/1496_19.txt
# Discriminator error:  tensor(1.1581, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6918, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1497
# results/diabetes/1497_19.txt
# Discriminator error:  tensor(2.1008, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2370, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1498
# results/diabetes/1498_19.txt
# Discriminator error:  tensor(1.6813, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0178, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1499
# results/diabetes/1499_19.txt
# Discriminator error:  tensor(1.2845, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6036, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)

# %%
results_dir = f"models/{file_name.split('/')[-1].split('.')[0]}"
os.mkdir(results_dir)

# %%
print(epoch)
torch.save({
            'epoch': epoch,
            'model_state_dict': generator.state_dict(),
            'optimizer_state_dict': g_optimizer.state_dict(),
            'model_attributes': {'out_features': dataAtts.class_len},
            'loss': loss
            # }, "models/generator" + dataAtts.fname + "_" + str(epoch) + ".pt")
            }, results_dir + "/generator" + dataAtts.fname + "_" + str(epoch) + ".pt")

torch.save({
            'epoch': epoch,
            'model_state_dict': discriminator.state_dict(),
            'optimizer_state_dict': d_optimizer.state_dict(),
            'loss': loss
            # }, "models/discriminator" + dataAtts.fname + "_" + str(epoch) + ".pt")
            }, results_dir + "/discriminator" + dataAtts.fname + "_" + str(epoch) + ".pt")
# Out:
# 1499

# %%
plt.plot(d_error_plt, 'b')
plt.plot(g_error_plt, 'r')
filename = "results/" + dataAtts.fname + "/" + "error_growth.txt"
file = open(filename, "w")
file.write("Discriminator error: " + str(d_error_plt) + "\n")
file.write("\n\n\n")
file.write("Generator error: " + str(g_error_plt) + "\n")
file.close()

plt.savefig('images/'+ dataAtts.fname + "/"+ 'error.png')
plt.show()
plt.clf()
