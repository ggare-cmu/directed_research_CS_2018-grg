# %%
import torch
import pandas as pd
from torch import nn, optim
from torch.autograd.variable import Variable
from torchvision import transforms, datasets
from data_treatment import DataSetGRG, DataAtts
from discriminator import *
from generator import *
import ipywidgets as widgets
from IPython.display import display
import matplotlib.pyplot as plt
import glob

# %%
# Noise
def noise(size):
    n = Variable(torch.randn(size, 100))
    if torch.cuda.is_available(): 
        return n.cuda() 
    return n

# %%
files_dropdown = widgets.Dropdown(
    # options=glob.glob("original_data/*.csv"),
    options=glob.glob("grg_data/*.csv"),
    description='File:',
    # value = 'original_data/diabetes_escalonated.csv',
    disabled=False,
)
display(files_dropdown)
# Out:
# Dropdown(description='File:', options=('grg_data/diabetes-small3_TrainUpsampledPatient.csv', 'grg_data/diabete…

# %%
file_name=files_dropdown.value
dataAtts = DataAtts(file_name)

# %%
def train_generator(optimizer, fake_data):
    # 2. Train Generator
    # Reset gradients
    optimizer.zero_grad()
    # Sample noise and generate fake data
    prediction = discriminator(fake_data)
    # Calculate error and backpropagate
    error = loss(prediction, real_data_target(prediction.size(0)))
    error.backward()
    # Update weights with gradients
    optimizer.step()
    # Return error
    return error

def train_discriminator(optimizer, real_data, fake_data):
    # Reset gradients
    optimizer.zero_grad()
    
    # 1.1 Train on Real Data
    prediction_real = discriminator(real_data)
    # Calculate error and backpropagate
    error_real = loss(prediction_real, real_data_target(real_data.size(0)))
    error_real.backward()

    # 1.2 Train on Fake Data
    prediction_fake = discriminator(fake_data)
    # Calculate error and backpropagate
    error_fake = loss(prediction_fake, fake_data_target(real_data.size(0)))
    error_fake.backward()
    
    # 1.3 Update weights with gradients
    optimizer.step()
    
    # Return error
    return error_real + error_fake, prediction_real, prediction_fake

# %%
def real_data_target(size):
    '''
    Tensor containing ones, with shape = size
    '''
    data = Variable(torch.ones(size, 1))
    if torch.cuda.is_available(): return data.cuda()
    return data

def fake_data_target(size):
    '''
    Tensor containing zeros, with shape = size
    '''
    data = Variable(torch.zeros(size, 1))
    if torch.cuda.is_available(): return data.cuda()
    return data

# %%
lr = 0.0002
#lr= 0.0002
batch_size = 5
# num_epochs = 106
num_epochs = 1500
print_interval = 10
loss = nn.BCELoss()

# %%
# discriminator = DiscriminatorNet(dataAtts.class_len)
discriminator = DiscriminatorNet(dataAtts.class_len,  hidden_layers=[512, 256])
generator = GeneratorNet(dataAtts.class_len,  hidden_layers=[512, 256])
if torch.cuda.is_available():
    discriminator.cuda()
    generator.cuda()
d_optimizer = optim.Adam(discriminator.parameters(), lr=lr)
g_optimizer = optim.Adam(generator.parameters(), lr=lr)

# %%
d_error_plt = [0]
g_error_plt = [0]

generated_points = []

# %%
database = DataSetGRG(csv_file=file_name, root_dir=".")

data_loader = torch.utils.data.DataLoader(database, batch_size=batch_size, shuffle=True)
num_batches = len(data_loader)

# %%
for epoch in range(num_epochs):
    print("Epoch ", epoch)

    for n_batch, real_batch in enumerate(data_loader):
        # 1. Train Discriminator
        real_data = Variable(real_batch).float()
        if torch.cuda.is_available(): 
            real_data = real_data.cuda()
        # Generate fake data
        fake_data = generator(noise(real_data.size(0))).detach()
        # Train D
        d_error, d_pred_real, d_pred_fake = train_discriminator(d_optimizer,
                                                                real_data, fake_data)

        # 2. Train Generator
        # Generate fake data
        fake_data = generator(noise(real_batch.size(0)))
        generated_points.append(fake_data)
        # Train G
        g_error = train_generator(g_optimizer, fake_data)

        # Display Progress

        #if (n_batch) % print_interval == 0:
    filename = "results/" + dataAtts.fname + "/" + str(epoch) + "_" + str(n_batch) + ".txt"
    print(filename)
    file = open(filename, "w")
    print("Discriminator error: ", d_error)
    print("Generator error: ", g_error)
    print("")

    file.write("Discriminator error: " + str(d_error) + "\n")
    file.write("Generator error: " + str(g_error) + "\n")
    file.write("Points: " + str(fake_data) + "\n\n\n")

    # d_error_plt.append(d_error)
    # g_error_plt.append(g_error)
    d_error_plt.append(d_error.detach().cpu().numpy())
    g_error_plt.append(g_error.detach().cpu().numpy())
        #     #display.clear_output(True)
        #     # Display Images
        #     test_images = generator(test_noise).data.cpu()
        #     logger.log_images(test_images, num_test_samples, epoch, n_batch, num_batches);
        #     # Display status Logs
        #     #logger.display_status(epoch, num_epochs, n_batch, num_batches, d_error, g_error, d_pred_real, d_pred_fake)
        # # Model Checkpoints
# Out:
# Epoch  0
# results/diabetes/0_19.txt
# Discriminator error:  tensor(0.8250, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6104, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1
# results/diabetes/1_19.txt
# Discriminator error:  tensor(0.9682, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4579, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  2
# results/diabetes/2_19.txt
# Discriminator error:  tensor(0.9647, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4781, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  3
# results/diabetes/3_19.txt
# Discriminator error:  tensor(0.8824, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6841, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  4
# results/diabetes/4_19.txt
# Discriminator error:  tensor(1.1258, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4514, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  5
# results/diabetes/5_19.txt
# Discriminator error:  tensor(0.7253, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5765, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  6
# results/diabetes/6_19.txt
# Discriminator error:  tensor(0.5652, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9313, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  7
# results/diabetes/7_19.txt
# Discriminator error:  tensor(1.1304, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.2762, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  8
# results/diabetes/8_19.txt
# Discriminator error:  tensor(1.2725, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5472, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  9
# results/diabetes/9_19.txt
# Discriminator error:  tensor(2.0408, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4269, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  10
# results/diabetes/10_19.txt
# Discriminator error:  tensor(0.5640, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0179, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  11
# results/diabetes/11_19.txt
# Discriminator error:  tensor(0.9088, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1591, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  12
# results/diabetes/12_19.txt
# Discriminator error:  tensor(1.2579, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6738, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  13
# results/diabetes/13_19.txt
# Discriminator error:  tensor(2.2356, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4373, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  14
# results/diabetes/14_19.txt
# Discriminator error:  tensor(3.1756, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7514, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  15
# results/diabetes/15_19.txt
# Discriminator error:  tensor(0.3558, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9008, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  16
# results/diabetes/16_19.txt
# Discriminator error:  tensor(0.6657, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5741, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  17
# results/diabetes/17_19.txt
# Discriminator error:  tensor(0.9440, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4558, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  18
# results/diabetes/18_19.txt
# Discriminator error:  tensor(1.4149, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8206, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  19
# results/diabetes/19_19.txt
# Discriminator error:  tensor(0.9591, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0452, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  20
# results/diabetes/20_19.txt
# Discriminator error:  tensor(0.7938, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4879, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  21
# results/diabetes/21_19.txt
# Discriminator error:  tensor(0.3400, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1551, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  22
# results/diabetes/22_19.txt
# Discriminator error:  tensor(0.8246, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9773, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  23
# results/diabetes/23_19.txt
# Discriminator error:  tensor(0.5032, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8467, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  24
# results/diabetes/24_19.txt
# Discriminator error:  tensor(0.7279, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.3936, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  25
# results/diabetes/25_19.txt
# Discriminator error:  tensor(0.9055, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0407, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  26
# results/diabetes/26_19.txt
# Discriminator error:  tensor(3.9305, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.1728, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  27
# results/diabetes/27_19.txt
# Discriminator error:  tensor(0.7575, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1053, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  28
# results/diabetes/28_19.txt
# Discriminator error:  tensor(1.3216, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0007, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  29
# results/diabetes/29_19.txt
# Discriminator error:  tensor(0.6492, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6024, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  30
# results/diabetes/30_19.txt
# Discriminator error:  tensor(0.6992, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0810, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  31
# results/diabetes/31_19.txt
# Discriminator error:  tensor(0.4812, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4431, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  32
# results/diabetes/32_19.txt
# Discriminator error:  tensor(1.0122, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7611, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  33
# results/diabetes/33_19.txt
# Discriminator error:  tensor(0.5258, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0153, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  34
# results/diabetes/34_19.txt
# Discriminator error:  tensor(0.8924, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7255, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  35
# results/diabetes/35_19.txt
# Discriminator error:  tensor(0.7226, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1501, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  36
# results/diabetes/36_19.txt
# Discriminator error:  tensor(1.6156, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5672, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  37
# results/diabetes/37_19.txt
# Discriminator error:  tensor(0.5160, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4647, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  38
# results/diabetes/38_19.txt
# Discriminator error:  tensor(0.9343, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5199, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  39
# results/diabetes/39_19.txt
# Discriminator error:  tensor(1.2566, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7023, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  40
# results/diabetes/40_19.txt
# Discriminator error:  tensor(0.7419, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9266, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  41
# results/diabetes/41_19.txt
# Discriminator error:  tensor(1.1119, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0958, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  42
# results/diabetes/42_19.txt
# Discriminator error:  tensor(0.5904, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1815, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  43
# results/diabetes/43_19.txt
# Discriminator error:  tensor(0.8473, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8749, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  44
# results/diabetes/44_19.txt
# Discriminator error:  tensor(0.6586, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9980, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  45
# results/diabetes/45_19.txt
# Discriminator error:  tensor(0.5880, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6434, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  46
# results/diabetes/46_19.txt
# Discriminator error:  tensor(1.3250, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7884, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  47
# results/diabetes/47_19.txt
# Discriminator error:  tensor(1.2974, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1245, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  48
# results/diabetes/48_19.txt
# Discriminator error:  tensor(2.3811, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1205, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  49
# results/diabetes/49_19.txt
# Discriminator error:  tensor(0.1878, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.3884, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  50
# results/diabetes/50_19.txt
# Discriminator error:  tensor(1.3067, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7444, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  51
# results/diabetes/51_19.txt
# Discriminator error:  tensor(0.4234, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4747, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  52
# results/diabetes/52_19.txt
# Discriminator error:  tensor(2.0385, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8120, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  53
# results/diabetes/53_19.txt
# Discriminator error:  tensor(1.1149, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7377, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  54
# results/diabetes/54_19.txt
# Discriminator error:  tensor(1.8801, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7045, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  55
# results/diabetes/55_19.txt
# Discriminator error:  tensor(0.4906, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1029, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  56
# results/diabetes/56_19.txt
# Discriminator error:  tensor(1.1747, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5722, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  57
# results/diabetes/57_19.txt
# Discriminator error:  tensor(0.7601, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3738, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  58
# results/diabetes/58_19.txt
# Discriminator error:  tensor(0.6119, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3060, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  59
# results/diabetes/59_19.txt
# Discriminator error:  tensor(1.0126, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2717, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  60
# results/diabetes/60_19.txt
# Discriminator error:  tensor(0.5111, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0587, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  61
# results/diabetes/61_19.txt
# Discriminator error:  tensor(0.3600, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3585, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  62
# results/diabetes/62_19.txt
# Discriminator error:  tensor(1.2180, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9472, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  63
# results/diabetes/63_19.txt
# Discriminator error:  tensor(0.5186, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8861, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  64
# results/diabetes/64_19.txt
# Discriminator error:  tensor(2.5187, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.2164, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  65
# results/diabetes/65_19.txt
# Discriminator error:  tensor(0.2854, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4746, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  66
# results/diabetes/66_19.txt
# Discriminator error:  tensor(0.6049, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9318, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  67
# results/diabetes/67_19.txt
# Discriminator error:  tensor(1.0698, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0813, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  68
# results/diabetes/68_19.txt
# Discriminator error:  tensor(0.7681, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3418, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  69
# results/diabetes/69_19.txt
# Discriminator error:  tensor(0.9574, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1900, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  70
# results/diabetes/70_19.txt
# Discriminator error:  tensor(0.4244, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4369, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  71
# results/diabetes/71_19.txt
# Discriminator error:  tensor(1.6199, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8297, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  72
# results/diabetes/72_19.txt
# Discriminator error:  tensor(0.9130, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9918, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  73
# results/diabetes/73_19.txt
# Discriminator error:  tensor(1.0412, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7780, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  74
# results/diabetes/74_19.txt
# Discriminator error:  tensor(0.3703, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6461, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  75
# results/diabetes/75_19.txt
# Discriminator error:  tensor(0.5401, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9763, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  76
# results/diabetes/76_19.txt
# Discriminator error:  tensor(0.4143, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1601, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  77
# results/diabetes/77_19.txt
# Discriminator error:  tensor(1.9071, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8335, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  78
# results/diabetes/78_19.txt
# Discriminator error:  tensor(1.1792, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0165, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  79
# results/diabetes/79_19.txt
# Discriminator error:  tensor(1.8711, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.5000, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  80
# results/diabetes/80_19.txt
# Discriminator error:  tensor(1.7330, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7932, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  81
# results/diabetes/81_19.txt
# Discriminator error:  tensor(1.8035, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2093, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  82
# results/diabetes/82_19.txt
# Discriminator error:  tensor(0.9304, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6223, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  83
# results/diabetes/83_19.txt
# Discriminator error:  tensor(0.7253, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5395, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  84
# results/diabetes/84_19.txt
# Discriminator error:  tensor(1.4021, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2248, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  85
# results/diabetes/85_19.txt
# Discriminator error:  tensor(0.2434, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.6534, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  86
# results/diabetes/86_19.txt
# Discriminator error:  tensor(1.0074, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4340, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  87
# results/diabetes/87_19.txt
# Discriminator error:  tensor(0.9821, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.2973, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  88
# results/diabetes/88_19.txt
# Discriminator error:  tensor(0.6184, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7819, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  89
# results/diabetes/89_19.txt
# Discriminator error:  tensor(0.9678, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6930, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  90
# results/diabetes/90_19.txt
# Discriminator error:  tensor(0.7294, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0141, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  91
# results/diabetes/91_19.txt
# Discriminator error:  tensor(1.1516, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0922, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  92
# results/diabetes/92_19.txt
# Discriminator error:  tensor(1.7212, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4327, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  93
# results/diabetes/93_19.txt
# Discriminator error:  tensor(0.8393, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7793, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  94
# results/diabetes/94_19.txt
# Discriminator error:  tensor(2.2899, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8355, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  95
# results/diabetes/95_19.txt
# Discriminator error:  tensor(0.2270, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9763, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  96
# results/diabetes/96_19.txt
# Discriminator error:  tensor(1.4309, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1251, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  97
# results/diabetes/97_19.txt
# Discriminator error:  tensor(0.0679, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(3.1598, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  98
# results/diabetes/98_19.txt
# Discriminator error:  tensor(0.1004, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(3.6161, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  99
# results/diabetes/99_19.txt
# Discriminator error:  tensor(0.2459, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6490, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  100
# results/diabetes/100_19.txt
# Discriminator error:  tensor(1.5601, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5946, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  101
# results/diabetes/101_19.txt
# Discriminator error:  tensor(0.2897, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2657, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  102
# results/diabetes/102_19.txt
# Discriminator error:  tensor(1.3380, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9164, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  103
# results/diabetes/103_19.txt
# Discriminator error:  tensor(1.0566, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2281, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  104
# results/diabetes/104_19.txt
# Discriminator error:  tensor(0.5621, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4028, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  105
# results/diabetes/105_19.txt
# Discriminator error:  tensor(0.4891, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9444, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  106
# results/diabetes/106_19.txt
# Discriminator error:  tensor(2.1754, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.4611, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  107
# results/diabetes/107_19.txt
# Discriminator error:  tensor(1.6041, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0275, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  108
# results/diabetes/108_19.txt
# Discriminator error:  tensor(0.6073, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3312, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  109
# results/diabetes/109_19.txt
# Discriminator error:  tensor(0.5139, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5914, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  110
# results/diabetes/110_19.txt
# Discriminator error:  tensor(0.3338, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8530, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  111
# results/diabetes/111_19.txt
# Discriminator error:  tensor(1.7877, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2063, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  112
# results/diabetes/112_19.txt
# Discriminator error:  tensor(0.6412, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1512, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  113
# results/diabetes/113_19.txt
# Discriminator error:  tensor(0.4895, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7577, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  114
# results/diabetes/114_19.txt
# Discriminator error:  tensor(0.4479, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1371, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  115
# results/diabetes/115_19.txt
# Discriminator error:  tensor(1.0439, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5316, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  116
# results/diabetes/116_19.txt
# Discriminator error:  tensor(1.9353, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.9086, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  117
# results/diabetes/117_19.txt
# Discriminator error:  tensor(1.3164, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.6277, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  118
# results/diabetes/118_19.txt
# Discriminator error:  tensor(0.8098, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6764, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  119
# results/diabetes/119_19.txt
# Discriminator error:  tensor(0.3357, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9726, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  120
# results/diabetes/120_19.txt
# Discriminator error:  tensor(2.3441, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6686, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  121
# results/diabetes/121_19.txt
# Discriminator error:  tensor(0.8638, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7528, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  122
# results/diabetes/122_19.txt
# Discriminator error:  tensor(0.7807, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.6939, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  123
# results/diabetes/123_19.txt
# Discriminator error:  tensor(0.4888, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2799, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  124
# results/diabetes/124_19.txt
# Discriminator error:  tensor(0.8644, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.4635, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  125
# results/diabetes/125_19.txt
# Discriminator error:  tensor(0.6379, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4768, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  126
# results/diabetes/126_19.txt
# Discriminator error:  tensor(0.3186, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6715, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  127
# results/diabetes/127_19.txt
# Discriminator error:  tensor(0.6664, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8108, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  128
# results/diabetes/128_19.txt
# Discriminator error:  tensor(0.6935, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9743, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  129
# results/diabetes/129_19.txt
# Discriminator error:  tensor(1.0776, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9222, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  130
# results/diabetes/130_19.txt
# Discriminator error:  tensor(0.6439, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6858, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  131
# results/diabetes/131_19.txt
# Discriminator error:  tensor(0.5574, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6461, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  132
# results/diabetes/132_19.txt
# Discriminator error:  tensor(0.5792, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8090, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  133
# results/diabetes/133_19.txt
# Discriminator error:  tensor(0.7525, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8705, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  134
# results/diabetes/134_19.txt
# Discriminator error:  tensor(0.9689, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8637, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  135
# results/diabetes/135_19.txt
# Discriminator error:  tensor(1.1283, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7459, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  136
# results/diabetes/136_19.txt
# Discriminator error:  tensor(0.2954, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6800, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  137
# results/diabetes/137_19.txt
# Discriminator error:  tensor(0.0958, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.7426, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  138
# results/diabetes/138_19.txt
# Discriminator error:  tensor(1.1407, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9202, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  139
# results/diabetes/139_19.txt
# Discriminator error:  tensor(0.1584, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.7207, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  140
# results/diabetes/140_19.txt
# Discriminator error:  tensor(0.6811, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(3.3901, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  141
# results/diabetes/141_19.txt
# Discriminator error:  tensor(1.1530, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.2743, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  142
# results/diabetes/142_19.txt
# Discriminator error:  tensor(0.3798, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8354, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  143
# results/diabetes/143_19.txt
# Discriminator error:  tensor(0.9651, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6927, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  144
# results/diabetes/144_19.txt
# Discriminator error:  tensor(0.7035, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3032, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  145
# results/diabetes/145_19.txt
# Discriminator error:  tensor(1.8449, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5197, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  146
# results/diabetes/146_19.txt
# Discriminator error:  tensor(0.1000, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.5453, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  147
# results/diabetes/147_19.txt
# Discriminator error:  tensor(0.2065, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7470, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  148
# results/diabetes/148_19.txt
# Discriminator error:  tensor(0.7108, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9904, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  149
# results/diabetes/149_19.txt
# Discriminator error:  tensor(1.7159, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6105, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  150
# results/diabetes/150_19.txt
# Discriminator error:  tensor(0.5138, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3047, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  151
# results/diabetes/151_19.txt
# Discriminator error:  tensor(1.3184, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0272, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  152
# results/diabetes/152_19.txt
# Discriminator error:  tensor(0.3116, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0492, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  153
# results/diabetes/153_19.txt
# Discriminator error:  tensor(0.2481, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9132, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  154
# results/diabetes/154_19.txt
# Discriminator error:  tensor(0.4746, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8541, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  155
# results/diabetes/155_19.txt
# Discriminator error:  tensor(0.5841, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9635, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  156
# results/diabetes/156_19.txt
# Discriminator error:  tensor(0.2775, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1444, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  157
# results/diabetes/157_19.txt
# Discriminator error:  tensor(0.2696, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0921, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  158
# results/diabetes/158_19.txt
# Discriminator error:  tensor(0.1746, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(3.2427, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  159
# results/diabetes/159_19.txt
# Discriminator error:  tensor(0.1571, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(3.1892, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  160
# results/diabetes/160_19.txt
# Discriminator error:  tensor(0.2688, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(3.4424, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  161
# results/diabetes/161_19.txt
# Discriminator error:  tensor(2.9327, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(5.1278, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  162
# results/diabetes/162_19.txt
# Discriminator error:  tensor(0.0360, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0140, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  163
# results/diabetes/163_19.txt
# Discriminator error:  tensor(0.5945, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6072, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  164
# results/diabetes/164_19.txt
# Discriminator error:  tensor(0.8208, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5292, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  165
# results/diabetes/165_19.txt
# Discriminator error:  tensor(0.1699, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(3.3998, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  166
# results/diabetes/166_19.txt
# Discriminator error:  tensor(0.8839, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.5475, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  167
# results/diabetes/167_19.txt
# Discriminator error:  tensor(0.8612, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5941, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  168
# results/diabetes/168_19.txt
# Discriminator error:  tensor(0.5042, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3139, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  169
# results/diabetes/169_19.txt
# Discriminator error:  tensor(1.1872, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0511, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  170
# results/diabetes/170_19.txt
# Discriminator error:  tensor(0.7538, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8962, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  171
# results/diabetes/171_19.txt
# Discriminator error:  tensor(0.3928, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4461, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  172
# results/diabetes/172_19.txt
# Discriminator error:  tensor(0.4716, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5666, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  173
# results/diabetes/173_19.txt
# Discriminator error:  tensor(0.2915, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3255, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  174
# results/diabetes/174_19.txt
# Discriminator error:  tensor(0.8118, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5868, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  175
# results/diabetes/175_19.txt
# Discriminator error:  tensor(0.4613, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7793, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  176
# results/diabetes/176_19.txt
# Discriminator error:  tensor(0.3745, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4530, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  177
# results/diabetes/177_19.txt
# Discriminator error:  tensor(0.4979, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0844, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  178
# results/diabetes/178_19.txt
# Discriminator error:  tensor(0.1636, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.6190, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  179
# results/diabetes/179_19.txt
# Discriminator error:  tensor(0.2158, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9145, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  180
# results/diabetes/180_19.txt
# Discriminator error:  tensor(0.3149, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0788, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  181
# results/diabetes/181_19.txt
# Discriminator error:  tensor(0.4345, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.5609, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  182
# results/diabetes/182_19.txt
# Discriminator error:  tensor(0.7405, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4374, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  183
# results/diabetes/183_19.txt
# Discriminator error:  tensor(1.6496, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6978, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  184
# results/diabetes/184_19.txt
# Discriminator error:  tensor(1.7605, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1492, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  185
# results/diabetes/185_19.txt
# Discriminator error:  tensor(0.5639, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0571, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  186
# results/diabetes/186_19.txt
# Discriminator error:  tensor(1.8579, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5001, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  187
# results/diabetes/187_19.txt
# Discriminator error:  tensor(0.3650, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4320, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  188
# results/diabetes/188_19.txt
# Discriminator error:  tensor(0.8385, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4203, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  189
# results/diabetes/189_19.txt
# Discriminator error:  tensor(0.4019, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.6861, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  190
# results/diabetes/190_19.txt
# Discriminator error:  tensor(1.1425, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2291, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  191
# results/diabetes/191_19.txt
# Discriminator error:  tensor(1.0657, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3207, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  192
# results/diabetes/192_19.txt
# Discriminator error:  tensor(0.6269, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1663, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  193
# results/diabetes/193_19.txt
# Discriminator error:  tensor(0.4499, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3708, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  194
# results/diabetes/194_19.txt
# Discriminator error:  tensor(0.8162, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9928, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  195
# results/diabetes/195_19.txt
# Discriminator error:  tensor(0.3039, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0951, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  196
# results/diabetes/196_19.txt
# Discriminator error:  tensor(0.6841, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1403, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  197
# results/diabetes/197_19.txt
# Discriminator error:  tensor(0.4261, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5536, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  198
# results/diabetes/198_19.txt
# Discriminator error:  tensor(1.0255, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2334, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  199
# results/diabetes/199_19.txt
# Discriminator error:  tensor(0.7408, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8430, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  200
# results/diabetes/200_19.txt
# Discriminator error:  tensor(0.3655, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1706, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  201
# results/diabetes/201_19.txt
# Discriminator error:  tensor(1.0242, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7755, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  202
# results/diabetes/202_19.txt
# Discriminator error:  tensor(0.2871, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3178, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  203
# results/diabetes/203_19.txt
# Discriminator error:  tensor(0.2816, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8051, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  204
# results/diabetes/204_19.txt
# Discriminator error:  tensor(1.7424, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5106, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  205
# results/diabetes/205_19.txt
# Discriminator error:  tensor(0.6666, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7133, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  206
# results/diabetes/206_19.txt
# Discriminator error:  tensor(0.4245, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2828, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  207
# results/diabetes/207_19.txt
# Discriminator error:  tensor(0.1354, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1152, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  208
# results/diabetes/208_19.txt
# Discriminator error:  tensor(0.3767, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0022, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  209
# results/diabetes/209_19.txt
# Discriminator error:  tensor(0.7330, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5454, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  210
# results/diabetes/210_19.txt
# Discriminator error:  tensor(0.8632, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5957, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  211
# results/diabetes/211_19.txt
# Discriminator error:  tensor(1.0974, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8748, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  212
# results/diabetes/212_19.txt
# Discriminator error:  tensor(1.5006, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0569, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  213
# results/diabetes/213_19.txt
# Discriminator error:  tensor(0.7405, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9694, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  214
# results/diabetes/214_19.txt
# Discriminator error:  tensor(0.6453, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1631, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  215
# results/diabetes/215_19.txt
# Discriminator error:  tensor(0.1316, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1078, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  216
# results/diabetes/216_19.txt
# Discriminator error:  tensor(0.8699, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8147, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  217
# results/diabetes/217_19.txt
# Discriminator error:  tensor(0.8483, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1126, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  218
# results/diabetes/218_19.txt
# Discriminator error:  tensor(0.5912, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0842, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  219
# results/diabetes/219_19.txt
# Discriminator error:  tensor(0.3775, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3879, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  220
# results/diabetes/220_19.txt
# Discriminator error:  tensor(0.3035, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0649, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  221
# results/diabetes/221_19.txt
# Discriminator error:  tensor(0.5204, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5971, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  222
# results/diabetes/222_19.txt
# Discriminator error:  tensor(0.3530, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1016, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  223
# results/diabetes/223_19.txt
# Discriminator error:  tensor(0.7391, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.7610, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  224
# results/diabetes/224_19.txt
# Discriminator error:  tensor(0.4544, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.1674, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  225
# results/diabetes/225_19.txt
# Discriminator error:  tensor(0.8606, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0671, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  226
# results/diabetes/226_19.txt
# Discriminator error:  tensor(0.9185, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8812, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  227
# results/diabetes/227_19.txt
# Discriminator error:  tensor(0.6366, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2678, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  228
# results/diabetes/228_19.txt
# Discriminator error:  tensor(1.4331, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(3.0334, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  229
# results/diabetes/229_19.txt
# Discriminator error:  tensor(1.3378, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.7326, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  230
# results/diabetes/230_19.txt
# Discriminator error:  tensor(0.2976, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9775, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  231
# results/diabetes/231_19.txt
# Discriminator error:  tensor(0.1703, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.8635, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  232
# results/diabetes/232_19.txt
# Discriminator error:  tensor(1.1071, device='cuda:0', grad_fn=<AddBackward0>)
# ...
# Generator error:  tensor(1.0818, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1424
# results/diabetes/1424_19.txt
# Discriminator error:  tensor(0.5956, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(2.0713, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1425
# results/diabetes/1425_19.txt
# Discriminator error:  tensor(1.0999, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3051, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1426
# results/diabetes/1426_19.txt
# Discriminator error:  tensor(0.6210, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0867, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1427
# results/diabetes/1427_19.txt
# Discriminator error:  tensor(0.8420, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9386, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1428
# results/diabetes/1428_19.txt
# Discriminator error:  tensor(1.0014, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9981, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1429
# results/diabetes/1429_19.txt
# Discriminator error:  tensor(0.8438, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0993, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1430
# results/diabetes/1430_19.txt
# Discriminator error:  tensor(1.0337, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0291, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1431
# results/diabetes/1431_19.txt
# Discriminator error:  tensor(1.4269, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5612, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1432
# results/diabetes/1432_19.txt
# Discriminator error:  tensor(0.9101, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2444, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1433
# results/diabetes/1433_19.txt
# Discriminator error:  tensor(1.2414, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7527, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1434
# results/diabetes/1434_19.txt
# Discriminator error:  tensor(1.6159, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9793, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1435
# results/diabetes/1435_19.txt
# Discriminator error:  tensor(0.9337, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3210, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1436
# results/diabetes/1436_19.txt
# Discriminator error:  tensor(1.2469, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2053, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1437
# results/diabetes/1437_19.txt
# Discriminator error:  tensor(1.1430, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3913, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1438
# results/diabetes/1438_19.txt
# Discriminator error:  tensor(0.7412, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5803, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1439
# results/diabetes/1439_19.txt
# Discriminator error:  tensor(0.9037, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.7330, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1440
# results/diabetes/1440_19.txt
# Discriminator error:  tensor(1.3958, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2481, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1441
# results/diabetes/1441_19.txt
# Discriminator error:  tensor(1.3366, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2732, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1442
# results/diabetes/1442_19.txt
# Discriminator error:  tensor(0.9246, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.9312, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1443
# results/diabetes/1443_19.txt
# Discriminator error:  tensor(0.7079, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3884, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1444
# results/diabetes/1444_19.txt
# Discriminator error:  tensor(0.7648, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4057, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1445
# results/diabetes/1445_19.txt
# Discriminator error:  tensor(0.8525, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0189, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1446
# results/diabetes/1446_19.txt
# Discriminator error:  tensor(1.9320, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4537, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1447
# results/diabetes/1447_19.txt
# Discriminator error:  tensor(0.7782, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2368, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1448
# results/diabetes/1448_19.txt
# Discriminator error:  tensor(0.9057, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.8191, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1449
# results/diabetes/1449_19.txt
# Discriminator error:  tensor(1.0621, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2162, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1450
# results/diabetes/1450_19.txt
# Discriminator error:  tensor(0.5690, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4238, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1451
# results/diabetes/1451_19.txt
# Discriminator error:  tensor(0.6244, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0605, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1452
# results/diabetes/1452_19.txt
# Discriminator error:  tensor(1.1966, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3018, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1453
# results/diabetes/1453_19.txt
# Discriminator error:  tensor(0.8917, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2363, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1454
# results/diabetes/1454_19.txt
# Discriminator error:  tensor(0.9186, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1392, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1455
# results/diabetes/1455_19.txt
# Discriminator error:  tensor(0.7836, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4664, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1456
# results/diabetes/1456_19.txt
# Discriminator error:  tensor(0.4191, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2535, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1457
# results/diabetes/1457_19.txt
# Discriminator error:  tensor(0.7757, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5414, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1458
# results/diabetes/1458_19.txt
# Discriminator error:  tensor(0.8076, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2624, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1459
# results/diabetes/1459_19.txt
# Discriminator error:  tensor(0.9264, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4120, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1460
# results/diabetes/1460_19.txt
# Discriminator error:  tensor(0.6904, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3158, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1461
# results/diabetes/1461_19.txt
# Discriminator error:  tensor(1.1559, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2202, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1462
# results/diabetes/1462_19.txt
# Discriminator error:  tensor(0.7633, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2069, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1463
# results/diabetes/1463_19.txt
# Discriminator error:  tensor(1.5068, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3365, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1464
# results/diabetes/1464_19.txt
# Discriminator error:  tensor(0.3969, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3109, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1465
# results/diabetes/1465_19.txt
# Discriminator error:  tensor(0.3455, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5862, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1466
# results/diabetes/1466_19.txt
# Discriminator error:  tensor(1.3244, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5955, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1467
# results/diabetes/1467_19.txt
# Discriminator error:  tensor(0.9682, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2289, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1468
# results/diabetes/1468_19.txt
# Discriminator error:  tensor(0.6518, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1112, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1469
# results/diabetes/1469_19.txt
# Discriminator error:  tensor(1.0286, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4112, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1470
# results/diabetes/1470_19.txt
# Discriminator error:  tensor(0.6946, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2122, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1471
# results/diabetes/1471_19.txt
# Discriminator error:  tensor(1.2380, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0736, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1472
# results/diabetes/1472_19.txt
# Discriminator error:  tensor(1.1802, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1597, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1473
# results/diabetes/1473_19.txt
# Discriminator error:  tensor(1.2497, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0802, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1474
# results/diabetes/1474_19.txt
# Discriminator error:  tensor(1.1851, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4370, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1475
# results/diabetes/1475_19.txt
# Discriminator error:  tensor(0.9636, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4312, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1476
# results/diabetes/1476_19.txt
# Discriminator error:  tensor(0.5338, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9561, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1477
# results/diabetes/1477_19.txt
# Discriminator error:  tensor(0.5242, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2149, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1478
# results/diabetes/1478_19.txt
# Discriminator error:  tensor(1.1319, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1427, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1479
# results/diabetes/1479_19.txt
# Discriminator error:  tensor(1.1331, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2035, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1480
# results/diabetes/1480_19.txt
# Discriminator error:  tensor(1.1089, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3015, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1481
# results/diabetes/1481_19.txt
# Discriminator error:  tensor(1.0405, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3469, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1482
# results/diabetes/1482_19.txt
# Discriminator error:  tensor(1.5650, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5191, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1483
# results/diabetes/1483_19.txt
# Discriminator error:  tensor(0.6516, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3340, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1484
# results/diabetes/1484_19.txt
# Discriminator error:  tensor(1.4064, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1590, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1485
# results/diabetes/1485_19.txt
# Discriminator error:  tensor(1.3538, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.5135, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1486
# results/diabetes/1486_19.txt
# Discriminator error:  tensor(0.5384, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3140, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1487
# results/diabetes/1487_19.txt
# Discriminator error:  tensor(0.5260, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4007, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1488
# results/diabetes/1488_19.txt
# Discriminator error:  tensor(1.0019, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(0.9353, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1489
# results/diabetes/1489_19.txt
# Discriminator error:  tensor(0.7879, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4583, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1490
# results/diabetes/1490_19.txt
# Discriminator error:  tensor(1.4569, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.0242, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1491
# results/diabetes/1491_19.txt
# Discriminator error:  tensor(0.3675, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1793, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1492
# results/diabetes/1492_19.txt
# Discriminator error:  tensor(0.8185, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.1918, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1493
# results/diabetes/1493_19.txt
# Discriminator error:  tensor(1.2165, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.3148, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1494
# results/diabetes/1494_19.txt
# Discriminator error:  tensor(0.8619, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2311, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1495
# results/diabetes/1495_19.txt
# Discriminator error:  tensor(0.5388, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2267, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1496
# results/diabetes/1496_19.txt
# Discriminator error:  tensor(0.7382, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.4250, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1497
# results/diabetes/1497_19.txt
# Discriminator error:  tensor(0.8010, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2080, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1498
# results/diabetes/1498_19.txt
# Discriminator error:  tensor(1.1491, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2309, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)
#
# Epoch  1499
# results/diabetes/1499_19.txt
# Discriminator error:  tensor(1.0128, device='cuda:0', grad_fn=<AddBackward0>)
# Generator error:  tensor(1.2098, device='cuda:0', grad_fn=<BinaryCrossEntropyBackward0>)

# %%
results_dir = f"models/{file_name.split('/')[-1].split('.')[0]}"
os.mkdir(results_dir)

# %%
print(epoch)
torch.save({
            'epoch': epoch,
            'model_state_dict': generator.state_dict(),
            'optimizer_state_dict': g_optimizer.state_dict(),
            'model_attributes': {'out_features': dataAtts.class_len},
            'loss': loss
            # }, "models/generator" + dataAtts.fname + "_" + str(epoch) + ".pt")
            }, results_dir + "/generator" + dataAtts.fname + "_" + str(epoch) + ".pt")

torch.save({
            'epoch': epoch,
            'model_state_dict': discriminator.state_dict(),
            'optimizer_state_dict': d_optimizer.state_dict(),
            'loss': loss
            # }, "models/discriminator" + dataAtts.fname + "_" + str(epoch) + ".pt")
            }, results_dir + "/discriminator" + dataAtts.fname + "_" + str(epoch) + ".pt")
# Out:
# 1499

# %%
plt.plot(d_error_plt, 'b')
plt.plot(g_error_plt, 'r')
filename = "results/" + dataAtts.fname + "/" + "error_growth.txt"
file = open(filename, "w")
file.write("Discriminator error: " + str(d_error_plt) + "\n")
file.write("\n\n\n")
file.write("Generator error: " + str(g_error_plt) + "\n")
file.close()

plt.savefig('images/'+ dataAtts.fname + "/"+ 'error.png')
plt.show()
plt.clf()
